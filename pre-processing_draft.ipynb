# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from datetime import datetime
from sklearn.preprocessing import OneHotEncoder

# %%
df1 = pd.read_csv('mojo_pg11.csv')
df2 = pd.read_csv('mojo_pg22.csv')
df3 = pd.read_csv('mojo_pg33.csv')
df4 = pd.read_csv('mojo_pg44.csv')
df5 = pd.read_csv('mojo_pg55.csv')

# %%
df_all = pd.concat([df1,df2,df3,df4,df5])

# %%
df_all.columns
# Out:
# Index(['movie_title', 'domestic_distributor', 'budget',
#        'domestic_opening_sales', 'earliest_release', 'rating',
#        'runtime_minutes', 'genres', 'summary_sales', 'crew_list', 'cast_list'],
#       dtype='object')

# %%
df_all.sort_values(['domestic_opening_sales'], ascending=False)
# Out:
#                  movie_title                 domestic_distributor  \
# 1          Avengers: Endgame  Walt Disney Studios Motion Pictures
# 4     Avengers: Infinity War  Walt Disney Studios Motion Pictures
# 0     Star Wars: Episode VII  Walt Disney Studios Motion Pictures
# 8    Star Wars: Episode VIII  Walt Disney Studios Motion Pictures
# 6             Jurassic World                   Universal Pictures
# ..                       ...                                  ...
# 84        Young Frankenstein                Twentieth Century Fox
# 116                Pinocchio  Walt Disney Studios Motion Pictures
# 133                Airplane!                   Paramount Pictures
# 165                     MASH                Twentieth Century Fox
# 198           A Star Is Born                         Warner Bros.
#
#           budget  domestic_opening_sales   earliest_release rating  \
# 1    356000000.0             357115007.0     April 24, 2019  PG-13
# ...

# %%
top_movies_page_info['domestic_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'Domestic'])
top_movies_page_info['international_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'International'])
top_movies_page_info['worldwide_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'Worldwide'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-127-4617de2786d9> in <module>
# ----> 1 top_movies_page_info['domestic_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'Domestic'])
#       2 top_movies_page_info['international_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'International'])
#       3 top_movies_page_info['worldwide_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'Worldwide'])
#
# NameError: name 'top_movies_page_info' is not defined

# %%
df_all.dtypes
# Out:
# movie_title                object
# domestic_distributor       object
# budget                    float64
# domestic_opening_sales    float64
# earliest_release           object
# rating                     object
# runtime_minutes           float64
# genres                     object
# summary_sales              object
# crew_list                  object
# cast_list                  object
# dtype: object

# %%
df_all['genres'] = df_all['genres'].apply(literal_eval)
df_all.explode('genres')
# Out:
#                 movie_title                 domestic_distributor       budget  \
# 0    Star Wars: Episode VII  Walt Disney Studios Motion Pictures  245000000.0
# 0    Star Wars: Episode VII  Walt Disney Studios Motion Pictures  245000000.0
# 0    Star Wars: Episode VII  Walt Disney Studios Motion Pictures  245000000.0
# 1         Avengers: Endgame  Walt Disney Studios Motion Pictures  356000000.0
# 1         Avengers: Endgame  Walt Disney Studios Motion Pictures  356000000.0
# ..                      ...                                  ...          ...
# 198          A Star Is Born                         Warner Bros.          NaN
# 199                 Knowing                 Summit Entertainment   50000000.0
# 199                 Knowing                 Summit Entertainment   50000000.0
# 199                 Knowing                 Summit Entertainment   50000000.0
# 199                 Knowing                 Summit Entertainment   50000000.0
#
# ...

# %%
df_all.dtypes
# Out:
# movie_title                 object
# domestic_distributor        object
# budget                     float64
# domestic_opening_sales     float64
# earliest_release            object
# rating                      object
# runtime_minutes            float64
# genres                      object
# summary_sales               object
# crew_list                   object
# cast_list                   object
# domestic_sales              object
# domestic_dist_processed     object
# dtype: object

# %%
dist_counts = df_all['domestic_distributor'].value_counts()
other_dist = list(dist_counts[dist_counts <= 6].index)
other_dist
df_all['domestic_dist_processed'] = df_all['domestic_distributor'].replace(other_dist, 'Other')
df_all['domestic_dist_processed'].value_counts()
# Out:
# Warner Bros.                           166
# Walt Disney Studios Motion Pictures    161
# Twentieth Century Fox                  130
# Universal Pictures                     127
# Paramount Pictures                     116
# Sony Pictures Entertainment (SPE)      100
# Other                                   50
# DreamWorks                              22
# New Line Cinema                         22
# Lionsgate                               20
# DreamWorks Distribution                 17
# Columbia Pictures                       14
# Metro-Goldwyn-Mayer (MGM)               14
# TriStar Pictures                        12
# Miramax                                  9
# Revolution Studios                       8
# Dimension Films                          7
# Name: domestic_dist_processed, dtype: int64

# %%
domestic_distributors_list = df_all['domestic_dist_processed'].unique().tolist()
domestic_distributors_list
# Out:
# ['Walt Disney Studios Motion Pictures',
#  'Twentieth Century Fox',
#  'Paramount Pictures',
#  'Universal Pictures',
#  'Warner Bros.',
#  'DreamWorks Distribution',
#  'Lionsgate',
#  'Sony Pictures Entertainment (SPE)',
#  'DreamWorks',
#  'New Line Cinema',
#  'Other',
#  'Columbia Pictures',
#  'TriStar Pictures',
#  'Metro-Goldwyn-Mayer (MGM)',
#  nan,
#  'Miramax',
#  'Revolution Studios',
#  'Dimension Films']

# %%
df_dist = df_all[['domestic_dist_processed']]
for i in domestic_distributors_list:
    df_dist[i] = df_dist['domestic_dist_processed'].apply(lambda x : 1 if i in x else 0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-113-84a05aa4623b> in <module>
#       1 df_dist = df_all[['domestic_dist_processed']]
#       2 for i in domestic_distributors_list:
# ----> 3     df_dist[i] = df_dist['domestic_dist_processed'].apply(lambda x : 1 if i in x else 0)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4198             else:
#    4199                 values = self.astype(object)._values
# -> 4200                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    4201
#    4202         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-113-84a05aa4623b> in <lambda>(x)
#       1 df_dist = df_all[['domestic_dist_processed']]
#       2 for i in domestic_distributors_list:
# ...

# %%
for s in df_all['earliest_release']:
    datetime.strptime(s, '%B %d, %Y')
    d.strftime('%Y-%m-%d')

# %%
df_all.head()
# Out:
#               movie_title                 domestic_distributor       budget  \
# 0  Star Wars: Episode VII  Walt Disney Studios Motion Pictures  245000000.0
# 1       Avengers: Endgame  Walt Disney Studios Motion Pictures  356000000.0
# 2                  Avatar                Twentieth Century Fox  237000000.0
# 3           Black Panther  Walt Disney Studios Motion Pictures          NaN
# 4  Avengers: Infinity War  Walt Disney Studios Motion Pictures          NaN
#
#    domestic_opening_sales   earliest_release rating  runtime_minutes  \
# 0             247966675.0  December 16, 2015  PG-13            138.0
# 1             357115007.0     April 24, 2019  PG-13            181.0
# 2              77025481.0  December 16, 2009  PG-13            162.0
# 3             202003951.0  February 13, 2018  PG-13            134.0
# 4             257698183.0     April 25, 2018  PG-13            149.0
#
#                                          genres  \
# ...

# %%
df_all.dtypes
# Out:
# movie_title                 object
# domestic_distributor        object
# budget                     float64
# domestic_opening_sales     float64
# earliest_release            object
# rating                      object
# runtime_minutes            float64
# genres                      object
# summary_sales               object
# crew_list                   object
# cast_list                   object
# domestic_sales              object
# domestic_dist_processed     object
# dtype: object
