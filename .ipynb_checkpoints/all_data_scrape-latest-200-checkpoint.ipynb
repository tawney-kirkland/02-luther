# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
from datetime import datetime

# %%
url = 'https://www.boxofficemojo.com/chart/top_lifetime_gross/?offset=200'

user_agent = {'User-agent': 'Mozilla/5.0'}

response  = requests.get(url, headers = user_agent)

page = response.text

soup = BeautifulSoup(page,"lxml")

# %%
table = soup.find('table')
table
# Out:
# <table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Lifetime Gross">Lifetime Gross</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">201</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0372784/?ref_=bo_cso_table_1">Batman Begins</a></td><td class="a-text-right mojo-field-type-money">$206,852,432</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2005/?ref_=bo_cso_table_1">2005</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">202</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0367594/?ref_=bo_cso_table_2">Charlie and the Chocolate Factory</a></td><td class="a-text-right mojo-field-type-money">$206,459,076</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2005/?ref_=bo_cso_table_2">2005</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">203</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0382932/?ref_=bo_cso_table_3">Ratatouille</a></td><td class="a-text-right mojo-field-type-money">$206,445,654</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2007/?ref_=bo_cso_table_3">2007</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">204</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1981115/?ref_=bo_cso_table_4">Thor: The Dark World</a></td><td class="a-text-right mojo-field-type-money">$206,362,140</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2013/?ref_=bo_cso_table_4">2013</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">205</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1502397/?ref_=bo_cso_table_5">Bad Boys for Life</a></td><td class="a-text-right mojo-field-type-money">$206,305,244</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2020/?ref_=bo_cso_table_5">2020</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">206</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0145660/?ref_=bo_cso_table_6">Austin Powers: The Spy Who Shagged Me</a></td><td class="a-text-right mojo-field-type-money">$206,040,086</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/1999/?ref_=bo_cso_table_6">1999</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">207</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0103064/?ref_=bo_cso_table_7">Terminator 2: Judgment Day</a></td><td class="a-text-right mojo-field-type-money">$205,881,154</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/1991/?ref_=bo_cso_table_7">1991</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">208</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1872181/?ref_=bo_cso_table_8">The Amazing Spider-Man 2</a></td><td class="a-text-right mojo-field-type-money">$202,853,933</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2014/?ref_=bo_cso_table_8">2014</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">209</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0816711/?ref_=bo_cso_table_9">World War Z</a></td><td class="a-text-right mojo-field-type-money">$202,359,711</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2013/?ref_=bo_cso_table_9">2013</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">210</td><td class="a-text-left mojo-field-type-title ...

# %%
rows = [row for row in table.find_all('tr')]

# %%
movies = {}

for row in rows[1:]:
    items = row.find_all('td')
    link = row.find('a')
    title, url = link.text, link['href']
    movies[title] = [url] + [i.text for i in items]
    
movies
# Out:
# {'Batman Begins': ['/title/tt0372784/?ref_=bo_cso_table_1',
#   '201',
#   'Batman Begins',
#   '$206,852,432',
#   '2005'],
#  'Charlie and the Chocolate Factory': ['/title/tt0367594/?ref_=bo_cso_table_2',
#   '202',
#   'Charlie and the Chocolate Factory',
#   '$206,459,076',
#   '2005'],
#  'Ratatouille': ['/title/tt0382932/?ref_=bo_cso_table_3',
#   '203',
#   'Ratatouille',
#   '$206,445,654',
#   '2007'],
#  'Thor: The Dark World': ['/title/tt1981115/?ref_=bo_cso_table_4',
#   '204',
#   'Thor: The Dark World',
#   '$206,362,140',
#   '2013'],
#  'Bad Boys for Life': ['/title/tt1502397/?ref_=bo_cso_table_5',
#   '205',
#   'Bad Boys for Life',
#   '$206,305,244',
#   '2020'],
#  'Austin Powers: The Spy Who Shagged Me': ['/title/tt0145660/?ref_=bo_cso_table_6',
#   '206',
#   'Austin Powers: The Spy Who Shagged Me',
#   '$206,040,086',
#   '1999'],
#  'Terminator 2: Judgment Day': ['/title/tt0103064/?ref_=bo_cso_table_7',
#   '207',
#   'Terminator 2: Judgment Day',
#   '$205,881,154',
#   '1991'],
#  'The Amazing Spider-Man 2': ['/title/tt1872181/?ref_=bo_cso_table_8',
#   '208',
#   'The Amazing Spider-Man 2',
#   '$202,853,933',
#   '2014'],
#  'World War Z': ['/title/tt0816711/?ref_=bo_cso_table_9',
#   '209',
#   'World War Z',
#   '$202,359,711',
#   '2013'],
#  'The Mummy Returns': ['/title/tt0209163/?ref_=bo_cso_table_10',
#   '210',
#   'The Mummy Returns',
#   '$202,019,785',
#   '2001'],
#  'Armageddon': ['/title/tt0120591/?ref_=bo_cso_table_11',
#   '211',
#   'Armageddon',
#   '$201,578,182',
#   '1998'],
#  'Cinderella': ['/title/tt1661199/?ref_=bo_cso_table_12',
#   '212',
#   'Cinderella',
#   '$201,151,353',
#   '2015'],
#  'Ralph Breaks the Internet': ['/title/tt5848272/?ref_=bo_cso_table_13',
#   '213',
#   'Ralph Breaks the Internet',
#   '$201,091,711',
#   '2018'],
#  'Gone with the Wind': ['/title/tt0031381/?ref_=bo_cso_table_14',
#   '214',
#   'Gone with the Wind',
#   '$200,852,579',
#   '1939'],
#  'Tangled': ['/title/tt0398286/?ref_=bo_cso_table_15',
#   '215',
#   'Tangled',
#   '$200,821,936',
#   '2010'],
#  'Godzilla': ['/title/tt0831387/?ref_=bo_cso_table_16',
#   '216',
#   'Godzilla',
#   '$200,676,069',
#   '2014'],
#  'Superman Returns': ['/title/tt0348150/?ref_=bo_cso_table_17',
#   '217',
#   'Superman Returns',
#   '$200,081,192',
#   '2006'],
#  'Spectre': ['/title/tt2379713/?ref_=bo_cso_table_18',
#   '218',
#   'Spectre',
#   '$200,074,609',
#   '2015'],
#  'Pearl Harbor': ['/title/tt0213149/?ref_=bo_cso_table_19',
#   '219',
#   'Pearl Harbor',
#   '$198,542,554',
#   '2001'],
#  'Monsters vs. Aliens': ['/title/tt0892782/?ref_=bo_cso_table_20',
#   '220',
#   'Monsters vs. Aliens',
#   '$198,351,526',
#   '2009'],
#  'Happy Feet': ['/title/tt0366548/?ref_=bo_cso_table_21',
#   '221',
#   'Happy Feet',
#   '$198,000,317',
#   '2006'],
#  'Indiana Jones and the Last Crusade': ['/title/tt0097576/?ref_=bo_cso_table_22',
#   '222',
#   'Indiana Jones and the Last Crusade',
#   '$197,171,806',
#   '1989'],
#  'Ice Age: Dawn of the Dinosaurs': ['/title/tt1080016/?ref_=bo_cso_table_23',
#   '223',
#   'Ice Age: Dawn of the Dinosaurs',
#   '$196,573,705',
#   '2009'],
#  'Ice Age: The Meltdown': ['/title/tt0438097/?ref_=bo_cso_table_24',
#   '224',
#   'Ice Age: The Meltdown',
#   '$195,330,621',
#   '2006'],
#  'Mission: Impossible - Rogue Nation': ['/title/tt2381249/?ref_=bo_cso_table_25',
#   '225',
#   'Mission: Impossible - Rogue Nation',
#   '$195,042,377',
#   '2015'],
#  'Twilight': ['/title/tt1099212/?ref_=bo_cso_table_26',
#   '226',
#   'Twilight',
#   '$193,962,473',
#   '2008'],
#  'Men in Black II': ['/title/tt0120912/?ref_=bo_cso_table_27',
#   '227',
#   'Men in Black II',
#   '$193,735,288',
#   '2002'],
#  'Madagascar': ['/title/tt0351283/?ref_=bo_cso_table_28',
#   '228',
#   'Madagascar',
#   '$193,595,521',
#   '2005'],
#  '22 Jump Street': ['/title/tt2294449/?ref_=bo_cso_table_29',
#   '229',
#   '22 Jump Street',
#   '$191,719,337',
#   '2014'],
#  'Cars 2': ['/title/tt1216475/?ref_=bo_cso_table_30',
#   '230',
#   'Cars 2',
#   '$191,452,396',
#   '2011'],
#  'Teenage Mutant Ninja Turtles': ['/title/tt1291150/?ref_=bo_cso_table_31',
#   '231',
#   'Teenage Mutant Ninja Turtles',
#   '$191,204,754',
#   '2014'],
#  'Spider-Man: Into the Spider-Verse': ['/title/tt4633694/?ref_=bo_cso_table_32',
#   '232',
#   'Spider-Man: Into the Spider-Verse',
#   '$190,241,310',
#   '2018'],
#  'Grease': ['/title/tt0077631/?ref_=bo_cso_table_33',
#   '233',
#   'Grease',
#   '$190,071,103',
#   '1978'],
#  'Dunkirk': ['/title/tt5013056/?ref_=bo_cso_table_34',
#   '234',
#   'Dunkirk',
#   '$189,740,665',
#   '2017'],
#  'Wreck-It Ralph': ['/title/tt1772341/?ref_=bo_cso_table_35',
#   '235',
#   'Wreck-It Ralph',
#   '$189,422,889',
#   '2012'],
#  'A Quiet Place': ['/title/tt6644200/?ref_=bo_cso_table_36',
#   '236',
#   'A Quiet Place',
#   '$188,024,361',
#   '2018'],
#  'Interstellar': ['/title/tt0816692/?ref_=bo_cso_table_37',
#   '237',
#   'Interstellar',
#   '$188,020,017',
#   '2014'],
#  'The Polar Express': ['/title/tt0338348/?ref_=bo_cso_table_38',
#   '238',
#   'The Polar Express',
#   '$187,935,490',
#   '2004'],
#  'Gladiator': ['/title/tt0172495/?ref_=bo_cso_table_39',
#   '239',
#   'Gladiator',
#   '$187,705,427',
#   '2000'],
#  'The Croods': ['/title/tt0481499/?ref_=bo_cso_table_40',
#   '240',
#   'The Croods',
#   '$187,168,425',
#   '2013'],
#  'Sherlock Holmes: A Game of Shadows': ['/title/tt1515091/?ref_=bo_cso_table_41',
#   '241',
#   'Sherlock Holmes: A Game of Shadows',
#   '$186,848,418',
#   '2011'],
#  'The Day After Tomorrow': ['/title/tt0319262/?ref_=bo_cso_table_42',
#   '242',
#   'The Day After Tomorrow',
#   '$186,740,799',
#   '2004'],
#  'Mr. & Mrs. Smith': ['/title/tt0356910/?ref_=bo_cso_table_43',
#   '243',
#   'Mr. & Mrs. Smith',
#   '$186,336,279',
#   '2005'],
#  'Snow White and the Seven Dwarfs': ['/title/tt0029583/?ref_=bo_cso_table_44',
#   '244',
#   'Snow White and the Seven Dwarfs',
#   '$184,925,486',
#   '1937'],
#  'Pitch Perfect 2': ['/title/tt2848292/?ref_=bo_cso_table_45',
#   '245',
#   'Pitch Perfect 2',
#   '$184,296,230',
#   '2015'],
#  'Dances with Wolves': ['/title/tt0099348/?ref_=bo_cso_table_46',
#   '246',
#   'Dances with Wolves',
#   '$184,208,848',
#   '1990'],
#  'Batman Forever': ['/title/tt0112462/?ref_=bo_cso_table_47',
#   '247',
#   'Batman Forever',
#   '$184,069,126',
#   '1995'],
#  'The Fugitive': ['/title/tt0106977/?ref_=bo_cso_table_48',
#   '248',
#   'The Fugitive',
#   '$183,875,760',
#   '1993'],
#  'The Revenant': ['/title/tt1663202/?ref_=bo_cso_table_49',
#   '249',
#   'The Revenant',
#   '$183,637,894',
#   '2015'],
#  "Ocean's Eleven": ['/title/tt0240772/?ref_=bo_cso_table_50',
#   '250',
#   "Ocean's Eleven",
#   '$183,417,150',
#   '2001'],
#  'The Simpsons Movie': ['/title/tt0462538/?ref_=bo_cso_table_51',
#   '251',
#   'The Simpsons Movie',
#   '$183,135,014',
#   '2007'],
#  'What Women Want': ['/title/tt0207201/?ref_=bo_cso_table_52',
#   '252',
#   'What Women Want',
#   '$182,811,707',
#   '2000'],
#  'The Perfect Storm': ['/title/tt0177971/?ref_=bo_cso_table_53',
#   '253',
#   'The Perfect Storm',
#   '$182,618,434',
#   '2000'],
#  'Lincoln': ['/title/tt0443272/?ref_=bo_cso_table_54',
#   '254',
#   'Lincoln',
#   '$182,207,973',
#   '2012'],
#  'Liar Liar': ['/title/tt0119528/?ref_=bo_cso_table_55',
#   '255',
#   'Liar Liar',
#   '$181,410,615',
#   '1997'],
#  'Jurassic Park III': ['/title/tt0163025/?ref_=bo_cso_table_56',
#   '256',
#   'Jurassic Park III',
#   '$181,171,875',
#   '2001'],
#  'Thor': ['/title/tt0800369/?ref_=bo_cso_table_57',
#   '257',
#   'Thor',
#   '$181,030,624',
#   '2011'],
#  'Mission: Impossible': ['/title/tt0117060/?ref_=bo_cso_table_58',
#   '258',
#   'Mission: Impossible',
#   '$180,981,856',
#   '1996'],
#  'Ant-Man': ['/title/tt0478970/?ref_=bo_cso_table_59',
#   '259',
#   'Ant-Man',
#   '$180,202,163',
#   '2015'],
#  'Planet of the Apes': ['/title/tt0133152/?ref_=bo_cso_table_60',
#   '260',
#   'Planet of the Apes',
#   '$180,011,740',
#   '2001'],
#  'Madagascar: Escape 2 Africa': ['/title/tt0479952/?ref_=bo_cso_table_61',
#   '261',
#   'Madagascar: Escape 2 Africa',
#   '$180,010,950',
#   '2008'],
#  'X-Men Origins: Wolverine': ['/title/tt0458525/?ref_=bo_cso_table_62',
#   '262',
#   'X-Men Origins: Wolverine',
#   '$179,883,157',
#   '2009'],
#  'Indiana Jones and the Temple of Doom': ['/title/tt0087469/?ref_=bo_cso_table_63',
#   '263',
#   'Indiana Jones and the Temple of Doom',
#   '$179,870,271',
#   '1984'],
#  'Top Gun': ['/title/tt0092099/?ref_=bo_cso_table_64',
#   '264',
#   'Top Gun',
#   '$179,800,601',
#   '1986'],
#  'Hitch': ['/title/tt0386588/?ref_=bo_cso_table_65',
#   '265',
#   'Hitch',
#   '$179,495,555',
#   '2005'],
#  'Men in Black 3': ['/title/tt1409024/?ref_=bo_cso_table_66',
#   '266',
#   'Men in Black 3',
#   '$179,020,854',
#   '2012'],
#  'Pretty Woman': ['/title/tt0100405/?ref_=bo_cso_table_67',
#   '267',
#   'Pretty Woman',
#   '$178,406,268',
#   '1990'],
#  'Home': ['/title/tt2224026/?ref_=bo_cso_table_68',
#   '268',
#   'Home',
#   '$177,397,510',
#   '2015'],
#  'Night at the Museum: Battle of the Smithsonian': ['/title/tt1078912/?ref_=bo_cso_table_69',
#   '269',
#   'Night at the Museum: Battle of the Smithsonian',
#   '$177,243,721',
#   '2009'],
#  'Tootsie': ['/title/tt0084805/?ref_=bo_cso_table_70',
#   '270',
#   'Tootsie',
#   '$177,200,000',
#   '1982'],
#  'How to Train Your Dragon 2': ['/title/tt1646971/?ref_=bo_cso_table_71',
#   '271',
#   'How to Train Your Dragon 2',
#   '$177,002,924',
#   '2014'],
#  'Rise of the Planet of the Apes': ['/title/tt1318514/?ref_=bo_cso_table_72',
#   '272',
#   'Rise of the Planet of the Apes',
#   '$176,760,185',
#   '2011'],
#  'Captain America: The First Avenger': ['/title/tt0458339/?ref_=bo_cso_table_73',
#   '273',
#   'Captain America: The First Avenger',
#   '$176,654,505',
#   '2011'],
#  'Elf': ['/title/tt0319343/?ref_=bo_cso_table_74',
#   '274',
#   'Elf',
#   '$176,630,408',
#   '2003'],
#  'The Karate Kid': ['/title/tt1155076/?ref_=bo_cso_table_75',
#   '275',
#   'The Karate Kid',
#   '$176,591,618',
#   '2010'],
#  "There's Something About Mary": ['/title/tt0129387/?ref_=bo_cso_table_76',
#   '276',
#   "There's Something About Mary",
#   '$176,484,651',
#   '1998'],
#  'Ice Age': ['/title/tt0268380/?ref_=bo_cso_table_77',
#   '277',
#   'Ice Age',
#   '$176,387,405',
#   '2002'],
#  'The Bourne Supremacy': ['/title/tt0372183/?ref_=bo_cso_table_78',
#   '278',
#   'The Bourne Supremacy',
#   '$176,241,941',
#   '2004'],
#  'Get Out': ['/title/tt5052448/?ref_=bo_cso_table_79',
#   '279',
#   'Get Out',
#   '$176,040,665',
#   '2017'],
#  'The Lego Batman Movie': ['/title/tt4116284/?ref_=bo_cso_table_80',
#   '280',
#   'The Lego Batman Movie',
#   '$175,750,384',
#   '2017'],
#  'Us': ['/title/tt6857112/?ref_=bo_cso_table_81',
#   '281',
#   'Us',
#   '$175,084,580',
#   '2019'],
#  'The Boss Baby': ['/title/tt3874544/?ref_=bo_cso_table_82',
#   '282',
#   'The Boss Baby',
#   '$175,003,033',
#   '2017'],
#  'Crocodile Dundee': ['/title/tt0090555/?ref_=bo_cso_table_83',
#   '283',
#   'Crocodile Dundee',
#   '$174,803,506',
#   '1986'],
#  'Crazy Rich Asians': ['/title/tt3104988/?ref_=bo_cso_table_84',
#   '284',
#   'Crazy Rich Asians',
#   '$174,532,921',
#   '2018'],
#  'The Greatest Showman': ['/title/tt1485796/?ref_=bo_cso_table_85',
#   '285',
#   'The Greatest Showman',
#   '$174,340,174',
#   '2017'],
#  'Fast & Furious Presents: Hobbs & Shaw': ['/title/tt6806448/?ref_=bo_cso_table_86',
#   '286',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   '$173,956,935',
#   '2019'],
#  'Apollo 13': ['/title/tt0112384/?ref_=bo_cso_table_87',
#   '287',
#   'Apollo 13',
#   '$173,837,933',
#   '1995'],
#  'Home Alone 2: Lost in New York': ['/title/tt0104431/?ref_=bo_cso_table_88',
#   '288',
#   'Home Alone 2: Lost in New York',
#   '$173,585,516',
#   '1992'],
#  'National Treasure': ['/title/tt0368891/?ref_=bo_cso_table_89',
#   '289',
#   'National Treasure',
#   '$173,008,894',
#   '2004'],
#  'Air Force One': ['/title/tt0118571/?ref_=bo_cso_table_90',
#   '290',
#   'Air Force One',
#   '$172,956,409',
#   '1997'],
#  'Rain Man': ['/title/tt0095953/?ref_=bo_cso_table_91',
#   '291',
#   'Rain Man',
#   '$172,825,435',
#   '1988'],
#  'Pirates of the Caribbean: Dead Men Tell No Tales': ['/title/tt1790809/?ref_=bo_cso_table_92',
#   '292',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   '$172,558,876',
#   '2017'],
#  'TRON: Legacy': ['/title/tt1104001/?ref_=bo_cso_table_93',
#   '293',
#   'TRON: Legacy',
#   '$172,062,763',
#   '2010'],
#  'Mary Poppins Returns': ['/title/tt5028340/?ref_=bo_cso_table_94',
#   '294',
#   'Mary Poppins Returns',
#   '$171,958,438',
#   '2018'],
#  'The Matrix': ['/title/tt0133093/?ref_=bo_cso_table_95',
#   '295',
#   'The Matrix',
#   '$171,479,930',
#   '1999'],
#  'True Grit': ['/title/tt1403865/?ref_=bo_cso_table_96',
#   '296',
#   'True Grit',
#   '$171,243,005',
#   '2010'],
#  'Tarzan': ['/title/tt0120855/?ref_=bo_cso_table_97',
#   '297',
#   'Tarzan',
#   '$171,091,819',
#   '1999'],
#  'John Wick: Chapter 3 - Parabellum': ['/title/tt6146586/?ref_=bo_cso_table_98',
#   '298',
#   'John Wick: Chapter 3 - Parabellum',
#   '$171,015,687',
#   '2019'],
#  'A Beautiful Mind': ['/title/tt0268978/?ref_=bo_cso_table_99',
#   '299',
#   'A Beautiful Mind',
#   '$170,742,341',
#   '2001'],
#  'Chicago': ['/title/tt0299658/?ref_=bo_cso_table_100',
#   '300',
#   'Chicago',
#   '$170,687,518',
#   '2002'],
#  'The Help': ['/title/tt1454029/?ref_=bo_cso_table_101',
#   '301',
#   'The Help',
#   '$169,708,112',
#   '2011'],
#  'Hotel Transylvania 2': ['/title/tt2510894/?ref_=bo_cso_table_102',
#   '302',
#   'Hotel Transylvania 2',
#   '$169,700,110',
#   '2015'],
#  'Hidden Figures': ['/title/tt4846340/?ref_=bo_cso_table_103',
#   '303',
#   'Hidden Figures',
#   '$169,607,287',
#   '2016'],
#  'Bridesmaids': ['/title/tt1478338/?ref_=bo_cso_table_104',
#   '304',
#   'Bridesmaids',
#   '$169,106,725',
#   '2011'],
#  'Quantum of Solace': ['/title/tt0830515/?ref_=bo_cso_table_105',
#   '305',
#   'Quantum of Solace',
#   '$168,368,427',
#   '2008'],
#  'Wild Hogs': ['/title/tt0486946/?ref_=bo_cso_table_106',
#   '306',
#   'Wild Hogs',
#   '$168,273,550',
#   '2007'],
#  'Kong: Skull Island': ['/title/tt3731562/?ref_=bo_cso_table_107',
#   '307',
#   'Kong: Skull Island',
#   '$168,052,812',
#   '2017'],
#  'Three Men and a Baby': ['/title/tt0094137/?ref_=bo_cso_table_108',
#   '308',
#   'Three Men and a Baby',
#   '$167,780,960',
#   '1987'],
#  'Gone Girl': ['/title/tt2267998/?ref_=bo_cso_table_109',
#   '309',
#   'Gone Girl',
#   '$167,767,189',
#   '2014'],
#  'Hotel Transylvania 3: Summer Vacation': ['/title/tt5220122/?ref_=bo_cso_table_110',
#   '310',
#   'Hotel Transylvania 3: Summer Vacation',
#   '$167,510,016',
#   '2018'],
#  'Casino Royale': ['/title/tt0381061/?ref_=bo_cso_table_111',
#   '311',
#   'Casino Royale',
#   '$167,445,960',
#   '2006'],
#  'Meet the Parents': ['/title/tt0212338/?ref_=bo_cso_table_112',
#   '312',
#   'Meet the Parents',
#   '$166,244,045',
#   '2000'],
#  'Fifty Shades of Grey': ['/title/tt2322441/?ref_=bo_cso_table_113',
#   '313',
#   'Fifty Shades of Grey',
#   '$166,167,230',
#   '2015'],
#  '2012': ['/title/tt1190080/?ref_=bo_cso_table_114',
#   '314',
#   '2012',
#   '$166,112,167',
#   '2009'],
#  'Robin Hood: Prince of Thieves': ['/title/tt0102798/?ref_=bo_cso_table_115',
#   '315',
#   'Robin Hood: Prince of Thieves',
#   '$165,493,908',
#   '1991'],
#  'Knives Out': ['/title/tt8946378/?ref_=bo_cso_table_116',
#   '316',
#   'Knives Out',
#   '$165,363,234',
#   '2019'],
#  'Kung Fu Panda 2': ['/title/tt1302011/?ref_=bo_cso_table_117',
#   '317',
#   'Kung Fu Panda 2',
#   '$165,249,063',
#   '2011'],
#  'Hannibal': ['/title/tt0212985/?ref_=bo_cso_table_118',
#   '318',
#   'Hannibal',
#   '$165,092,268',
#   '2001'],
#  'Catch Me If You Can': ['/title/tt0264464/?ref_=bo_cso_table_119',
#   '319',
#   'Catch Me If You Can',
#   '$164,615,351',
#   '2002'],
#  'The Proposal': ['/title/tt1041829/?ref_=bo_cso_table_120',
#   '320',
#   'The Proposal',
#   '$163,958,031',
#   '2009'],
#  'The Pursuit of Happyness': ['/title/tt0454921/?ref_=bo_cso_table_121',
#   '321',
#   'The Pursuit of Happyness',
#   '$163,566,459',
#   '2006'],
#  'Big Daddy': ['/title/tt0142342/?ref_=bo_cso_table_122',
#   '322',
#   'Big Daddy',
#   '$163,479,795',
#   '1999'],
#  'Clash of the Titans': ['/title/tt0800320/?ref_=bo_cso_table_123',
#   '323',
#   'Clash of the Titans',
#   '$163,214,888',
#   '2010'],
#  'The SpongeBob Movie: Sponge Out of Water': ['/title/tt2279373/?ref_=bo_cso_table_124',
#   '324',
#   'The SpongeBob Movie: Sponge Out of Water',
#   '$162,994,032',
#   '2015'],
#  'Batman Returns': ['/title/tt0103776/?ref_=bo_cso_table_125',
#   '325',
#   'Batman Returns',
#   '$162,902,340',
#   '1992'],
#  'Django Unchained': ['/title/tt1853728/?ref_=bo_cso_table_126',
#   '326',
#   'Django Unchained',
#   '$162,805,434',
#   '2012'],
#  "A Bug's Life": ['/title/tt0120623/?ref_=bo_cso_table_127',
#   '327',
#   "A Bug's Life",
#   '$162,798,565',
#   '1998'],
#  'Jason Bourne': ['/title/tt4196776/?ref_=bo_cso_table_128',
#   '328',
#   'Jason Bourne',
#   '$162,434,410',
#   '2016'],
#  'Grown Ups': ['/title/tt1375670/?ref_=bo_cso_table_129',
#   '329',
#   'Grown Ups',
#   '$162,001,186',
#   '2010'],
#  'The Waterboy': ['/title/tt0120484/?ref_=bo_cso_table_130',
#   '330',
#   'The Waterboy',
#   '$161,491,646',
#   '1998'],
#  'Ice Age: Continental Drift': ['/title/tt1667889/?ref_=bo_cso_table_131',
#   '331',
#   'Ice Age: Continental Drift',
#   '$161,321,843',
#   '2012'],
#  'Straight Outta Compton': ['/title/tt1398426/?ref_=bo_cso_table_132',
#   '332',
#   'Straight Outta Compton',
#   '$161,197,785',
#   '2015'],
#  'Die Another Day': ['/title/tt0246460/?ref_=bo_cso_table_133',
#   '333',
#   'Die Another Day',
#   '$160,942,139',
#   '2002'],
#  'Shark Tale': ['/title/tt0307453/?ref_=bo_cso_table_134',
#   '334',
#   'Shark Tale',
#   '$160,861,908',
#   '2004'],
#  'How to Train Your Dragon: The Hidden World': ['/title/tt2386490/?ref_=bo_cso_table_135',
#   '335',
#   'How to Train Your Dragon: The Hidden World',
#   '$160,799,505',
#   '2019'],
#  'The Heat': ['/title/tt2404463/?ref_=bo_cso_table_136',
#   '336',
#   'The Heat',
#   '$159,582,188',
#   '2013'],
#  'Fantastic Beasts: The Crimes of Grindelwald': ['/title/tt4123430/?ref_=bo_cso_table_137',
#   '337',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   '$159,555,901',
#   '2018'],
#  'Halloween': ['/title/tt1502407/?ref_=bo_cso_table_138',
#   '338',
#   'Halloween',
#   '$159,342,015',
#   '2018'],
#  'The Sound of Music': ['/title/tt0059742/?ref_=bo_cso_table_139',
#   '339',
#   'The Sound of Music',
#   '$159,287,539',
#   '1965'],
#  '1917': ['/title/tt8579674/?ref_=bo_cso_table_140',
#   '340',
#   '1917',
#   '$159,227,644',
#   '2019'],
#  'The Secret Life of Pets 2': ['/title/tt5113040/?ref_=bo_cso_table_141',
#   '341',
#   'The Secret Life of Pets 2',
#   '$158,874,395',
#   '2019'],
#  'Star Trek Beyond': ['/title/tt2660888/?ref_=bo_cso_table_142',
#   '342',
#   'Star Trek Beyond',
#   '$158,848,340',
#   '2016'],
#  'The Firm': ['/title/tt0106918/?ref_=bo_cso_table_143',
#   '343',
#   'The Firm',
#   '$158,348,367',
#   '1993'],
#  'The Longest Yard': ['/title/tt0398165/?ref_=bo_cso_table_144',
#   '344',
#   'The Longest Yard',
#   '$158,119,460',
#   '2005'],
#  'X-Men': ['/title/tt0120903/?ref_=bo_cso_table_145',
#   '345',
#   'X-Men',
#   '$157,299,718',
#   '2000'],
#  'Scary Movie': ['/title/tt0175142/?ref_=bo_cso_table_146',
#   '346',
#   'Scary Movie',
#   '$157,019,771',
#   '2000'],
#  'Fatal Attraction': ['/title/tt0093010/?ref_=bo_cso_table_147',
#   '347',
#   'Fatal Attraction',
#   '$156,645,693',
#   '1987'],
#  'Who Framed Roger Rabbit': ['/title/tt0096438/?ref_=bo_cso_table_148',
#   '348',
#   'Who Framed Roger Rabbit',
#   '$156,452,370',
#   '1988'],
#  'The Sting': ['/title/tt0070735/?ref_=bo_cso_table_149',
#   '349',
#   'The Sting',
#   '$156,000,000',
#   '1973'],
#  'What Lies Beneath': ['/title/tt0161081/?ref_=bo_cso_table_150',
#   '350',
#   'What Lies Beneath',
#   '$155,464,351',
#   '2000'],
#  'X-Men: Apocalypse': ['/title/tt3385516/?ref_=bo_cso_table_151',
#   '351',
#   'X-Men: Apocalypse',
#   '$155,442,489',
#   '2016'],
#  'The Mummy': ['/title/tt0120616/?ref_=bo_cso_table_152',
#   '352',
#   'The Mummy',
#   '$155,385,488',
#   '1999'],
#  'Snow White and the Huntsman': ['/title/tt1735898/?ref_=bo_cso_table_153',
#   '353',
#   'Snow White and the Huntsman',
#   '$155,332,381',
#   '2012'],
#  'San Andreas': ['/title/tt2126355/?ref_=bo_cso_table_154',
#   '354',
#   'San Andreas',
#   '$155,190,832',
#   '2015'],
#  'Fast & Furious': ['/title/tt1013752/?ref_=bo_cso_table_155',
#   '355',
#   'Fast & Furious',
#   '$155,064,265',
#   '2009'],
#  'Over the Hedge': ['/title/tt0327084/?ref_=bo_cso_table_156',
#   '356',
#   'Over the Hedge',
#   '$155,019,340',
#   '2006'],
#  'Fantastic Four': ['/title/tt0120667/?ref_=bo_cso_table_157',
#   '357',
#   'Fantastic Four',
#   '$154,696,080',
#   '2005'],
#  'Horton Hears a Who!': ['/title/tt0451079/?ref_=bo_cso_table_158',
#   '358',
#   'Horton Hears a Who!',
#   '$154,529,439',
#   '2008'],
#  'Mad Max: Fury Road': ['/title/tt1392190/?ref_=bo_cso_table_159',
#   '359',
#   'Mad Max: Fury Road',
#   '$154,058,340',
#   '2015'],
#  'Jerry Maguire': ['/title/tt0116695/?ref_=bo_cso_table_160',
#   '360',
#   'Jerry Maguire',
#   '$153,952,592',
#   '1996'],
#  'Trolls': ['/title/tt1679335/?ref_=bo_cso_table_161',
#   '361',
#   'Trolls',
#   '$153,707,064',
#   '2016'],
#  'Beverly Hills Cop II': ['/title/tt0092644/?ref_=bo_cso_table_162',
#   '362',
#   'Beverly Hills Cop II',
#   '$153,665,036',
#   '1987'],
#  'Gremlins': ['/title/tt0087363/?ref_=bo_cso_table_163',
#   '363',
#   'Gremlins',
#   '$153,378,102',
#   '1984'],
#  'Scooby-Doo': ['/title/tt0267913/?ref_=bo_cso_table_164',
#   '364',
#   'Scooby-Doo',
#   '$153,294,164',
#   '2002'],
#  'Cars 3': ['/title/tt3606752/?ref_=bo_cso_table_165',
#   '365',
#   'Cars 3',
#   '$152,901,115',
#   '2017'],
#  'Sex and the City': ['/title/tt1000774/?ref_=bo_cso_table_166',
#   '366',
#   'Sex and the City',
#   '$152,647,258',
#   '2008'],
#  'Runaway Bride': ['/title/tt0163187/?ref_=bo_cso_table_167',
#   '367',
#   'Runaway Bride',
#   '$152,257,509',
#   '1999'],
#  'La La Land': ['/title/tt3783958/?ref_=bo_cso_table_168',
#   '368',
#   'La La Land',
#   '$151,101,803',
#   '2016'],
#  'Divergent': ['/title/tt1840309/?ref_=bo_cso_table_169',
#   '369',
#   'Divergent',
#   '$150,947,895',
#   '2014'],
#  'Rambo: First Blood Part II': ['/title/tt0089880/?ref_=bo_cso_table_170',
#   '370',
#   'Rambo: First Blood Part II',
#   '$150,415,432',
#   '1985'],
#  "We're the Millers": ['/title/tt1723121/?ref_=bo_cso_table_171',
#   '371',
#   "We're the Millers",
#   '$150,394,119',
#   '2013'],
#  'Terminator 3: Rise of the Machines': ['/title/tt0181852/?ref_=bo_cso_table_172',
#   '372',
#   'Terminator 3: Rise of the Machines',
#   '$150,371,112',
#   '2003'],
#  "Daddy's Home": ['/title/tt1528854/?ref_=bo_cso_table_173',
#   '373',
#   "Daddy's Home",
#   '$150,357,137',
#   '2015'],
#  'G.I. Joe: The Rise of Cobra': ['/title/tt1046173/?ref_=bo_cso_table_174',
#   '374',
#   'G.I. Joe: The Rise of Cobra',
#   '$150,201,498',
#   '2009'],
#  'Neighbors': ['/title/tt2004420/?ref_=bo_cso_table_175',
#   '375',
#   'Neighbors',
#   '$150,157,400',
#   '2014'],
#  'American Hustle': ['/title/tt1800241/?ref_=bo_cso_table_176',
#   '376',
#   'American Hustle',
#   '$150,117,807',
#   '2013'],
#  'Puss in Boots': ['/title/tt0448694/?ref_=bo_cso_table_177',
#   '377',
#   'Puss in Boots',
#   '$149,260,504',
#   '2011'],
#  'Sonic the Hedgehog': ['/title/tt3794354/?ref_=bo_cso_table_178',
#   '378',
#   'Sonic the Hedgehog',
#   '$148,974,665',
#   '2020'],
#  'Les Misérables': ['/title/tt1707386/?ref_=bo_cso_table_179',
#   '379',
#   'Les Misérables',
#   '$148,809,770',
#   '2012'],
#  'Knocked Up': ['/title/tt0478311/?ref_=bo_cso_table_180',
#   '380',
#   'Knocked Up',
#   '$148,768,917',
#   '2007'],
#  'As Good as It Gets': ['/title/tt0119822/?ref_=bo_cso_table_181',
#   '381',
#   'As Good as It Gets',
#   '$148,478,011',
#   '1997'],
#  'Little Fockers': ['/title/tt0970866/?ref_=bo_cso_table_182',
#   '382',
#   'Little Fockers',
#   '$148,438,600',
#   '2010'],
#  'Megamind': ['/title/tt1001526/?ref_=bo_cso_table_183',
#   '383',
#   'Megamind',
#   '$148,415,853',
#   '2010'],
#  'Hotel Transylvania': ['/title/tt0837562/?ref_=bo_cso_table_184',
#   '384',
#   'Hotel Transylvania',
#   '$148,313,048',
#   '2012'],
#  'Talladega Nights: The Ballad of Ricky Bobby': ['/title/tt0415306/?ref_=bo_cso_table_185',
#   '385',
#   'Talladega Nights: The Ballad of Ricky Bobby',
#   '$148,213,377',
#   '2006'],
#  'Gran Torino': ['/title/tt1205489/?ref_=bo_cso_table_186',
#   '386',
#   'Gran Torino',
#   '$148,095,302',
#   '2008'],
#  'Lethal Weapon 2': ['/title/tt0097733/?ref_=bo_cso_table_187',
#   '387',
#   'Lethal Weapon 2',
#   '$147,253,986',
#   '1989'],
#  'War for the Planet of the Apes': ['/title/tt3450958/?ref_=bo_cso_table_188',
#   '388',
#   'War for the Planet of the Apes',
#   '$146,880,162',
#   '2017'],
#  'X-Men: First Class': ['/title/tt1270798/?ref_=bo_cso_table_189',
#   '389',
#   'X-Men: First Class',
#   '$146,408,305',
#   '2011'],
#  'Paul Blart: Mall Cop': ['/title/tt1114740/?ref_=bo_cso_table_190',
#   '390',
#   'Paul Blart: Mall Cop',
#   '$146,336,178',
#   '2009'],
#  'True Lies': ['/title/tt0111503/?ref_=bo_cso_table_191',
#   '391',
#   'True Lies',
#   '$146,282,411',
#   '1994'],
#  'Lilo & Stitch': ['/title/tt0275847/?ref_=bo_cso_table_192',
#   '392',
#   'Lilo & Stitch',
#   '$145,794,338',
#   '2002'],
#  'The Santa Clause': ['/title/tt0111070/?ref_=bo_cso_table_193',
#   '393',
#   'The Santa Clause',
#   '$145,539,357',
#   '1994'],
#  'The Meg': ['/title/tt4779682/?ref_=bo_cso_table_194',
#   '394',
#   'The Meg',
#   '$145,443,742',
#   '2018'],
#  'American Pie 2': ['/title/tt0252866/?ref_=bo_cso_table_195',
#   '395',
#   'American Pie 2',
#   '$145,103,595',
#   '2001'],
#  'Taken': ['/title/tt0936501/?ref_=bo_cso_table_196',
#   '396',
#   'Taken',
#   '$145,000,989',
#   '2009'],
#  'One Hundred and One Dalmatians': ['/title/tt0055254/?ref_=bo_cso_table_197',
#   '397',
#   'One Hundred and One Dalmatians',
#   '$144,880,014',
#   '1961'],
#  'The Great Gatsby': ['/title/tt1343092/?ref_=bo_cso_table_198',
#   '398',
#   'The Great Gatsby',
#   '$144,840,419',
#   '2013'],
#  'I, Robot': ['/title/tt0343818/?ref_=bo_cso_table_199',
#   '399',
#   'I, Robot',
#   '$144,801,023',
#   '2004'],
#  'Lethal Weapon 3': ['/title/tt0104714/?ref_=bo_cso_table_200',
#   '400',
#   'Lethal Weapon 3',
#   '$144,731,527',
#   '1992']}

# %%
top_movies = pd.DataFrame(movies).T  #transpose
top_movies.columns = ['link_stub', 'rank_all_movies','title', 
                    'lifetime_gross', 'year']

top_movies.head()
# Out:
#                                                                link_stub  \
# Batman Begins                      /title/tt0372784/?ref_=bo_cso_table_1
# Charlie and the Chocolate Factory  /title/tt0367594/?ref_=bo_cso_table_2
# Ratatouille                        /title/tt0382932/?ref_=bo_cso_table_3
# Thor: The Dark World               /title/tt1981115/?ref_=bo_cso_table_4
# Bad Boys for Life                  /title/tt1502397/?ref_=bo_cso_table_5
#
#                                   rank_all_movies  \
# Batman Begins                                 201
# Charlie and the Chocolate Factory             202
# Ratatouille                                   203
# Thor: The Dark World                          204
# Bad Boys for Life                             205
#
#                                                                title  \
# Batman Begins                                          Batman Begins
# Charlie and the Chocolate Factory  Charlie and the Chocolate Factory
# Ratatouille                                              Ratatouille
# Thor: The Dark World                            Thor: The Dark World
# Bad Boys for Life                                  Bad Boys for Life
#
#                                   lifetime_gross  year
# Batman Begins                       $206,852,432  2005
# Charlie and the Chocolate Factory   $206,459,076  2005
# Ratatouille                         $206,445,654  2007
# Thor: The Dark World                $206,362,140  2013
# Bad Boys for Life                   $206,305,244  2020

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
        # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
import dateutil.parser

def money_to_int(moneystring):
    if moneystring:
        moneystring = moneystring.replace('$', '').replace(',', '')
        return int(moneystring)
    else:
        pass

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

def clean_genres(genre_list):
    genres = [item.strip() for item in genre_list if item.strip()]
    return genres

# %%
def clean_sales(lst):
    
    '''Clean the summary domestic/international summary table
    
    Takes the raw list of money strings and converts each item to int
    '''
    
    sale_list = [item.text for item in lst]
    
    sale_list = [money_to_int(item) for item in sale_list]
   
    return sale_list


def clean_regions(lst):
    
    '''Clean the summary domestic/international summary table
    
    Takes raw list of region string, cleans, and puts back into list
    '''
    
    region_list = [item.text for item in lst]
    region_list = [item.strip() for item in region_list if item.split()]
    region_list = [item.split('(')[0].strip() for item in region_list]
    
    return region_list

# %%
def get_movie_dict(link):
    '''
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic distributor
        - budget
        - domestic gross
        - earliest release
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['movie_title', 'domestic_distributor','budget', 'domestic_opening_sales',
               'earliest_release',
               'rating', 'runtime_minutes','genres','summary_sales','crew_list','cast_list']
    
    #Get title
    title_string = soup.find('title').text
    if title_string:
        movie_title = title_string.split('-')[0].strip()
    else:
        pass
    
    #Get domestic distributor
    domdist_regex = re.compile('Domestic Distributor')
    if domdist_regex:
        try:
            domdist_string = soup.find(text=domdist_regex).findNext().text
            try:
                domestic_dist = domdist_string.split('See')[0].strip()
            except:
                domestic_dist = None
            #return domestic_dist
        except:
            domestic_dist = None
    
    # Domestic distributor
    if domestic_dist != None:
        domestic_dist = get_movie_value(soup,'Domestic Distributor').split('See')[0].strip()
    else:
        pass

    # Budget
    raw_budget = get_movie_value(soup,'Budget')
    budget = money_to_int(raw_budget)

    # Domestic opening sales
    raw_domestic_opening = get_movie_value(soup,'Domestic Opening')
    domestic_opening_sales = money_to_int(raw_domestic_opening)

    #Earliest release date (raw)
    earliest_release_str = get_movie_value(soup,'Earliest Release').split('\n')[0].strip()
    earliest_release = datetime.strptime(earliest_release_str, '%B %d, %Y')
    earliest_release.strftime('%Y-%m-%d')

    #Rating
    rating = get_movie_value(soup,'MPAA')

    # Runtime
    raw_runtime = get_movie_value(soup,'Running Time')
    runtime_minutes = runtime_to_minutes(raw_runtime)

    #Genres
    raw_genres = get_movie_value(soup, 'Genres').split('\n')
    genres = clean_genres(raw_genres)
    
    #Sales list (domestic, international, worldwide)
    raw_sales_list = soup.find(class_='mojo-performance-summary-table').find_all('span', class_='money')[0:]
    sales_list = clean_sales(raw_sales_list)
    
    # Regions list
    raw_sales_regions = soup.find(class_='mojo-performance-summary-table').find_all('span', class_='a-size-small')[0:]
    regions_list = clean_regions(raw_sales_regions)
    
    # Zip region and associated sales per region - believe should solve for any missing regions
    summary_sales = [list(i) for i in zip(regions_list,sales_list)]
    
    #Find link for cast and crew
    credits = soup.find('a', class_='a-size-base a-link-normal mojo-navigation-tab',href=True)
    credits_href = str(credits.get('href'))
    credits_url = base_url + credits_href
    
    #Refer to cast and crew page
    response1 = requests.get(credits_url,headers = user_agent)
    page1 = response1.text
    soup1 = BeautifulSoup(page1, 'lxml')
    
    #Find crew table, cast table
    table_crew = soup1.find('table',id='principalCrew').find_all('td')
    table_cast = soup1.find('table',id='principalCast').find_all('td')
    
    #clean the tables
    def clean_credits(table1):
        lst1 = [item.text for item in table1]
        lst2 = [item.split('\n')[0].strip() for item in lst1]
        lst2 = [item for item in lst2[::2]]

        return lst2

    crew_list = clean_credits(table_crew)
    cast_list = clean_credits(table_cast)
    
    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [movie_title, domestic_dist, budget,domestic_opening_sales,
                                    earliest_release,
                                    rating, runtime_minutes,genres,summary_sales,crew_list,cast_list]))

    return movie_dict

# %%
top_movies_page_info_list = []

for link in top_movies.link_stub:
    top_movies_page_info_list.append(get_movie_dict(link))
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     158         try:
# --> 159             conn = connection.create_connection(
#     160                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83     if err is not None:
# ---> 84         raise err
#      85
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      73                 sock.bind(source_address)
# ---> 74             sock.connect(sa)
#      75             return sock
#
# TimeoutError: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         try:
# --> 381             self._validate_conn(conn)
#     382         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     977         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 978             conn.connect()
#     979
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     308         # Add certificate verification
# --> 309         conn = self._new_conn()
#     310         hostname = self.host
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     170         except SocketError as e:
# --> 171             raise NewConnectionError(
#     172                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7fe6a006e400>: Failed to establish a new connection: [Errno 60] Operation timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     725
# --> 726             retries = retries.increment(
#     727                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     445         if new_retry.is_exhausted():
# --> 446             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     447
#
# MaxRetryError: HTTPSConnectionPool(host='www.boxofficemojo.com', port=443): Max retries exceeded with url: /title/tt0372784/credits/?ref_=bo_tt_tab (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6a006e400>: Failed to establish a new connection: [Errno 60] Operation timed out'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-60-20ba4de6f2c3> in <module>
#       2
#       3 for link in top_movies.link_stub:
# ----> 4     top_movies_page_info_list.append(get_movie_dict(link))
#
# <ipython-input-59-ab9510916329> in get_movie_dict(link)
#      96
#      97     #Refer to cast and crew page
# ---> 98     response1 = requests.get(credits_url,headers = user_agent)
#      99     page1 = response1.text
#     100     soup1 = BeautifulSoup(page1, 'lxml')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='www.boxofficemojo.com', port=443): Max retries exceeded with url: /title/tt0372784/credits/?ref_=bo_tt_tab (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fe6a006e400>: Failed to establish a new connection: [Errno 60] Operation timed out'))

# %%
top_movies_page_info = pd.DataFrame(top_movies_page_info_list)  #convert list of dict to df
top_movies_page_info.set_index('movie_title', inplace=True)
top_movies_page_info
# Out:
#                                                   domestic_distributor  \
# movie_title
# Batman Begins                                             Warner Bros.
# Charlie and the Chocolate Factory                         Warner Bros.
# Ratatouille                        Walt Disney Studios Motion Pictures
# Thor: The Dark World               Walt Disney Studios Motion Pictures
# Bad Boys for Life                    Sony Pictures Entertainment (SPE)
# ...                                                                ...
# Taken                                            Twentieth Century Fox
# One Hundred and One Dalmatians     Walt Disney Studios Motion Pictures
# The Great Gatsby                                          Warner Bros.
# I, Robot                                         Twentieth Century Fox
# Lethal Weapon 3                                           Warner Bros.
#
#                                         budget  domestic_opening_sales  \
# movie_title
# Batman Begins                      150000000.0              48745440.0
# Charlie and the Chocolate Factory  150000000.0              56178450.0
# Ratatouille                        150000000.0              47027395.0
# Thor: The Dark World               170000000.0              85737841.0
# Bad Boys for Life                   90000000.0              62504105.0
# ...                                        ...                     ...
# Taken                               25000000.0              24717037.0
# One Hundred and One Dalmatians             NaN                     NaN
# The Great Gatsby                   105000000.0              50085185.0
# I, Robot                           120000000.0              52179887.0
# Lethal Weapon 3                     35000000.0              33243086.0
#
#                                     earliest_release rating  runtime_minutes  \
# movie_title
# Batman Begins                          June 15, 2005  PG-13            140.0
# Charlie and the Chocolate Factory      July 14, 2005     PG            115.0
# Ratatouille                            June 28, 2007      G            111.0
# Thor: The Dark World                October 30, 2013  PG-13            112.0
# Bad Boys for Life                   January 15, 2020      R            124.0
# ...                                              ...    ...              ...
# Taken                              February 27, 2008  PG-13             90.0
# One Hundred and One Dalmatians      January 25, 1961   None             79.0
# The Great Gatsby                        May 10, 2013  PG-13            143.0
# I, Robot                               July 15, 2004  PG-13            115.0
# Lethal Weapon 3                         May 15, 1992      R            118.0
#
#                                                                             genres  \
# movie_title
# Batman Begins                                                  [Action, Adventure]
# Charlie and the Chocolate Factory    [Adventure, Comedy, Family, Fantasy, Musical]
# Ratatouille                        [Adventure, Animation, Comedy, Family, Fantasy]
# Thor: The Dark World                                  [Action, Adventure, Fantasy]
# Bad Boys for Life                                [Action, Comedy, Crime, Thriller]
# ...                                                                            ...
# Taken                                                           [Action, Thriller]
# One Hundred and One Dalmatians              [Adventure, Animation, Comedy, Family]
# The Great Gatsby                                                  [Drama, Romance]
# I, Robot                                         [Action, Drama, Sci-Fi, Thriller]
# Lethal Weapon 3                                          [Action, Crime, Thriller]
#
#                                                                        summary_sales  \
# movie_title
# Batman Begins                      [[Domestic, 206852432], [International, 166809...
# Charlie and the Chocolate Factory  [[Domestic, 206459076], [International, 268509...
# Ratatouille                        [[Domestic, 206445654], [International, 417280...
# Thor: The Dark World               [[Domestic, 206362140], [International, 438421...
# Bad Boys for Life                  [[Domestic, 206305244], [International, 220200...
# ...                                                                              ...
# Taken                              [[Domestic, 145000989], [International, 818367...
# One Hundred and One Dalmatians     [[Domestic, 144880014], [International, 710000...
# The Great Gatsby                   [[Domestic, 144840419], [International, 208801...
# I, Robot                           [[Domestic, 144801023], [International, 208332...
# Lethal Weapon 3                    [[Domestic, 144731527], [International, 177000...
#
#                                                                            crew_list  \
# movie_title
# Batman Begins                      [Christopher Nolan, Bob Kane, David S. Goyer, ...
# Charlie and the Chocolate Factory  [Tim Burton, Roald Dahl, John August, Brad Gre...
# Ratatouille                        [Brad Bird, Jan Pinkava, Brad Bird, Jan Pinkav...
# Thor: The Dark World               [Alan Taylor, Christopher L. Yost, Christopher...
# Bad Boys for Life                  [Adil El Arbi, Bilall Fallah, Peter Craig, Joe...
# ...                                                                              ...
# Taken                              [Pierre Morel, Luc Besson, Robert Mark Kamen, ...
# One Hundred and One Dalmatians     [Clyde Geronimi, Hamilton Luske, Wolfgang Reit...
# The Great Gatsby                   [Baz Luhrmann, Baz Luhrmann, Craig Pearce, F. ...
# I, Robot                           [Alex Proyas, Jeff Vintar, Akiva Goldsman, Jef...
# Lethal Weapon 3                    [Richard Donner, Jeffrey Boam, Jeffrey Boam, R...
#
#                                                                            cast_list
# movie_title
# Batman Begins                      [Christian Bale, Michael Caine, Ken Watanabe, ...
# Charlie and the Chocolate Factory  [Johnny Depp, Freddie Highmore, David Kelly, H...
# Ratatouille                        [Brad Garrett, Lou Romano, Patton Oswalt, Ian ...
# Thor: The Dark World               [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# Bad Boys for Life                  [Will Smith, Martin Lawrence, Vanessa Hudgens,...
# ...                                                                              ...
# Taken                              [Liam Neeson, Maggie Grace, Famke Janssen, Lel...
# One Hundred and One Dalmatians     [Rod Taylor, Betty Lou Gerson, J. Pat O'Malley...
# The Great Gatsby                   [Leonardo DiCaprio, Carey Mulligan, Joel Edger...
# I, Robot                           [Will Smith, Bridget Moynahan, Bruce Greenwood...
# Lethal Weapon 3                    [Mel Gibson, Danny Glover, Joe Pesci, Rene Russo]
#
# [200 rows x 10 columns]

# %%
top_movies_page_info.to_csv('mojo_pg2.csv')

# %%
top_movies_page_info.head()
# Out:
#                                                   domestic_distributor  \
# movie_title
# Batman Begins                                             Warner Bros.
# Charlie and the Chocolate Factory                         Warner Bros.
# Ratatouille                        Walt Disney Studios Motion Pictures
# Thor: The Dark World               Walt Disney Studios Motion Pictures
# Bad Boys for Life                    Sony Pictures Entertainment (SPE)
#
#                                         budget  domestic_opening_sales  \
# movie_title
# Batman Begins                      150000000.0              48745440.0
# Charlie and the Chocolate Factory  150000000.0              56178450.0
# Ratatouille                        150000000.0              47027395.0
# Thor: The Dark World               170000000.0              85737841.0
# Bad Boys for Life                   90000000.0              62504105.0
#
#                                    earliest_release rating  runtime_minutes  \
# movie_title
# Batman Begins                         June 15, 2005  PG-13            140.0
# Charlie and the Chocolate Factory     July 14, 2005     PG            115.0
# Ratatouille                           June 28, 2007      G            111.0
# Thor: The Dark World               October 30, 2013  PG-13            112.0
# Bad Boys for Life                  January 15, 2020      R            124.0
#
#                                                                             genres  \
# movie_title
# Batman Begins                                                  [Action, Adventure]
# Charlie and the Chocolate Factory    [Adventure, Comedy, Family, Fantasy, Musical]
# Ratatouille                        [Adventure, Animation, Comedy, Family, Fantasy]
# Thor: The Dark World                                  [Action, Adventure, Fantasy]
# Bad Boys for Life                                [Action, Comedy, Crime, Thriller]
#
#                                                                        summary_sales  \
# movie_title
# Batman Begins                      [[Domestic, 206852432], [International, 166809...
# Charlie and the Chocolate Factory  [[Domestic, 206459076], [International, 268509...
# Ratatouille                        [[Domestic, 206445654], [International, 417280...
# Thor: The Dark World               [[Domestic, 206362140], [International, 438421...
# Bad Boys for Life                  [[Domestic, 206305244], [International, 220200...
#
#                                                                            crew_list  \
# movie_title
# Batman Begins                      [Christopher Nolan, Bob Kane, David S. Goyer, ...
# Charlie and the Chocolate Factory  [Tim Burton, Roald Dahl, John August, Brad Gre...
# Ratatouille                        [Brad Bird, Jan Pinkava, Brad Bird, Jan Pinkav...
# Thor: The Dark World               [Alan Taylor, Christopher L. Yost, Christopher...
# Bad Boys for Life                  [Adil El Arbi, Bilall Fallah, Peter Craig, Joe...
#
#                                                                            cast_list
# movie_title
# Batman Begins                      [Christian Bale, Michael Caine, Ken Watanabe, ...
# Charlie and the Chocolate Factory  [Johnny Depp, Freddie Highmore, David Kelly, H...
# Ratatouille                        [Brad Garrett, Lou Romano, Patton Oswalt, Ian ...
# Thor: The Dark World               [Chris Hemsworth, Natalie Portman, Tom Hiddles...
# Bad Boys for Life                  [Will Smith, Martin Lawrence, Vanessa Hudgens,...
