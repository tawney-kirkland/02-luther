# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
from datetime import datetime

# %%
url = 'https://www.boxofficemojo.com/chart/top_lifetime_gross/?offset=800'

user_agent = {'User-agent': 'Mozilla/5.0'}

response  = requests.get(url, headers = user_agent)

page = response.text

soup = BeautifulSoup(page,"lxml")

# %%
table = soup.find('table')
table
# Out:
# <table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Lifetime Gross">Lifetime Gross</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">801</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0252076/?ref_=bo_cso_table_1">Maid in Manhattan</a></td><td class="a-text-right mojo-field-type-money">$94,011,225</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2002/?ref_=bo_cso_table_1">2002</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">802</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1001508/?ref_=bo_cso_table_2">He's Just Not That Into You</a></td><td class="a-text-right mojo-field-type-money">$93,953,653</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2009/?ref_=bo_cso_table_2">2009</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">803</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0311113/?ref_=bo_cso_table_3">Master and Commander: The Far Side of the World</a></td><td class="a-text-right mojo-field-type-money">$93,927,920</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2003/?ref_=bo_cso_table_3">2003</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">804</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1907668/?ref_=bo_cso_table_4">Flight</a></td><td class="a-text-right mojo-field-type-money">$93,772,375</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2012/?ref_=bo_cso_table_4">2012</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">805</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0964517/?ref_=bo_cso_table_5">The Fighter</a></td><td class="a-text-right mojo-field-type-money">$93,617,009</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2010/?ref_=bo_cso_table_5">2010</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">806</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0265029/?ref_=bo_cso_table_6">America's Sweethearts</a></td><td class="a-text-right mojo-field-type-money">$93,607,673</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2001/?ref_=bo_cso_table_6">2001</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">807</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0048280/?ref_=bo_cso_table_7">Lady and the Tramp</a></td><td class="a-text-right mojo-field-type-money">$93,602,326</td><td class="a-text-left mojo-field-type-year">1955</td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">808</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0825232/?ref_=bo_cso_table_8">The Bucket List</a></td><td class="a-text-right mojo-field-type-money">$93,466,502</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2007/?ref_=bo_cso_table_8">2007</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">809</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1964418/?ref_=bo_cso_table_9">Tomorrowland</a></td><td class="a-text-right mojo-field-type-money">$93,436,322</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2015/?ref_=bo_cso_table_9">2015</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">810</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2404435/?ref_=bo_cso_table_10">The Magnificent Seven< ...

# %%
rows = [row for row in table.find_all('tr')]

# %%
movies = {}

for row in rows[1:]:
    items = row.find_all('td')
    link = row.find('a')
    title, url = link.text, link['href']
    movies[title] = [url] + [i.text for i in items]
    
movies
# Out:
# {'Maid in Manhattan': ['/title/tt0252076/?ref_=bo_cso_table_1',
#   '801',
#   'Maid in Manhattan',
#   '$94,011,225',
#   '2002'],
#  "He's Just Not That Into You": ['/title/tt1001508/?ref_=bo_cso_table_2',
#   '802',
#   "He's Just Not That Into You",
#   '$93,953,653',
#   '2009'],
#  'Master and Commander: The Far Side of the World': ['/title/tt0311113/?ref_=bo_cso_table_3',
#   '803',
#   'Master and Commander: The Far Side of the World',
#   '$93,927,920',
#   '2003'],
#  'Flight': ['/title/tt1907668/?ref_=bo_cso_table_4',
#   '804',
#   'Flight',
#   '$93,772,375',
#   '2012'],
#  'The Fighter': ['/title/tt0964517/?ref_=bo_cso_table_5',
#   '805',
#   'The Fighter',
#   '$93,617,009',
#   '2010'],
#  "America's Sweethearts": ['/title/tt0265029/?ref_=bo_cso_table_6',
#   '806',
#   "America's Sweethearts",
#   '$93,607,673',
#   '2001'],
#  'Lady and the Tramp': ['/title/tt0048280/?ref_=bo_cso_table_7',
#   '807',
#   'Lady and the Tramp',
#   '$93,602,326',
#   '1955'],
#  'The Bucket List': ['/title/tt0825232/?ref_=bo_cso_table_8',
#   '808',
#   'The Bucket List',
#   '$93,466,502',
#   '2007'],
#  'Tomorrowland': ['/title/tt1964418/?ref_=bo_cso_table_9',
#   '809',
#   'Tomorrowland',
#   '$93,436,322',
#   '2015'],
#  'The Magnificent Seven': ['/title/tt2404435/?ref_=bo_cso_table_10',
#   '810',
#   'The Magnificent Seven',
#   '$93,432,655',
#   '2016'],
#  'Cats & Dogs': ['/title/tt0239395/?ref_=bo_cso_table_11',
#   '811',
#   'Cats & Dogs',
#   '$93,385,515',
#   '2001'],
#  'Space Station 3D': ['/title/tt0290296/?ref_=bo_cso_table_12',
#   '812',
#   'Space Station 3D',
#   '$93,383,953',
#   '2002'],
#  'Two Weeks Notice': ['/title/tt0313737/?ref_=bo_cso_table_13',
#   '813',
#   'Two Weeks Notice',
#   '$93,354,851',
#   '2002'],
#  'Red Dragon': ['/title/tt0289765/?ref_=bo_cso_table_14',
#   '814',
#   'Red Dragon',
#   '$93,149,898',
#   '2002'],
#  'Cinderella': ['/title/tt0042332/?ref_=bo_cso_table_15',
#   '815',
#   'Cinderella',
#   '$93,141,149',
#   '1950'],
#  'When Harry Met Sally...': ['/title/tt0098635/?ref_=bo_cso_table_16',
#   '816',
#   'When Harry Met Sally...',
#   '$93,075,866',
#   '1989'],
#  'Elysium': ['/title/tt1535108/?ref_=bo_cso_table_17',
#   '817',
#   'Elysium',
#   '$93,050,117',
#   '2013'],
#  'Flubber': ['/title/tt0119137/?ref_=bo_cso_table_18',
#   '818',
#   'Flubber',
#   '$92,977,226',
#   '1997'],
#  'Flashdance': ['/title/tt0085549/?ref_=bo_cso_table_19',
#   '819',
#   'Flashdance',
#   '$92,921,203',
#   '1983'],
#  'The Town': ['/title/tt0840361/?ref_=bo_cso_table_20',
#   '820',
#   'The Town',
#   '$92,186,262',
#   '2010'],
#  'Non-Stop': ['/title/tt2024469/?ref_=bo_cso_table_21',
#   '821',
#   'Non-Stop',
#   '$92,168,600',
#   '2014'],
#  'The Client': ['/title/tt0109446/?ref_=bo_cso_table_22',
#   '822',
#   'The Client',
#   '$92,115,211',
#   '1994'],
#  'Blade Runner 2049': ['/title/tt1856101/?ref_=bo_cso_table_23',
#   '823',
#   'Blade Runner 2049',
#   '$92,054,159',
#   '2017'],
#  'John Wick: Chapter 2': ['/title/tt4425200/?ref_=bo_cso_table_24',
#   '824',
#   'John Wick: Chapter 2',
#   '$92,029,184',
#   '2017'],
#  'Star Trek: First Contact': ['/title/tt0117731/?ref_=bo_cso_table_25',
#   '825',
#   'Star Trek: First Contact',
#   '$92,027,888',
#   '1996'],
#  'Think Like a Man': ['/title/tt1621045/?ref_=bo_cso_table_26',
#   '826',
#   'Think Like a Man',
#   '$91,547,205',
#   '2012'],
#  'Kindergarten Cop': ['/title/tt0099938/?ref_=bo_cso_table_27',
#   '827',
#   'Kindergarten Cop',
#   '$91,457,688',
#   '1990'],
#  'Heaven Is for Real': ['/title/tt1929263/?ref_=bo_cso_table_28',
#   '828',
#   'Heaven Is for Real',
#   '$91,443,253',
#   '2014'],
#  'The Haunting': ['/title/tt0171363/?ref_=bo_cso_table_29',
#   '829',
#   'The Haunting',
#   '$91,411,151',
#   '1999'],
#  'Crimson Tide': ['/title/tt0112740/?ref_=bo_cso_table_30',
#   '830',
#   'Crimson Tide',
#   '$91,387,195',
#   '1995'],
#  'Back to School': ['/title/tt0090685/?ref_=bo_cso_table_31',
#   '831',
#   'Back to School',
#   '$91,258,000',
#   '1986'],
#  'Ride Along 2': ['/title/tt2869728/?ref_=bo_cso_table_32',
#   '832',
#   'Ride Along 2',
#   '$91,221,830',
#   '2016'],
#  'Stepmom': ['/title/tt0120686/?ref_=bo_cso_table_33',
#   '833',
#   'Stepmom',
#   '$91,137,662',
#   '1998'],
#  'The Imitation Game': ['/title/tt2084970/?ref_=bo_cso_table_34',
#   '834',
#   'The Imitation Game',
#   '$91,125,683',
#   '2014'],
#  'The Karate Kid': ['/title/tt0087538/?ref_=bo_cso_table_35',
#   '835',
#   'The Karate Kid',
#   '$91,077,276',
#   '1984'],
#  'Save the Last Dance': ['/title/tt0206275/?ref_=bo_cso_table_36',
#   '836',
#   'Save the Last Dance',
#   '$91,057,006',
#   '2001'],
#  'The Scorpion King': ['/title/tt0277296/?ref_=bo_cso_table_37',
#   '837',
#   'The Scorpion King',
#   '$91,047,077',
#   '2002'],
#  'Prince of Persia: The Sands of Time': ['/title/tt0473075/?ref_=bo_cso_table_38',
#   '838',
#   'Prince of Persia: The Sands of Time',
#   '$90,759,676',
#   '2010'],
#  'Antz': ['/title/tt0120587/?ref_=bo_cso_table_39',
#   '839',
#   'Antz',
#   '$90,757,863',
#   '1998'],
#  'Scary Movie 4': ['/title/tt0362120/?ref_=bo_cso_table_40',
#   '840',
#   'Scary Movie 4',
#   '$90,710,620',
#   '2006'],
#  'The Game Plan': ['/title/tt0492956/?ref_=bo_cso_table_41',
#   '841',
#   'The Game Plan',
#   '$90,648,202',
#   '2007'],
#  'Me, Myself & Irene': ['/title/tt0183505/?ref_=bo_cso_table_42',
#   '842',
#   'Me, Myself & Irene',
#   '$90,570,999',
#   '2000'],
#  'High School Musical 3': ['/title/tt0962726/?ref_=bo_cso_table_43',
#   '843',
#   'High School Musical 3',
#   '$90,559,416',
#   '2008'],
#  'Madea Goes to Jail': ['/title/tt1142800/?ref_=bo_cso_table_44',
#   '844',
#   'Madea Goes to Jail',
#   '$90,508,336',
#   '2009'],
#  'Space Cowboys': ['/title/tt0186566/?ref_=bo_cso_table_45',
#   '845',
#   'Space Cowboys',
#   '$90,464,773',
#   '2000'],
#  'Space Jam': ['/title/tt0117705/?ref_=bo_cso_table_46',
#   '846',
#   'Space Jam',
#   '$90,418,342',
#   '1996'],
#  'Get Hard': ['/title/tt2561572/?ref_=bo_cso_table_47',
#   '847',
#   'Get Hard',
#   '$90,411,453',
#   '2015'],
#  'Trading Places': ['/title/tt0086465/?ref_=bo_cso_table_48',
#   '848',
#   'Trading Places',
#   '$90,404,800',
#   '1983'],
#  'RED': ['/title/tt1245526/?ref_=bo_cso_table_49',
#   '849',
#   'RED',
#   '$90,380,162',
#   '2010'],
#  'Planes': ['/title/tt1691917/?ref_=bo_cso_table_50',
#   '850',
#   'Planes',
#   '$90,288,712',
#   '2013'],
#  'Legally Blonde 2': ['/title/tt0333780/?ref_=bo_cso_table_51',
#   '851',
#   'Legally Blonde 2',
#   '$90,186,328',
#   '2003'],
#  'Mystic River': ['/title/tt0327056/?ref_=bo_cso_table_52',
#   '852',
#   'Mystic River',
#   '$90,135,191',
#   '2003'],
#  'Terminator Genisys': ['/title/tt1340138/?ref_=bo_cso_table_53',
#   '853',
#   'Terminator Genisys',
#   '$89,760,956',
#   '2015'],
#  'Flightplan': ['/title/tt0408790/?ref_=bo_cso_table_54',
#   '854',
#   'Flightplan',
#   '$89,707,299',
#   '2005'],
#  'Father of the Bride': ['/title/tt0101862/?ref_=bo_cso_table_55',
#   '855',
#   'Father of the Bride',
#   '$89,325,780',
#   '1991'],
#  "The Emperor's New Groove": ['/title/tt0120917/?ref_=bo_cso_table_56',
#   '856',
#   "The Emperor's New Groove",
#   '$89,302,687',
#   '2000'],
#  'The Lone Ranger': ['/title/tt1210819/?ref_=bo_cso_table_57',
#   '857',
#   'The Lone Ranger',
#   '$89,302,115',
#   '2013'],
#  'Taken 3': ['/title/tt2446042/?ref_=bo_cso_table_58',
#   '858',
#   'Taken 3',
#   '$89,256,424',
#   '2015'],
#  "Don't Breathe": ['/title/tt4160708/?ref_=bo_cso_table_59',
#   '859',
#   "Don't Breathe",
#   '$89,217,875',
#   '2016'],
#  'Scream 3': ['/title/tt0134084/?ref_=bo_cso_table_60',
#   '860',
#   'Scream 3',
#   '$89,143,175',
#   '2000'],
#  'Oblivion': ['/title/tt1483013/?ref_=bo_cso_table_61',
#   '861',
#   'Oblivion',
#   '$89,107,235',
#   '2013'],
#  'The Ugly Truth': ['/title/tt1142988/?ref_=bo_cso_table_62',
#   '862',
#   'The Ugly Truth',
#   '$88,915,214',
#   '2009'],
#  'Percy Jackson & the Olympians: The Lightning Thief': ['/title/tt0814255/?ref_=bo_cso_table_63',
#   '863',
#   'Percy Jackson & the Olympians: The Lightning Thief',
#   '$88,768,303',
#   '2010'],
#  'Failure to Launch': ['/title/tt0427229/?ref_=bo_cso_table_64',
#   '864',
#   'Failure to Launch',
#   '$88,715,192',
#   '2006'],
#  'The Muppets': ['/title/tt1204342/?ref_=bo_cso_table_65',
#   '865',
#   'The Muppets',
#   '$88,631,237',
#   '2011'],
#  'Inside Man': ['/title/tt0454848/?ref_=bo_cso_table_66',
#   '866',
#   'Inside Man',
#   '$88,513,495',
#   '2006'],
#  'Back to the Future Part III': ['/title/tt0099088/?ref_=bo_cso_table_67',
#   '867',
#   'Back to the Future Part III',
#   '$88,277,583',
#   '1990'],
#  'Waterworld': ['/title/tt0114898/?ref_=bo_cso_table_68',
#   '868',
#   'Waterworld',
#   '$88,246,220',
#   '1995'],
#  'Starsky & Hutch': ['/title/tt0335438/?ref_=bo_cso_table_69',
#   '869',
#   'Starsky & Hutch',
#   '$88,237,754',
#   '2004'],
#  'Along Came Polly': ['/title/tt0343135/?ref_=bo_cso_table_70',
#   '870',
#   'Along Came Polly',
#   '$88,097,164',
#   '2004'],
#  'The Hand That Rocks the Cradle': ['/title/tt0104389/?ref_=bo_cso_table_71',
#   '871',
#   'The Hand That Rocks the Cradle',
#   '$88,036,683',
#   '1992'],
#  'Entrapment': ['/title/tt0137494/?ref_=bo_cso_table_72',
#   '872',
#   'Entrapment',
#   '$87,704,396',
#   '1999'],
#  'Peter Pan': ['/title/tt0046183/?ref_=bo_cso_table_73',
#   '873',
#   'Peter Pan',
#   '$87,404,651',
#   '1953'],
#  'Pineapple Express': ['/title/tt0910936/?ref_=bo_cso_table_74',
#   '874',
#   'Pineapple Express',
#   '$87,341,380',
#   '2008'],
#  "Miss Peregrine's Home for Peculiar Children": ['/title/tt1935859/?ref_=bo_cso_table_75',
#   '875',
#   "Miss Peregrine's Home for Peculiar Children",
#   '$87,242,834',
#   '2016'],
#  'Everest': ['/title/tt0120661/?ref_=bo_cso_table_76',
#   '876',
#   'Everest',
#   '$87,178,599',
#   '1998'],
#  'Out of Africa': ['/title/tt0089755/?ref_=bo_cso_table_77',
#   '877',
#   'Out of Africa',
#   '$87,071,205',
#   '1985'],
#  'Sisters': ['/title/tt1850457/?ref_=bo_cso_table_78',
#   '878',
#   'Sisters',
#   '$87,044,645',
#   '2015'],
#  'Saw II': ['/title/tt0432348/?ref_=bo_cso_table_79',
#   '879',
#   'Saw II',
#   '$87,039,965',
#   '2005'],
#  'The Naked Gun 2½: The Smell of Fear': ['/title/tt0102510/?ref_=bo_cso_table_80',
#   '880',
#   'The Naked Gun 2½: The Smell of Fear',
#   '$86,930,411',
#   '1991'],
#  'The Campaign': ['/title/tt1790886/?ref_=bo_cso_table_81',
#   '881',
#   'The Campaign',
#   '$86,907,746',
#   '2012'],
#  'The War of the Roses': ['/title/tt0098621/?ref_=bo_cso_table_82',
#   '882',
#   'The War of the Roses',
#   '$86,888,546',
#   '1989'],
#  'The Amityville Horror': ['/title/tt0078767/?ref_=bo_cso_table_83',
#   '883',
#   'The Amityville Horror',
#   '$86,432,000',
#   '1979'],
#  'Presumed Innocent': ['/title/tt0100404/?ref_=bo_cso_table_84',
#   '884',
#   'Presumed Innocent',
#   '$86,303,188',
#   '1990'],
#  'Young Frankenstein': ['/title/tt0072431/?ref_=bo_cso_table_85',
#   '885',
#   'Young Frankenstein',
#   '$86,273,333',
#   '1974'],
#  'The Accountant': ['/title/tt2140479/?ref_=bo_cso_table_86',
#   '886',
#   'The Accountant',
#   '$86,260,045',
#   '2016'],
#  'Dumb and Dumber To': ['/title/tt2096672/?ref_=bo_cso_table_87',
#   '887',
#   'Dumb and Dumber To',
#   '$86,208,010',
#   '2014'],
#  'The Emoji Movie': ['/title/tt4877122/?ref_=bo_cso_table_88',
#   '888',
#   'The Emoji Movie',
#   '$86,089,513',
#   '2017'],
#  'Mean Girls': ['/title/tt0377092/?ref_=bo_cso_table_89',
#   '889',
#   'Mean Girls',
#   '$86,058,055',
#   '2004'],
#  'Annie': ['/title/tt1823664/?ref_=bo_cso_table_90',
#   '890',
#   'Annie',
#   '$85,911,262',
#   '2014'],
#  'Alvin and the Chipmunks: The Road Chip': ['/title/tt2974918/?ref_=bo_cso_table_91',
#   '891',
#   'Alvin and the Chipmunks: The Road Chip',
#   '$85,886,987',
#   '2015'],
#  'Spy Kids 2: Island of Lost Dreams': ['/title/tt0287717/?ref_=bo_cso_table_92',
#   '892',
#   'Spy Kids 2: Island of Lost Dreams',
#   '$85,846,429',
#   '2002'],
#  'Alita: Battle Angel': ['/title/tt0437086/?ref_=bo_cso_table_93',
#   '893',
#   'Alita: Battle Angel',
#   '$85,838,210',
#   '2019'],
#  'Fury': ['/title/tt2713180/?ref_=bo_cso_table_94',
#   '894',
#   'Fury',
#   '$85,817,906',
#   '2014'],
#  'Pokémon: The First Movie - Mewtwo Strikes Back': ['/title/tt0190641/?ref_=bo_cso_table_95',
#   '895',
#   'Pokémon: The First Movie - Mewtwo Strikes Back',
#   '$85,744,662',
#   '1999'],
#  'Real Steel': ['/title/tt0433035/?ref_=bo_cso_table_96',
#   '896',
#   'Real Steel',
#   '$85,468,508',
#   '2011'],
#  'The SpongeBob SquarePants Movie': ['/title/tt0345950/?ref_=bo_cso_table_97',
#   '897',
#   'The SpongeBob SquarePants Movie',
#   '$85,417,988',
#   '2004'],
#  'Power Rangers': ['/title/tt3717490/?ref_=bo_cso_table_98',
#   '898',
#   'Power Rangers',
#   '$85,364,450',
#   '2017'],
#  'Brother Bear': ['/title/tt0328880/?ref_=bo_cso_table_99',
#   '899',
#   'Brother Bear',
#   '$85,336,277',
#   '2003'],
#  'Stripes': ['/title/tt0083131/?ref_=bo_cso_table_100',
#   '900',
#   'Stripes',
#   '$85,297,000',
#   '1981'],
#  'Anchorman: The Legend of Ron Burgundy': ['/title/tt0357413/?ref_=bo_cso_table_101',
#   '901',
#   'Anchorman: The Legend of Ron Burgundy',
#   '$85,288,303',
#   '2004'],
#  'Every Which Way but Loose': ['/title/tt0077523/?ref_=bo_cso_table_102',
#   '902',
#   'Every Which Way but Loose',
#   '$85,196,485',
#   '1978'],
#  'Rocky II': ['/title/tt0079817/?ref_=bo_cso_table_103',
#   '903',
#   'Rocky II',
#   '$85,182,160',
#   '1979'],
#  'Aliens': ['/title/tt0090605/?ref_=bo_cso_table_104',
#   '904',
#   'Aliens',
#   '$85,160,248',
#   '1986'],
#  'Open Season': ['/title/tt0400717/?ref_=bo_cso_table_105',
#   '905',
#   'Open Season',
#   '$85,105,259',
#   '2006'],
#  'Green Book': ['/title/tt6966692/?ref_=bo_cso_table_106',
#   '906',
#   'Green Book',
#   '$85,080,171',
#   '2018'],
#  'The Expendables 2': ['/title/tt1764651/?ref_=bo_cso_table_107',
#   '907',
#   'The Expendables 2',
#   '$85,028,192',
#   '2012'],
#  'Dangerous Minds': ['/title/tt0112792/?ref_=bo_cso_table_108',
#   '908',
#   'Dangerous Minds',
#   '$84,919,401',
#   '1995'],
#  'Paranormal Activity 2': ['/title/tt1536044/?ref_=bo_cso_table_109',
#   '909',
#   'Paranormal Activity 2',
#   '$84,752,907',
#   '2010'],
#  'Steel Magnolias': ['/title/tt0098384/?ref_=bo_cso_table_110',
#   '910',
#   'Steel Magnolias',
#   '$84,614,512',
#   '1989'],
#  'The Poseidon Adventure': ['/title/tt0069113/?ref_=bo_cso_table_111',
#   '911',
#   'The Poseidon Adventure',
#   '$84,563,118',
#   '1972'],
#  'Tammy': ['/title/tt2103254/?ref_=bo_cso_table_112',
#   '912',
#   'Tammy',
#   '$84,525,432',
#   '2014'],
#  'The Santa Clause 3: The Escape Clause': ['/title/tt0452681/?ref_=bo_cso_table_113',
#   '913',
#   'The Santa Clause 3: The Escape Clause',
#   '$84,500,122',
#   '2006'],
#  'Ferdinand': ['/title/tt3411444/?ref_=bo_cso_table_114',
#   '914',
#   'Ferdinand',
#   '$84,410,380',
#   '2017'],
#  'Crazy, Stupid, Love.': ['/title/tt1570728/?ref_=bo_cso_table_115',
#   '915',
#   'Crazy, Stupid, Love.',
#   '$84,351,197',
#   '2011'],
#  'Annabelle': ['/title/tt3322940/?ref_=bo_cso_table_116',
#   '916',
#   'Annabelle',
#   '$84,273,813',
#   '2014'],
#  'Pinocchio': ['/title/tt0032910/?ref_=bo_cso_table_117',
#   '917',
#   'Pinocchio',
#   '$84,254,167',
#   '1940'],
#  'Scooby-Doo 2: Monsters Unleashed': ['/title/tt0331632/?ref_=bo_cso_table_118',
#   '918',
#   'Scooby-Doo 2: Monsters Unleashed',
#   '$84,216,833',
#   '2004'],
#  'Birds of Prey': ['/title/tt7713068/?ref_=bo_cso_table_119',
#   '919',
#   'Birds of Prey',
#   '$84,158,461',
#   '2020'],
#  'Atlantis: The Lost Empire': ['/title/tt0230011/?ref_=bo_cso_table_120',
#   '920',
#   'Atlantis: The Lost Empire',
#   '$84,056,472',
#   '2001'],
#  'Cliffhanger': ['/title/tt0106582/?ref_=bo_cso_table_121',
#   '921',
#   'Cliffhanger',
#   '$84,049,211',
#   '1993'],
#  'The Other Woman': ['/title/tt2203939/?ref_=bo_cso_table_122',
#   '922',
#   'The Other Woman',
#   '$83,911,193',
#   '2014'],
#  'The X Files': ['/title/tt0120902/?ref_=bo_cso_table_123',
#   '923',
#   'The X Files',
#   '$83,898,313',
#   '1998'],
#  'Penguins of Madagascar': ['/title/tt1911658/?ref_=bo_cso_table_124',
#   '924',
#   'Penguins of Madagascar',
#   '$83,850,911',
#   '2014'],
#  'Die Hard': ['/title/tt0095016/?ref_=bo_cso_table_125',
#   '925',
#   'Die Hard',
#   '$83,844,093',
#   '1988'],
#  'Up in the Air': ['/title/tt1193138/?ref_=bo_cso_table_126',
#   '926',
#   'Up in the Air',
#   '$83,823,381',
#   '2009'],
#  'Wrath of the Titans': ['/title/tt1646987/?ref_=bo_cso_table_127',
#   '927',
#   'Wrath of the Titans',
#   '$83,670,083',
#   '2012'],
#  'Insidious: Chapter 2': ['/title/tt2226417/?ref_=bo_cso_table_128',
#   '928',
#   'Insidious: Chapter 2',
#   '$83,586,447',
#   '2013'],
#  'Under Siege': ['/title/tt0105690/?ref_=bo_cso_table_129',
#   '929',
#   'Under Siege',
#   '$83,563,139',
#   '1992'],
#  'Battle Los Angeles': ['/title/tt1217613/?ref_=bo_cso_table_130',
#   '930',
#   'Battle Los Angeles',
#   '$83,552,429',
#   '2011'],
#  'Immortals': ['/title/tt1253864/?ref_=bo_cso_table_131',
#   '931',
#   'Immortals',
#   '$83,504,017',
#   '2011'],
#  'I Can Only Imagine': ['/title/tt6450186/?ref_=bo_cso_table_132',
#   '932',
#   'I Can Only Imagine',
#   '$83,482,352',
#   '2018'],
#  'Apocalypse Now': ['/title/tt0078788/?ref_=bo_cso_table_133',
#   '933',
#   'Apocalypse Now',
#   '$83,471,511',
#   '1979'],
#  'Airplane!': ['/title/tt0080339/?ref_=bo_cso_table_134',
#   '934',
#   'Airplane!',
#   '$83,453,539',
#   '1980'],
#  'Patriot Games': ['/title/tt0105112/?ref_=bo_cso_table_135',
#   '935',
#   'Patriot Games',
#   '$83,351,587',
#   '1992'],
#  'Saving Mr. Banks': ['/title/tt2140373/?ref_=bo_cso_table_136',
#   '936',
#   'Saving Mr. Banks',
#   '$83,301,580',
#   '2013'],
#  'Smallfoot': ['/title/tt6182908/?ref_=bo_cso_table_137',
#   '937',
#   'Smallfoot',
#   '$83,240,103',
#   '2018'],
#  'Good Boys': ['/title/tt6977338/?ref_=bo_cso_table_138',
#   '938',
#   'Good Boys',
#   '$83,140,306',
#   '2019'],
#  'Valkyrie': ['/title/tt0985699/?ref_=bo_cso_table_139',
#   '939',
#   'Valkyrie',
#   '$83,077,833',
#   '2008'],
#  'Brokeback Mountain': ['/title/tt0388795/?ref_=bo_cso_table_140',
#   '940',
#   'Brokeback Mountain',
#   '$83,043,761',
#   '2005'],
#  'Turbo': ['/title/tt1860353/?ref_=bo_cso_table_141',
#   '941',
#   'Turbo',
#   '$83,028,128',
#   '2013'],
#  'Disclosure': ['/title/tt0109635/?ref_=bo_cso_table_142',
#   '942',
#   'Disclosure',
#   '$83,015,089',
#   '1994'],
#  "Charlotte's Web": ['/title/tt0413895/?ref_=bo_cso_table_143',
#   '943',
#   "Charlotte's Web",
#   '$82,985,708',
#   '2006'],
#  'Monster-in-Law': ['/title/tt0369735/?ref_=bo_cso_table_144',
#   '944',
#   'Monster-in-Law',
#   '$82,931,301',
#   '2005'],
#  'Are We There Yet?': ['/title/tt0368578/?ref_=bo_cso_table_145',
#   '945',
#   'Are We There Yet?',
#   '$82,674,398',
#   '2005'],
#  'Days of Thunder': ['/title/tt0099371/?ref_=bo_cso_table_146',
#   '946',
#   'Days of Thunder',
#   '$82,670,733',
#   '1990'],
#  'Freddy vs. Jason': ['/title/tt0329101/?ref_=bo_cso_table_147',
#   '947',
#   'Freddy vs. Jason',
#   '$82,622,655',
#   '2003'],
#  'Star Trek: The Motion Picture': ['/title/tt0079945/?ref_=bo_cso_table_148',
#   '948',
#   'Star Trek: The Motion Picture',
#   '$82,604,699',
#   '1979'],
#  'The Descendants': ['/title/tt1033575/?ref_=bo_cso_table_149',
#   '949',
#   'The Descendants',
#   '$82,584,160',
#   '2011'],
#  'Cheaper by the Dozen 2': ['/title/tt0452598/?ref_=bo_cso_table_150',
#   '950',
#   'Cheaper by the Dozen 2',
#   '$82,571,173',
#   '2005'],
#  "Mr. Holland's Opus": ['/title/tt0113862/?ref_=bo_cso_table_151',
#   '951',
#   "Mr. Holland's Opus",
#   '$82,569,971',
#   '1995'],
#  "Bram Stoker's Dracula": ['/title/tt0103874/?ref_=bo_cso_table_152',
#   '952',
#   "Bram Stoker's Dracula",
#   '$82,522,790',
#   '1992'],
#  'Fried Green Tomatoes': ['/title/tt0101921/?ref_=bo_cso_table_153',
#   '953',
#   'Fried Green Tomatoes',
#   '$82,418,501',
#   '1991'],
#  "Let's Be Cops": ['/title/tt1924435/?ref_=bo_cso_table_154',
#   '954',
#   "Let's Be Cops",
#   '$82,390,774',
#   '2014'],
#  'Blade II': ['/title/tt0187738/?ref_=bo_cso_table_155',
#   '955',
#   'Blade II',
#   '$82,348,319',
#   '2002'],
#  'Beowulf': ['/title/tt0442933/?ref_=bo_cso_table_156',
#   '956',
#   'Beowulf',
#   '$82,280,579',
#   '2007'],
#  'Bridge to Terabithia': ['/title/tt0398808/?ref_=bo_cso_table_157',
#   '957',
#   'Bridge to Terabithia',
#   '$82,272,442',
#   '2007'],
#  'The Pink Panther': ['/title/tt0383216/?ref_=bo_cso_table_158',
#   '958',
#   'The Pink Panther',
#   '$82,226,474',
#   '2006'],
#  'Teenage Mutant Ninja Turtles: Out of the Shadows': ['/title/tt3949660/?ref_=bo_cso_table_159',
#   '959',
#   'Teenage Mutant Ninja Turtles: Out of the Shadows',
#   '$82,051,601',
#   '2016'],
#  'The Post': ['/title/tt6294822/?ref_=bo_cso_table_160',
#   '960',
#   'The Post',
#   '$81,903,458',
#   '2017'],
#  'Alien': ['/title/tt0078748/?ref_=bo_cso_table_161',
#   '961',
#   'Alien',
#   '$81,900,459',
#   '1979'],
#  'Jaws 2': ['/title/tt0077766/?ref_=bo_cso_table_162',
#   '962',
#   'Jaws 2',
#   '$81,766,007',
#   '1978'],
#  'Maze Runner: The Scorch Trials': ['/title/tt4046784/?ref_=bo_cso_table_163',
#   '963',
#   'Maze Runner: The Scorch Trials',
#   '$81,697,192',
#   '2015'],
#  'Heaven Can Wait': ['/title/tt0077663/?ref_=bo_cso_table_164',
#   '964',
#   'Heaven Can Wait',
#   '$81,640,278',
#   '1978'],
#  'Eight Below': ['/title/tt0397313/?ref_=bo_cso_table_165',
#   '965',
#   'Eight Below',
#   '$81,612,565',
#   '2006'],
#  'MASH': ['/title/tt0066026/?ref_=bo_cso_table_166',
#   '966',
#   'MASH',
#   '$81,600,000',
#   '1970'],
#  'Unstoppable': ['/title/tt0477080/?ref_=bo_cso_table_167',
#   '967',
#   'Unstoppable',
#   '$81,562,942',
#   '2010'],
#  'Payback': ['/title/tt0120784/?ref_=bo_cso_table_168',
#   '968',
#   'Payback',
#   '$81,526,121',
#   '1999'],
#  'Ted 2': ['/title/tt2637276/?ref_=bo_cso_table_169',
#   '969',
#   'Ted 2',
#   '$81,476,385',
#   '2015'],
#  'The Talented Mr. Ripley': ['/title/tt0134119/?ref_=bo_cso_table_170',
#   '970',
#   'The Talented Mr. Ripley',
#   '$81,298,265',
#   '1999'],
#  'School of Rock': ['/title/tt0332379/?ref_=bo_cso_table_171',
#   '971',
#   'School of Rock',
#   '$81,261,177',
#   '2003'],
#  'Police Academy': ['/title/tt0087928/?ref_=bo_cso_table_172',
#   '972',
#   'Police Academy',
#   '$81,198,894',
#   '1984'],
#  'Snow Dogs': ['/title/tt0281373/?ref_=bo_cso_table_173',
#   '973',
#   'Snow Dogs',
#   '$81,172,560',
#   '2002'],
#  '21': ['/title/tt0478087/?ref_=bo_cso_table_174',
#   '974',
#   '21',
#   '$81,159,365',
#   '2008'],
#  'While You Were Sleeping': ['/title/tt0114924/?ref_=bo_cso_table_175',
#   '975',
#   'While You Were Sleeping',
#   '$81,057,016',
#   '1995'],
#  'Congo': ['/title/tt0112715/?ref_=bo_cso_table_176',
#   '976',
#   'Congo',
#   '$81,022,101',
#   '1995'],
#  'The Notebook': ['/title/tt0332280/?ref_=bo_cso_table_177',
#   '977',
#   'The Notebook',
#   '$81,001,787',
#   '2004'],
#  'Jimmy Neutron: Boy Genius': ['/title/tt0268397/?ref_=bo_cso_table_178',
#   '978',
#   'Jimmy Neutron: Boy Genius',
#   '$80,936,232',
#   '2001'],
#  'Another 48 Hrs.': ['/title/tt0099044/?ref_=bo_cso_table_179',
#   '979',
#   'Another 48 Hrs.',
#   '$80,818,974',
#   '1990'],
#  'Moonstruck': ['/title/tt0093565/?ref_=bo_cso_table_180',
#   '980',
#   'Moonstruck',
#   '$80,640,528',
#   '1987'],
#  'Eat Pray Love': ['/title/tt0879870/?ref_=bo_cso_table_181',
#   '981',
#   'Eat Pray Love',
#   '$80,574,010',
#   '2010'],
#  'The Texas Chainsaw Massacre': ['/title/tt0324216/?ref_=bo_cso_table_182',
#   '982',
#   'The Texas Chainsaw Massacre',
#   '$80,571,655',
#   '2003'],
#  'Zookeeper': ['/title/tt1222817/?ref_=bo_cso_table_183',
#   '983',
#   'Zookeeper',
#   '$80,360,843',
#   '2011'],
#  'Alien vs. Predator': ['/title/tt0370263/?ref_=bo_cso_table_184',
#   '984',
#   'Alien vs. Predator',
#   '$80,282,231',
#   '2004'],
#  'What Happens in Vegas': ['/title/tt1033643/?ref_=bo_cso_table_185',
#   '985',
#   'What Happens in Vegas',
#   '$80,277,646',
#   '2008'],
#  'The Dukes of Hazzard': ['/title/tt0377818/?ref_=bo_cso_table_186',
#   '986',
#   'The Dukes of Hazzard',
#   '$80,270,227',
#   '2005'],
#  'The Wedding Singer': ['/title/tt0120888/?ref_=bo_cso_table_187',
#   '987',
#   'The Wedding Singer',
#   '$80,245,725',
#   '1998'],
#  'Saw III': ['/title/tt0489270/?ref_=bo_cso_table_188',
#   '988',
#   'Saw III',
#   '$80,238,724',
#   '2006'],
#  'The Mummy': ['/title/tt2345759/?ref_=bo_cso_table_189',
#   '989',
#   'The Mummy',
#   '$80,227,895',
#   '2017'],
#  'Disturbia': ['/title/tt0486822/?ref_=bo_cso_table_190',
#   '990',
#   'Disturbia',
#   '$80,209,692',
#   '2007'],
#  'Nacho Libre': ['/title/tt0457510/?ref_=bo_cso_table_191',
#   '991',
#   'Nacho Libre',
#   '$80,197,993',
#   '2006'],
#  'Jumper': ['/title/tt0489099/?ref_=bo_cso_table_192',
#   '992',
#   'Jumper',
#   '$80,172,128',
#   '2008'],
#  'Goosebumps': ['/title/tt1051904/?ref_=bo_cso_table_193',
#   '993',
#   'Goosebumps',
#   '$80,080,379',
#   '2015'],
#  'Jack Reacher': ['/title/tt0790724/?ref_=bo_cso_table_194',
#   '994',
#   'Jack Reacher',
#   '$80,070,736',
#   '2012'],
#  'Cloverfield': ['/title/tt1060277/?ref_=bo_cso_table_195',
#   '995',
#   'Cloverfield',
#   '$80,048,433',
#   '2008'],
#  'Footloose': ['/title/tt0087277/?ref_=bo_cso_table_196',
#   '996',
#   'Footloose',
#   '$80,035,402',
#   '1984'],
#  'Dear John': ['/title/tt0989757/?ref_=bo_cso_table_197',
#   '997',
#   'Dear John',
#   '$80,014,842',
#   '2010'],
#  'Men in Black: International': ['/title/tt2283336/?ref_=bo_cso_table_198',
#   '998',
#   'Men in Black: International',
#   '$80,001,807',
#   '2019'],
#  'A Star Is Born': ['/title/tt0075265/?ref_=bo_cso_table_199',
#   '999',
#   'A Star Is Born',
#   '$80,000,000',
#   '1976'],
#  'Knowing': ['/title/tt0448011/?ref_=bo_cso_table_200',
#   '1,000',
#   'Knowing',
#   '$79,957,634',
#   '2009']}

# %%
top_movies = pd.DataFrame(movies).T  #transpose
top_movies.columns = ['link_stub', 'rank_all_movies','title', 
                    'lifetime_gross', 'year']

top_movies.shape
# Out:
# (200, 5)

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
        # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
import dateutil.parser

def money_to_int(moneystring):
    if moneystring:
        moneystring = moneystring.replace('$', '').replace(',', '')
        return int(moneystring)
    else:
        pass

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

def clean_genres(genre_list):
    genres = [item.strip() for item in genre_list if item.strip()]
    return genres

# %%
def clean_sales(lst):
    
    '''Clean the summary domestic/international summary table
    
    Takes the raw list of money strings and converts each item to int
    '''
    
    sale_list = [item.text for item in lst]
    
    sale_list = [money_to_int(item) for item in sale_list]
   
    return sale_list


def clean_regions(lst):
    
    '''Clean the summary domestic/international summary table
    
    Takes raw list of region string, cleans, and puts back into list
    '''
    
    region_list = [item.text for item in lst]
    region_list = [item.strip() for item in region_list if item.split()]
    region_list = [item.split('(')[0].strip() for item in region_list]
    
    return region_list

# %%
def get_movie_dict(link):
    '''
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic distributor
        - budget
        - domestic gross
        - earliest release
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['movie_title', 'domestic_distributor','budget', 'domestic_opening_sales',
               'earliest_release',
               'rating', 'runtime_minutes','genres','summary_sales','crew_list','cast_list']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string.split('-')[0].strip()
    
    #Get domestic distributor
    domdist_regex = re.compile('Domestic Distributor')
    domdist_string = soup.find(text=domdist_regex).findNext().text
    domestic_dist = domdist_string.split('See')[0].strip()
    
    # Domestic distributor
    domestic_dist = get_movie_value(soup,'Domestic Distributor').split('See')[0].strip()

    # Budget
    raw_budget = get_movie_value(soup,'Budget')
    budget = money_to_int(raw_budget)

    # Domestic opening sales
    raw_domestic_opening = get_movie_value(soup,'Domestic Opening')
    domestic_opening_sales = money_to_int(raw_domestic_opening)

    #Earliest release date (raw)
    earliest_release_str = get_movie_value(soup,'Earliest Release').split('\n')[0].strip()
    earliest_release = datetime.strptime(earliest_release_str, '%B %d, %Y')
    earliest_release.strftime('%Y-%m-%d')

    #Rating
    rating = get_movie_value(soup,'MPAA')

    # Runtime
    raw_runtime = get_movie_value(soup,'Running Time')
    runtime_minutes = runtime_to_minutes(raw_runtime)

    #Genres
    raw_genres = get_movie_value(soup, 'Genres').split('\n')
    genres = clean_genres(raw_genres)
    
    #Sales list (domestic, international, worldwide)
    raw_sales_list = soup.find(class_='mojo-performance-summary-table').find_all('span', class_='money')[0:]
    sales_list = clean_sales(raw_sales_list)
    
    # Regions list
    raw_sales_regions = soup.find(class_='mojo-performance-summary-table').find_all('span', class_='a-size-small')[0:]
    regions_list = clean_regions(raw_sales_regions)
    
    # Zip region and associated sales per region - believe should solve for any missing regions
    summary_sales = [list(i) for i in zip(regions_list,sales_list)]
    
    #Find link for cast and crew
    credits = soup.find('a', class_='a-size-base a-link-normal mojo-navigation-tab',href=True)
    credits_href = str(credits.get('href'))
    credits_url = base_url + credits_href
    
    #Refer to cast and crew page
    response1 = requests.get(credits_url,headers = user_agent)
    page1 = response1.text
    soup1 = BeautifulSoup(page1, 'lxml')
    
    #Find crew table, cast table
    table_crew = soup1.find('table',id='principalCrew').find_all('td')
    table_cast = soup1.find('table',id='principalCast').find_all('td')
    
    #clean the tables
    def clean_credits(table1):
        lst1 = [item.text for item in table1]
        lst2 = [item.split('\n')[0].strip() for item in lst1]
        lst2 = [item for item in lst2[::2]]

        return lst2

    crew_list = clean_credits(table_crew)
    cast_list = clean_credits(table_cast)
    
    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [title, domestic_dist, budget,domestic_opening_sales,
                                    earliest_release,
                                    rating, runtime_minutes,genres,summary_sales,crew_list,cast_list]))

    return movie_dict

# %%
top_movies_page_info_list = []

for link in top_movies.link_stub:
    top_movies_page_info_list.append(get_movie_dict(link))

# %%
top_movies_page_info = pd.DataFrame(top_movies_page_info_list)  #convert list of dict to df
top_movies_page_info.set_index('movie_title', inplace=True)

# %%
top_movies_page_info.to_csv('mojo_pg5.csv')

# %%
top_movies_page_info.head()
# Out:
#                                                   domestic_distributor  \
# movie_title
# Maid in Manhattan                                   Revolution Studios
# He's Just Not That Into You                               Warner Bros.
# Master and Commander: The Far Side of the World  Twentieth Century Fox
# Flight                                              Paramount Pictures
# The Fighter                                         Paramount Pictures
#
#                                                       budget  \
# movie_title
# Maid in Manhattan                                 55000000.0
# He's Just Not That Into You                              NaN
# Master and Commander: The Far Side of the World  150000000.0
# Flight                                            31000000.0
# The Fighter                                       25000000.0
#
#                                                  domestic_opening_sales  \
# movie_title
# Maid in Manhattan                                            18711407.0
# He's Just Not That Into You                                  27785487.0
# Master and Commander: The Far Side of the World              25105990.0
# Flight                                                       24900566.0
# The Fighter                                                    300010.0
#
#                                                 earliest_release rating  \
# movie_title
# Maid in Manhattan                                     2002-12-13  PG-13
# He's Just Not That Into You                           2009-02-05  PG-13
# Master and Commander: The Far Side of the World       2003-11-14  PG-13
# Flight                                                2012-11-02      R
# The Fighter                                           2009-11-20      R
#
#                                                  runtime_minutes  \
# movie_title
# Maid in Manhattan                                          105.0
# He's Just Not That Into You                                129.0
# Master and Commander: The Far Side of the World            138.0
# Flight                                                     138.0
# The Fighter                                                116.0
#
#                                                                                    genres  \
# movie_title
# Maid in Manhattan                                                [Comedy, Drama, Romance]
# He's Just Not That Into You                                      [Comedy, Drama, Romance]
# Master and Commander: The Far Side of the World  [Action, Adventure, Drama, History, War]
# Flight                                                                  [Drama, Thriller]
# The Fighter                                                     [Biography, Drama, Sport]
#
#                                                                                      summary_sales  \
# movie_title
# Maid in Manhattan                                [[Domestic, 94011225], [International, 6089546...
# He's Just Not That Into You                      [[Domestic, 93953653], [International, 8491250...
# Master and Commander: The Far Side of the World  [[Domestic, 93927920], [International, 1176946...
# Flight                                           [[Domestic, 93772375], [International, 6800000...
# The Fighter                                      [[Domestic, 93617009], [International, 3557386...
#
#                                                                                          crew_list  \
# movie_title
# Maid in Manhattan                                [Wayne Wang, John Hughes, Kevin Wade, Elaine G...
# He's Just Not That Into You                      [Ken Kwapis, Abby Kohn, Marc Silverstein, Greg...
# Master and Commander: The Far Side of the World  [Peter Weir, Patrick O'Brian, Peter Weir, John...
# Flight                                           [Robert Zemeckis, John Gatins, Laurie MacDonal...
# The Fighter                                      [David O. Russell, Scott Silver, Paul Tamasy, ...
#
#                                                                                          cast_list
# movie_title
# Maid in Manhattan                                [Jennifer Lopez, Ralph Fiennes, Natasha Richar...
# He's Just Not That Into You                      [Ginnifer Goodwin, Jennifer Aniston, Jennifer ...
# Master and Commander: The Far Side of the World  [Russell Crowe, Paul Bettany, Billy Boyd, Jame...
# Flight                                           [Denzel Washington, Nadine Velazquez, Don Chea...
# The Fighter                                      [Mark Wahlberg, Christian Bale, Amy Adams, Mel...
