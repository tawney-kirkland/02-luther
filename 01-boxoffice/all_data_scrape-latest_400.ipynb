# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd
from datetime import datetime

# %%
url = 'https://www.boxofficemojo.com/chart/top_lifetime_gross/?offset=400'

user_agent = {'User-agent': 'Mozilla/5.0'}

response  = requests.get(url, headers = user_agent)

page = response.text

soup = BeautifulSoup(page,"lxml")

# %%
table = soup.find('table')
table
# Out:
# <table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Lifetime Gross">Lifetime Gross</span>
# </th><th class="a-text-left mojo-field-type-year a-nowrap"><span title="Year">Year</span>
# </th></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">401</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0232500/?ref_=bo_cso_table_1">The Fast and the Furious</a></td><td class="a-text-right mojo-field-type-money">$144,533,925</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2001/?ref_=bo_cso_table_1">2001</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">402</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0795421/?ref_=bo_cso_table_2">Mamma Mia!</a></td><td class="a-text-right mojo-field-type-money">$144,169,664</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2008/?ref_=bo_cso_table_2">2008</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">403</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0118998/?ref_=bo_cso_table_3">Doctor Dolittle</a></td><td class="a-text-right mojo-field-type-money">$144,156,605</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/1998/?ref_=bo_cso_table_3">1998</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">404</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt5884052/?ref_=bo_cso_table_4">Pokémon Detective Pikachu</a></td><td class="a-text-right mojo-field-type-money">$144,105,346</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2019/?ref_=bo_cso_table_4">2019</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">405</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1436562/?ref_=bo_cso_table_5">Rio</a></td><td class="a-text-right mojo-field-type-money">$143,619,809</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2011/?ref_=bo_cso_table_5">2011</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">406</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt2267968/?ref_=bo_cso_table_6">Kung Fu Panda 3</a></td><td class="a-text-right mojo-field-type-money">$143,528,619</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2016/?ref_=bo_cso_table_6">2016</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">407</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0467406/?ref_=bo_cso_table_7">Juno</a></td><td class="a-text-right mojo-field-type-money">$143,495,265</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2007/?ref_=bo_cso_table_7">2007</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">408</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0822832/?ref_=bo_cso_table_8">Marley &amp; Me</a></td><td class="a-text-right mojo-field-type-money">$143,153,751</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2008/?ref_=bo_cso_table_8">2008</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">409</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0472181/?ref_=bo_cso_table_9">The Smurfs</a></td><td class="a-text-right mojo-field-type-money">$142,614,158</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/2011/?ref_=bo_cso_table_9">2011</a></td></tr><tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">410</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt7131622/?ref_=bo_cso_table_10 ...

# %%
rows = [row for row in table.find_all('tr')]

# %%
movies = {}

for row in rows[1:]:
    items = row.find_all('td')
    link = row.find('a')
    title, url = link.text, link['href']
    movies[title] = [url] + [i.text for i in items]
    
movies
# Out:
# {'The Fast and the Furious': ['/title/tt0232500/?ref_=bo_cso_table_1',
#   '401',
#   'The Fast and the Furious',
#   '$144,533,925',
#   '2001'],
#  'Mamma Mia!': ['/title/tt0795421/?ref_=bo_cso_table_2',
#   '402',
#   'Mamma Mia!',
#   '$144,169,664',
#   '2008'],
#  'Doctor Dolittle': ['/title/tt0118998/?ref_=bo_cso_table_3',
#   '403',
#   'Doctor Dolittle',
#   '$144,156,605',
#   '1998'],
#  'Pokémon Detective Pikachu': ['/title/tt5884052/?ref_=bo_cso_table_4',
#   '404',
#   'Pokémon Detective Pikachu',
#   '$144,105,346',
#   '2019'],
#  'Rio': ['/title/tt1436562/?ref_=bo_cso_table_5',
#   '405',
#   'Rio',
#   '$143,619,809',
#   '2011'],
#  'Kung Fu Panda 3': ['/title/tt2267968/?ref_=bo_cso_table_6',
#   '406',
#   'Kung Fu Panda 3',
#   '$143,528,619',
#   '2016'],
#  'Juno': ['/title/tt0467406/?ref_=bo_cso_table_7',
#   '407',
#   'Juno',
#   '$143,495,265',
#   '2007'],
#  'Marley & Me': ['/title/tt0822832/?ref_=bo_cso_table_8',
#   '408',
#   'Marley & Me',
#   '$143,153,751',
#   '2008'],
#  'The Smurfs': ['/title/tt0472181/?ref_=bo_cso_table_9',
#   '409',
#   'The Smurfs',
#   '$142,614,158',
#   '2011'],
#  'Once Upon a Time... In Hollywood': ['/title/tt7131622/?ref_=bo_cso_table_10',
#   '410',
#   'Once Upon a Time... In Hollywood',
#   '$142,502,728',
#   '2019'],
#  'xXx': ['/title/tt0295701/?ref_=bo_cso_table_11',
#   '411',
#   'xXx',
#   '$142,109,382',
#   '2002'],
#  'The Jungle Book': ['/title/tt0061852/?ref_=bo_cso_table_12',
#   '412',
#   'The Jungle Book',
#   '$141,843,612',
#   '1967'],
#  'The Chronicles of Narnia: Prince Caspian': ['/title/tt0499448/?ref_=bo_cso_table_13',
#   '413',
#   'The Chronicles of Narnia: Prince Caspian',
#   '$141,621,490',
#   '2008'],
#  "National Lampoon's Animal House": ['/title/tt0077975/?ref_=bo_cso_table_14',
#   '414',
#   "National Lampoon's Animal House",
#   '$141,600,000',
#   '1978'],
#  'Pocahontas': ['/title/tt0114148/?ref_=bo_cso_table_15',
#   '415',
#   'Pocahontas',
#   '$141,579,773',
#   '1995'],
#  'A Few Good Men': ['/title/tt0104257/?ref_=bo_cso_table_16',
#   '416',
#   'A Few Good Men',
#   '$141,340,178',
#   '1992'],
#  'Slumdog Millionaire': ['/title/tt1010048/?ref_=bo_cso_table_17',
#   '417',
#   'Slumdog Millionaire',
#   '$141,319,928',
#   '2008'],
#  'Rush Hour': ['/title/tt0120812/?ref_=bo_cso_table_18',
#   '418',
#   'Rush Hour',
#   '$141,186,864',
#   '1998'],
#  'The Blair Witch Project': ['/title/tt0185937/?ref_=bo_cso_table_19',
#   '419',
#   'The Blair Witch Project',
#   '$140,539,099',
#   '1999'],
#  'Deep Impact': ['/title/tt0120647/?ref_=bo_cso_table_20',
#   '420',
#   'Deep Impact',
#   '$140,464,664',
#   '1998'],
#  'Shazam!': ['/title/tt0448115/?ref_=bo_cso_table_21',
#   '421',
#   'Shazam!',
#   '$140,371,656',
#   '2019'],
#  "Ocean's Eight": ['/title/tt5164214/?ref_=bo_cso_table_22',
#   '422',
#   "Ocean's Eight",
#   '$140,218,711',
#   '2018'],
#  'Rush Hour 3': ['/title/tt0293564/?ref_=bo_cso_table_23',
#   '423',
#   'Rush Hour 3',
#   '$140,125,968',
#   '2007'],
#  "Look Who's Talking": ['/title/tt0097778/?ref_=bo_cso_table_24',
#   '424',
#   "Look Who's Talking",
#   '$140,088,813',
#   '1989'],
#  'Stuart Little': ['/title/tt0164912/?ref_=bo_cso_table_25',
#   '425',
#   'Stuart Little',
#   '$140,035,367',
#   '1999'],
#  'Taken 2': ['/title/tt1397280/?ref_=bo_cso_table_26',
#   '426',
#   'Taken 2',
#   '$139,854,287',
#   '2012'],
#  'Sister Act': ['/title/tt0105417/?ref_=bo_cso_table_27',
#   '427',
#   'Sister Act',
#   '$139,605,150',
#   '1992'],
#  'The Matrix Revolutions': ['/title/tt0242653/?ref_=bo_cso_table_28',
#   '428',
#   'The Matrix Revolutions',
#   '$139,313,948',
#   '2003'],
#  'The Santa Clause 2': ['/title/tt0304669/?ref_=bo_cso_table_29',
#   '429',
#   'The Santa Clause 2',
#   '$139,236,327',
#   '2002'],
#  "The King's Speech": ['/title/tt1504320/?ref_=bo_cso_table_30',
#   '430',
#   "The King's Speech",
#   '$138,797,449',
#   '2010'],
#  'Cheaper by the Dozen': ['/title/tt0349205/?ref_=bo_cso_table_31',
#   '431',
#   'Cheaper by the Dozen',
#   '$138,614,544',
#   '2003'],
#  'Bad Boys II': ['/title/tt0172156/?ref_=bo_cso_table_32',
#   '432',
#   'Bad Boys II',
#   '$138,608,444',
#   '2003'],
#  'Platoon': ['/title/tt0091763/?ref_=bo_cso_table_33',
#   '433',
#   'Platoon',
#   '$138,530,565',
#   '1986'],
#  '21 Jump Street': ['/title/tt1232829/?ref_=bo_cso_table_34',
#   '434',
#   '21 Jump Street',
#   '$138,447,667',
#   '2012'],
#  'Good Will Hunting': ['/title/tt0119217/?ref_=bo_cso_table_35',
#   '435',
#   'Good Will Hunting',
#   '$138,433,435',
#   '1997'],
#  'Split': ['/title/tt4972582/?ref_=bo_cso_table_36',
#   '436',
#   'Split',
#   '$138,291,365',
#   '2017'],
#  'A Christmas Carol': ['/title/tt1067106/?ref_=bo_cso_table_37',
#   '437',
#   'A Christmas Carol',
#   '$137,855,863',
#   '2009'],
#  'Dinosaur': ['/title/tt0130623/?ref_=bo_cso_table_38',
#   '438',
#   'Dinosaur',
#   '$137,748,063',
#   '2000'],
#  'Ready Player One': ['/title/tt1677720/?ref_=bo_cso_table_39',
#   '439',
#   'Ready Player One',
#   '$137,690,172',
#   '2018'],
#  'The Conjuring': ['/title/tt1457767/?ref_=bo_cso_table_40',
#   '440',
#   'The Conjuring',
#   '$137,400,141',
#   '2013'],
#  'Click': ['/title/tt0389860/?ref_=bo_cso_table_41',
#   '441',
#   'Click',
#   '$137,355,633',
#   '2006'],
#  'The Green Mile': ['/title/tt0120689/?ref_=bo_cso_table_42',
#   '442',
#   'The Green Mile',
#   '$136,801,374',
#   '1999'],
#  'Ransom': ['/title/tt0117438/?ref_=bo_cso_table_43',
#   '443',
#   'Ransom',
#   '$136,492,681',
#   '1996'],
#  'Godzilla': ['/title/tt0120685/?ref_=bo_cso_table_44',
#   '444',
#   'Godzilla',
#   '$136,314,294',
#   '1998'],
#  '101 Dalmatians': ['/title/tt0115433/?ref_=bo_cso_table_45',
#   '445',
#   '101 Dalmatians',
#   '$136,189,294',
#   '1996'],
#  'Argo': ['/title/tt1024648/?ref_=bo_cso_table_46',
#   '446',
#   'Argo',
#   '$136,025,503',
#   '2012'],
#  'Anger Management': ['/title/tt0305224/?ref_=bo_cso_table_47',
#   '447',
#   'Anger Management',
#   '$135,645,823',
#   '2003'],
#  'Chicken Little': ['/title/tt0371606/?ref_=bo_cso_table_48',
#   '448',
#   'Chicken Little',
#   '$135,386,665',
#   '2005'],
#  'Teenage Mutant Ninja Turtles': ['/title/tt0100758/?ref_=bo_cso_table_49',
#   '449',
#   'Teenage Mutant Ninja Turtles',
#   '$135,265,915',
#   '1990'],
#  'Close Encounters of the Third Kind': ['/title/tt0075860/?ref_=bo_cso_table_50',
#   '450',
#   'Close Encounters of the Third Kind',
#   '$135,189,114',
#   '1977'],
#  'Patch Adams': ['/title/tt0129290/?ref_=bo_cso_table_51',
#   '451',
#   'Patch Adams',
#   '$135,026,902',
#   '1998'],
#  'The Godfather': ['/title/tt0068646/?ref_=bo_cso_table_52',
#   '452',
#   'The Godfather',
#   '$134,966,411',
#   '1972'],
#  'Ride Along': ['/title/tt1408253/?ref_=bo_cso_table_53',
#   '453',
#   'Ride Along',
#   '$134,938,200',
#   '2014'],
#  'The Incredible Hulk': ['/title/tt0800080/?ref_=bo_cso_table_54',
#   '454',
#   'The Incredible Hulk',
#   '$134,806,913',
#   '2008'],
#  'Live Free or Die Hard': ['/title/tt0337978/?ref_=bo_cso_table_55',
#   '455',
#   'Live Free or Die Hard',
#   '$134,529,403',
#   '2007'],
#  'Wanted': ['/title/tt0493464/?ref_=bo_cso_table_56',
#   '456',
#   'Wanted',
#   '$134,508,551',
#   '2008'],
#  'Identity Thief': ['/title/tt2024432/?ref_=bo_cso_table_57',
#   '457',
#   'Identity Thief',
#   '$134,506,920',
#   '2013'],
#  'Superman': ['/title/tt0078346/?ref_=bo_cso_table_58',
#   '458',
#   'Superman',
#   '$134,451,603',
#   '1978'],
#  'The Rock': ['/title/tt0117500/?ref_=bo_cso_table_59',
#   '459',
#   'The Rock',
#   '$134,069,511',
#   '1996'],
#  'Mission: Impossible III': ['/title/tt0317919/?ref_=bo_cso_table_60',
#   '460',
#   'Mission: Impossible III',
#   '$134,029,801',
#   '2006'],
#  'Grown Ups 2': ['/title/tt2191701/?ref_=bo_cso_table_61',
#   '461',
#   'Grown Ups 2',
#   '$133,668,525',
#   '2013'],
#  'Troy': ['/title/tt0332452/?ref_=bo_cso_table_62',
#   '462',
#   'Troy',
#   '$133,378,256',
#   '2004'],
#  'Angels & Demons': ['/title/tt0808151/?ref_=bo_cso_table_63',
#   '463',
#   'Angels & Demons',
#   '$133,375,846',
#   '2009'],
#  'Alvin and the Chipmunks: Chipwrecked': ['/title/tt1615918/?ref_=bo_cso_table_64',
#   '464',
#   'Alvin and the Chipmunks: Chipwrecked',
#   '$133,110,742',
#   '2011'],
#  'Bringing Down the House': ['/title/tt0305669/?ref_=bo_cso_table_65',
#   '465',
#   'Bringing Down the House',
#   '$132,716,677',
#   '2003'],
#  'The Wolverine': ['/title/tt1430132/?ref_=bo_cso_table_66',
#   '466',
#   'The Wolverine',
#   '$132,556,852',
#   '2013'],
#  'Wonder': ['/title/tt2543472/?ref_=bo_cso_table_67',
#   '467',
#   'Wonder',
#   '$132,422,809',
#   '2017'],
#  'The Departed': ['/title/tt0407887/?ref_=bo_cso_table_68',
#   '468',
#   'The Departed',
#   '$132,384,315',
#   '2006'],
#  'Hulk': ['/title/tt0286716/?ref_=bo_cso_table_69',
#   '469',
#   'Hulk',
#   '$132,177,234',
#   '2003'],
#  'Silver Linings Playbook': ['/title/tt1045658/?ref_=bo_cso_table_70',
#   '470',
#   'Silver Linings Playbook',
#   '$132,092,958',
#   '2012'],
#  'Minority Report': ['/title/tt0181689/?ref_=bo_cso_table_71',
#   '471',
#   'Minority Report',
#   '$132,072,926',
#   '2002'],
#  'Fantastic 4: Rise of the Silver Surfer': ['/title/tt0486576/?ref_=bo_cso_table_72',
#   '472',
#   'Fantastic 4: Rise of the Silver Surfer',
#   '$131,921,738',
#   '2007'],
#  'The Last Airbender': ['/title/tt0938283/?ref_=bo_cso_table_73',
#   '473',
#   'The Last Airbender',
#   '$131,772,187',
#   '2010'],
#  'Rio 2': ['/title/tt2357291/?ref_=bo_cso_table_74',
#   '474',
#   'Rio 2',
#   '$131,538,435',
#   '2014'],
#  'Lara Croft: Tomb Raider': ['/title/tt0146316/?ref_=bo_cso_table_75',
#   '475',
#   'Lara Croft: Tomb Raider',
#   '$131,168,070',
#   '2001'],
#  'The Silence of the Lambs': ['/title/tt0102926/?ref_=bo_cso_table_76',
#   '476',
#   'The Silence of the Lambs',
#   '$130,742,922',
#   '1991'],
#  'Honey, I Shrunk the Kids': ['/title/tt0097523/?ref_=bo_cso_table_77',
#   '477',
#   'Honey, I Shrunk the Kids',
#   '$130,724,172',
#   '1989'],
#  'The Flintstones': ['/title/tt0109813/?ref_=bo_cso_table_78',
#   '478',
#   'The Flintstones',
#   '$130,531,208',
#   '1994'],
#  'Lethal Weapon 4': ['/title/tt0122151/?ref_=bo_cso_table_79',
#   '479',
#   'Lethal Weapon 4',
#   '$130,444,603',
#   '1998'],
#  'Get Smart': ['/title/tt0425061/?ref_=bo_cso_table_80',
#   '480',
#   'Get Smart',
#   '$130,319,208',
#   '2008'],
#  'The Divergent Series: Insurgent': ['/title/tt2908446/?ref_=bo_cso_table_81',
#   '481',
#   'The Divergent Series: Insurgent',
#   '$130,179,072',
#   '2015'],
#  'The Peanuts Movie': ['/title/tt2452042/?ref_=bo_cso_table_82',
#   '482',
#   'The Peanuts Movie',
#   '$130,178,411',
#   '2015'],
#  'Transformers: The Last Knight': ['/title/tt3371366/?ref_=bo_cso_table_83',
#   '483',
#   'Transformers: The Last Knight',
#   '$130,168,683',
#   '2017'],
#  'American Gangster': ['/title/tt0765429/?ref_=bo_cso_table_84',
#   '484',
#   'American Gangster',
#   '$130,164,645',
#   '2007'],
#  'American Beauty': ['/title/tt0169547/?ref_=bo_cso_table_85',
#   '485',
#   'American Beauty',
#   '$130,096,601',
#   '1999'],
#  'An Officer and a Gentleman': ['/title/tt0084434/?ref_=bo_cso_table_86',
#   '486',
#   'An Officer and a Gentleman',
#   '$129,795,554',
#   '1982'],
#  'The Ring': ['/title/tt0298130/?ref_=bo_cso_table_87',
#   '487',
#   'The Ring',
#   '$129,128,133',
#   '2002'],
#  'The Nutty Professor': ['/title/tt0117218/?ref_=bo_cso_table_88',
#   '488',
#   'The Nutty Professor',
#   '$128,814,019',
#   '1996'],
#  'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan': ['/title/tt0443453/?ref_=bo_cso_table_89',
#   '489',
#   'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan',
#   '$128,505,958',
#   '2006'],
#  'Ghostbusters': ['/title/tt1289401/?ref_=bo_cso_table_90',
#   '490',
#   'Ghostbusters',
#   '$128,350,574',
#   '2016'],
#  'Kingsman: The Secret Service': ['/title/tt2802144/?ref_=bo_cso_table_91',
#   '491',
#   'Kingsman: The Secret Service',
#   '$128,261,724',
#   '2015'],
#  'Robots': ['/title/tt0358082/?ref_=bo_cso_table_92',
#   '492',
#   'Robots',
#   '$128,200,012',
#   '2005'],
#  'Coming to America': ['/title/tt0094898/?ref_=bo_cso_table_93',
#   '493',
#   'Coming to America',
#   '$128,152,301',
#   '1988'],
#  'Crouching Tiger, Hidden Dragon': ['/title/tt0190332/?ref_=bo_cso_table_94',
#   '494',
#   'Crouching Tiger, Hidden Dragon',
#   '$128,078,872',
#   '2000'],
#  'Shutter Island': ['/title/tt1130884/?ref_=bo_cso_table_95',
#   '495',
#   'Shutter Island',
#   '$128,012,934',
#   '2010'],
#  'Into the Woods': ['/title/tt2180411/?ref_=bo_cso_table_96',
#   '496',
#   'Into the Woods',
#   '$128,002,372',
#   '2014'],
#  'Rocky IV': ['/title/tt0089927/?ref_=bo_cso_table_97',
#   '497',
#   'Rocky IV',
#   '$127,873,716',
#   '1985'],
#  'Enchanted': ['/title/tt0461770/?ref_=bo_cso_table_98',
#   '498',
#   'Enchanted',
#   '$127,807,262',
#   '2007'],
#  'The Curious Case of Benjamin Button': ['/title/tt0421715/?ref_=bo_cso_table_99',
#   '499',
#   'The Curious Case of Benjamin Button',
#   '$127,509,326',
#   '2008'],
#  'Central Intelligence': ['/title/tt1489889/?ref_=bo_cso_table_100',
#   '500',
#   'Central Intelligence',
#   '$127,440,871',
#   '2016'],
#  'Anchorman 2: The Legend Continues': ['/title/tt1229340/?ref_=bo_cso_table_101',
#   '501',
#   'Anchorman 2: The Legend Continues',
#   '$127,352,707',
#   '2013'],
#  'Sweet Home Alabama': ['/title/tt0256415/?ref_=bo_cso_table_102',
#   '502',
#   'Sweet Home Alabama',
#   '$127,223,418',
#   '2002'],
#  'Bumblebee': ['/title/tt4701182/?ref_=bo_cso_table_103',
#   '503',
#   'Bumblebee',
#   '$127,195,589',
#   '2018'],
#  'Dumb and Dumber': ['/title/tt0109686/?ref_=bo_cso_table_104',
#   '504',
#   'Dumb and Dumber',
#   '$127,175,374',
#   '1994'],
#  '2 Fast 2 Furious': ['/title/tt0322259/?ref_=bo_cso_table_105',
#   '505',
#   '2 Fast 2 Furious',
#   '$127,154,901',
#   '2003'],
#  "My Best Friend's Wedding": ['/title/tt0119738/?ref_=bo_cso_table_106',
#   '506',
#   "My Best Friend's Wedding",
#   '$127,120,029',
#   '1997'],
#  'Super 8': ['/title/tt1650062/?ref_=bo_cso_table_107',
#   '507',
#   'Super 8',
#   '$127,004,179',
#   '2011'],
#  'The World Is Not Enough': ['/title/tt0143145/?ref_=bo_cso_table_108',
#   '508',
#   'The World Is Not Enough',
#   '$126,943,684',
#   '1999'],
#  'Sleepless in Seattle': ['/title/tt0108160/?ref_=bo_cso_table_109',
#   '509',
#   'Sleepless in Seattle',
#   '$126,808,165',
#   '1993'],
#  'Smokey and the Bandit': ['/title/tt0076729/?ref_=bo_cso_table_110',
#   '510',
#   'Smokey and the Bandit',
#   '$126,737,428',
#   '1977'],
#  'Lucy': ['/title/tt2872732/?ref_=bo_cso_table_111',
#   '511',
#   'Lucy',
#   '$126,663,600',
#   '2014'],
#  'The Legend of Tarzan': ['/title/tt0918940/?ref_=bo_cso_table_112',
#   '512',
#   'The Legend of Tarzan',
#   '$126,643,061',
#   '2016'],
#  'Bee Movie': ['/title/tt0389790/?ref_=bo_cso_table_113',
#   '513',
#   'Bee Movie',
#   '$126,631,277',
#   '2007'],
#  'Prometheus': ['/title/tt1446714/?ref_=bo_cso_table_114',
#   '514',
#   'Prometheus',
#   '$126,477,084',
#   '2012'],
#  'Safe House': ['/title/tt1599348/?ref_=bo_cso_table_115',
#   '515',
#   'Safe House',
#   '$126,373,434',
#   '2012'],
#  'Mr. Deeds': ['/title/tt0280590/?ref_=bo_cso_table_116',
#   '516',
#   'Mr. Deeds',
#   '$126,293,452',
#   '2002'],
#  'The Truman Show': ['/title/tt0120382/?ref_=bo_cso_table_117',
#   '517',
#   'The Truman Show',
#   '$125,618,201',
#   '1998'],
#  'Erin Brockovich': ['/title/tt0195685/?ref_=bo_cso_table_118',
#   '518',
#   'Erin Brockovich',
#   '$125,595,205',
#   '2000'],
#  "Ocean's Twelve": ['/title/tt0349903/?ref_=bo_cso_table_119',
#   '519',
#   "Ocean's Twelve",
#   '$125,544,280',
#   '2004'],
#  'Terminator Salvation': ['/title/tt0438488/?ref_=bo_cso_table_120',
#   '520',
#   'Terminator Salvation',
#   '$125,322,469',
#   '2009'],
#  "Charlie's Angels": ['/title/tt0160127/?ref_=bo_cso_table_121',
#   '521',
#   "Charlie's Angels",
#   '$125,305,545',
#   '2000'],
#  'Tomorrow Never Dies': ['/title/tt0120347/?ref_=bo_cso_table_122',
#   '522',
#   'Tomorrow Never Dies',
#   '$125,304,276',
#   '1997'],
#  'Lone Survivor': ['/title/tt1091191/?ref_=bo_cso_table_123',
#   '523',
#   'Lone Survivor',
#   '$125,095,601',
#   '2013'],
#  'Sully': ['/title/tt3263904/?ref_=bo_cso_table_124',
#   '524',
#   'Sully',
#   '$125,070,033',
#   '2016'],
#  'Rocky III': ['/title/tt0084602/?ref_=bo_cso_table_125',
#   '525',
#   'Rocky III',
#   '$125,049,125',
#   '1982'],
#  'The Vow': ['/title/tt1606389/?ref_=bo_cso_table_126',
#   '526',
#   'The Vow',
#   '$125,014,030',
#   '2012'],
#  'Life of Pi': ['/title/tt0454876/?ref_=bo_cso_table_127',
#   '527',
#   'Life of Pi',
#   '$124,987,023',
#   '2012'],
#  'The Fault in Our Stars': ['/title/tt2582846/?ref_=bo_cso_table_128',
#   '528',
#   'The Fault in Our Stars',
#   '$124,872,350',
#   '2014'],
#  'Cloudy with a Chance of Meatballs': ['/title/tt0844471/?ref_=bo_cso_table_129',
#   '529',
#   'Cloudy with a Chance of Meatballs',
#   '$124,870,275',
#   '2009'],
#  'The Devil Wears Prada': ['/title/tt0458352/?ref_=bo_cso_table_130',
#   '530',
#   'The Devil Wears Prada',
#   '$124,740,460',
#   '2006'],
#  "Something's Gotta Give": ['/title/tt0337741/?ref_=bo_cso_table_131',
#   '531',
#   "Something's Gotta Give",
#   '$124,728,738',
#   '2003'],
#  'Traffic': ['/title/tt0181865/?ref_=bo_cso_table_132',
#   '532',
#   'Traffic',
#   '$124,115,725',
#   '2000'],
#  'The Birdcage': ['/title/tt0115685/?ref_=bo_cso_table_133',
#   '533',
#   'The Birdcage',
#   '$124,060,553',
#   '1996'],
#  'City Slickers': ['/title/tt0101587/?ref_=bo_cso_table_134',
#   '534',
#   'City Slickers',
#   '$124,033,791',
#   '1991'],
#  'Good Morning, Vietnam': ['/title/tt0093105/?ref_=bo_cso_table_135',
#   '535',
#   'Good Morning, Vietnam',
#   '$123,922,370',
#   '1987'],
#  'Rango': ['/title/tt1192628/?ref_=bo_cso_table_136',
#   '536',
#   'Rango',
#   '$123,477,607',
#   '2011'],
#  'Nutty Professor II: The Klumps': ['/title/tt0144528/?ref_=bo_cso_table_137',
#   '537',
#   'Nutty Professor II: The Klumps',
#   '$123,309,890',
#   '2000'],
#  'The Good Dinosaur': ['/title/tt1979388/?ref_=bo_cso_table_138',
#   '538',
#   'The Good Dinosaur',
#   '$123,087,120',
#   '2015'],
#  'G.I. Joe: Retaliation': ['/title/tt1583421/?ref_=bo_cso_table_139',
#   '539',
#   'G.I. Joe: Retaliation',
#   '$122,523,060',
#   '2013'],
#  'Clear and Present Danger': ['/title/tt0109444/?ref_=bo_cso_table_140',
#   '540',
#   'Clear and Present Danger',
#   '$122,187,717',
#   '1994'],
#  'The Hunt for Red October': ['/title/tt0099810/?ref_=bo_cso_table_141',
#   '541',
#   'The Hunt for Red October',
#   '$122,012,643',
#   '1990'],
#  'The Bodyguard': ['/title/tt0103855/?ref_=bo_cso_table_142',
#   '542',
#   'The Bodyguard',
#   '$122,006,740',
#   '1992'],
#  "Wayne's World": ['/title/tt0105793/?ref_=bo_cso_table_143',
#   '543',
#   "Wayne's World",
#   '$121,697,323',
#   '1992'],
#  'The Bourne Identity': ['/title/tt0258463/?ref_=bo_cso_table_144',
#   '544',
#   'The Bourne Identity',
#   '$121,661,683',
#   '2002'],
#  'Superbad': ['/title/tt0829482/?ref_=bo_cso_table_145',
#   '545',
#   'Superbad',
#   '$121,463,226',
#   '2007'],
#  'Speed': ['/title/tt0111257/?ref_=bo_cso_table_146',
#   '546',
#   'Speed',
#   '$121,248,145',
#   '1994'],
#  '50 First Dates': ['/title/tt0343660/?ref_=bo_cso_table_147',
#   '547',
#   '50 First Dates',
#   '$120,908,074',
#   '2004'],
#  'Mamma Mia! Here We Go Again': ['/title/tt6911608/?ref_=bo_cso_table_148',
#   '548',
#   'Mamma Mia! Here We Go Again',
#   '$120,634,935',
#   '2018'],
#  'Mulan': ['/title/tt0120762/?ref_=bo_cso_table_149',
#   '549',
#   'Mulan',
#   '$120,620,254',
#   '1998'],
#  'Inglourious Basterds': ['/title/tt0361748/?ref_=bo_cso_table_150',
#   '550',
#   'Inglourious Basterds',
#   '$120,540,719',
#   '2009'],
#  'Seabiscuit': ['/title/tt0329575/?ref_=bo_cso_table_151',
#   '551',
#   'Seabiscuit',
#   '$120,277,854',
#   '2003'],
#  'Van Helsing': ['/title/tt0338526/?ref_=bo_cso_table_152',
#   '552',
#   'Van Helsing',
#   '$120,177,084',
#   '2004'],
#  'Four Christmases': ['/title/tt0369436/?ref_=bo_cso_table_153',
#   '553',
#   'Four Christmases',
#   '$120,146,040',
#   '2008'],
#  'I Now Pronounce You Chuck & Larry': ['/title/tt0762107/?ref_=bo_cso_table_154',
#   '554',
#   'I Now Pronounce You Chuck & Larry',
#   '$120,059,556',
#   '2007'],
#  'The Mask': ['/title/tt0110475/?ref_=bo_cso_table_155',
#   '555',
#   'The Mask',
#   '$119,938,730',
#   '1994'],
#  'Cloudy with a Chance of Meatballs 2': ['/title/tt1985966/?ref_=bo_cso_table_156',
#   '556',
#   'Cloudy with a Chance of Meatballs 2',
#   '$119,793,567',
#   '2013'],
#  'Hook': ['/title/tt0102057/?ref_=bo_cso_table_157',
#   '557',
#   'Hook',
#   '$119,654,823',
#   '1991'],
#  'Blazing Saddles': ['/title/tt0071230/?ref_=bo_cso_table_158',
#   '558',
#   'Blazing Saddles',
#   '$119,601,481',
#   '1974'],
#  'Walk the Line': ['/title/tt0358273/?ref_=bo_cso_table_159',
#   '559',
#   'Walk the Line',
#   '$119,519,402',
#   '2005'],
#  'G-Force': ['/title/tt0436339/?ref_=bo_cso_table_160',
#   '560',
#   'G-Force',
#   '$119,436,770',
#   '2009'],
#  'Total Recall': ['/title/tt0100802/?ref_=bo_cso_table_161',
#   '561',
#   'Total Recall',
#   '$119,412,921',
#   '1990'],
#  'On Golden Pond': ['/title/tt0082846/?ref_=bo_cso_table_162',
#   '562',
#   'On Golden Pond',
#   '$119,285,432',
#   '1981'],
#  'The Other Guys': ['/title/tt1386588/?ref_=bo_cso_table_163',
#   '563',
#   'The Other Guys',
#   '$119,219,978',
#   '2010'],
#  'Fahrenheit 9/11': ['/title/tt0361596/?ref_=bo_cso_table_164',
#   '564',
#   'Fahrenheit 9/11',
#   '$119,194,771',
#   '2004'],
#  'Back to the Future Part II': ['/title/tt0096874/?ref_=bo_cso_table_165',
#   '565',
#   'Back to the Future Part II',
#   '$119,000,002',
#   '1989'],
#  'The Sum of All Fears': ['/title/tt0164184/?ref_=bo_cso_table_166',
#   '566',
#   'The Sum of All Fears',
#   '$118,907,036',
#   '2002'],
#  'Hairspray': ['/title/tt0427327/?ref_=bo_cso_table_167',
#   '567',
#   'Hairspray',
#   '$118,871,849',
#   '2007'],
#  'The Break-Up': ['/title/tt0452594/?ref_=bo_cso_table_168',
#   '568',
#   'The Break-Up',
#   '$118,703,275',
#   '2006'],
#  'A Series of Unfortunate Events': ['/title/tt0339291/?ref_=bo_cso_table_169',
#   '569',
#   'A Series of Unfortunate Events',
#   '$118,634,549',
#   '2004'],
#  'Blades of Glory': ['/title/tt0445934/?ref_=bo_cso_table_170',
#   '570',
#   'Blades of Glory',
#   '$118,594,548',
#   '2007'],
#  'Salt': ['/title/tt0944835/?ref_=bo_cso_table_171',
#   '571',
#   'Salt',
#   '$118,311,368',
#   '2010'],
#  'Basic Instinct': ['/title/tt0103772/?ref_=bo_cso_table_172',
#   '572',
#   'Basic Instinct',
#   '$117,727,224',
#   '1992'],
#  'Now You See Me': ['/title/tt1670345/?ref_=bo_cso_table_173',
#   '573',
#   'Now You See Me',
#   '$117,723,989',
#   '2013'],
#  'Ford v Ferrari': ['/title/tt1950186/?ref_=bo_cso_table_174',
#   '574',
#   'Ford v Ferrari',
#   '$117,624,357',
#   '2019'],
#  "Big Momma's House": ['/title/tt0208003/?ref_=bo_cso_table_175',
#   '575',
#   "Big Momma's House",
#   '$117,559,438',
#   '2000'],
#  'Die Hard 2': ['/title/tt0099423/?ref_=bo_cso_table_176',
#   '576',
#   'Die Hard 2',
#   '$117,540,947',
#   '1990'],
#  'Horrible Bosses': ['/title/tt1499658/?ref_=bo_cso_table_177',
#   '577',
#   'Horrible Bosses',
#   '$117,538,559',
#   '2011'],
#  'The Nun': ['/title/tt5814060/?ref_=bo_cso_table_178',
#   '578',
#   'The Nun',
#   '$117,450,119',
#   '2018'],
#  'Rocky': ['/title/tt0075148/?ref_=bo_cso_table_179',
#   '579',
#   'Rocky',
#   '$117,235,147',
#   '1976'],
#  'Jackass 3D': ['/title/tt1116184/?ref_=bo_cso_table_180',
#   '580',
#   'Jackass 3D',
#   '$117,229,692',
#   '2010'],
#  "Ocean's Thirteen": ['/title/tt0496806/?ref_=bo_cso_table_181',
#   '581',
#   "Ocean's Thirteen",
#   '$117,154,724',
#   '2007'],
#  'S.W.A.T.': ['/title/tt0257076/?ref_=bo_cso_table_182',
#   '582',
#   'S.W.A.T.',
#   '$116,934,650',
#   '2003'],
#  'The Wolf of Wall Street': ['/title/tt0993846/?ref_=bo_cso_table_183',
#   '583',
#   'The Wolf of Wall Street',
#   '$116,900,694',
#   '2013'],
#  '8 Mile': ['/title/tt0298203/?ref_=bo_cso_table_184',
#   '584',
#   '8 Mile',
#   '$116,750,901',
#   '2002'],
#  'Double Jeopardy': ['/title/tt0150377/?ref_=bo_cso_table_185',
#   '585',
#   'Double Jeopardy',
#   '$116,741,558',
#   '1999'],
#  "Lee Daniels' The Butler": ['/title/tt1327773/?ref_=bo_cso_table_186',
#   '586',
#   "Lee Daniels' The Butler",
#   '$116,632,095',
#   '2013'],
#  'Green Lantern': ['/title/tt1133985/?ref_=bo_cso_table_187',
#   '587',
#   'Green Lantern',
#   '$116,601,172',
#   '2011'],
#  'Notting Hill': ['/title/tt0125439/?ref_=bo_cso_table_188',
#   '588',
#   'Notting Hill',
#   '$116,089,678',
#   '1999'],
#  'The Towering Inferno': ['/title/tt0072308/?ref_=bo_cso_table_189',
#   '589',
#   'The Towering Inferno',
#   '$116,000,000',
#   '1974'],
#  "You've Got Mail": ['/title/tt0128853/?ref_=bo_cso_table_190',
#   '590',
#   "You've Got Mail",
#   '$115,821,495',
#   '1998'],
#  'Ghost Rider': ['/title/tt0259324/?ref_=bo_cso_table_191',
#   '591',
#   'Ghost Rider',
#   '$115,802,596',
#   '2007'],
#  'Creed II': ['/title/tt6343314/?ref_=bo_cso_table_192',
#   '592',
#   'Creed II',
#   '$115,715,889',
#   '2018'],
#  'Remember the Titans': ['/title/tt0210945/?ref_=bo_cso_table_193',
#   '593',
#   'Remember the Titans',
#   '$115,654,751',
#   '2000'],
#  'District 9': ['/title/tt1136608/?ref_=bo_cso_table_194',
#   '594',
#   'District 9',
#   '$115,646,235',
#   '2009'],
#  'Unbroken': ['/title/tt1809398/?ref_=bo_cso_table_195',
#   '595',
#   'Unbroken',
#   '$115,637,895',
#   '2014'],
#  'Peter Rabbit': ['/title/tt5117670/?ref_=bo_cso_table_196',
#   '596',
#   'Peter Rabbit',
#   '$115,253,424',
#   '2018'],
#  'Big': ['/title/tt0094737/?ref_=bo_cso_table_197',
#   '597',
#   'Big',
#   '$115,227,281',
#   '1988'],
#  'Girls Trip': ['/title/tt3564472/?ref_=bo_cso_table_198',
#   '598',
#   'Girls Trip',
#   '$115,171,585',
#   '2017'],
#  'The Karate Kid Part II': ['/title/tt0091326/?ref_=bo_cso_table_199',
#   '599',
#   'The Karate Kid Part II',
#   '$115,103,979',
#   '1986'],
#  'American Graffiti': ['/title/tt0069704/?ref_=bo_cso_table_200',
#   '600',
#   'American Graffiti',
#   '$115,000,000',
#   '1973']}

# %%
top_movies = pd.DataFrame(movies).T  #transpose
top_movies.columns = ['link_stub', 'rank_all_movies','title', 
                    'lifetime_gross', 'year']

top_movies.shape
# Out:
# (200, 5)

# %%
def get_movie_value(soup, field_name):
    
    '''Grab a value from Box Office Mojo HTML
    
    Takes a string attribute of a movie on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    
    if not obj: 
        return None
    
        # this works for most of the values
    next_element = obj.findNext()
    
    if next_element:
        return next_element.text 
    else:
        return None

# %%
import dateutil.parser

def money_to_int(moneystring):
    if moneystring:
        moneystring = moneystring.replace('$', '').replace(',', '')
        return int(moneystring)
    else:
        pass

def runtime_to_minutes(runtimestring):
    runtime = runtimestring.split()
    try:
        minutes = int(runtime[0])*60 + int(runtime[2])
        return minutes
    except:
        return None

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

def clean_genres(genre_list):
    genres = [item.strip() for item in genre_list if item.strip()]
    return genres

# %%
def clean_sales(lst):
    
    '''Clean the summary domestic/international summary table
    
    Takes the raw list of money strings and converts each item to int
    '''
    
    sale_list = [item.text for item in lst]
    
    sale_list = [money_to_int(item) for item in sale_list]
   
    return sale_list


def clean_regions(lst):
    
    '''Clean the summary domestic/international summary table
    
    Takes raw list of region string, cleans, and puts back into list
    '''
    
    region_list = [item.text for item in lst]
    region_list = [item.strip() for item in region_list if item.split()]
    region_list = [item.split('(')[0].strip() for item in region_list]
    
    return region_list

# %%
def get_movie_dict(link):
    '''
    From BoxOfficeMojo link stub, request movie html, parse with BeautifulSoup, and
    collect 
        - title 
        - domestic distributor
        - budget
        - domestic gross
        - earliest release
        - runtime 
        - MPAA rating
        - full release date
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.boxofficemojo.com'
    
    #Create full url to scrape
    url = base_url + link
    
    #Request HTML and parse
    response = requests.get(url)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['movie_title', 'domestic_distributor','budget', 'domestic_opening_sales',
               'earliest_release',
               'rating', 'runtime_minutes','genres','summary_sales','crew_list','cast_list']
    
    #Get title
    title_string = soup.find('title').text
    title = title_string.split('-')[0].strip()
    
    #Get domestic distributor
    domdist_regex = re.compile('Domestic Distributor')
    domdist_string = soup.find(text=domdist_regex).findNext().text
    domestic_dist = domdist_string.split('See')[0].strip()
    
    # Domestic distributor
    domestic_dist = get_movie_value(soup,'Domestic Distributor').split('See')[0].strip()

    # Budget
    raw_budget = get_movie_value(soup,'Budget')
    budget = money_to_int(raw_budget)

    # Domestic opening sales
    raw_domestic_opening = get_movie_value(soup,'Domestic Opening')
    domestic_opening_sales = money_to_int(raw_domestic_opening)

    #Earliest release date (raw)
    earliest_release_str = get_movie_value(soup,'Earliest Release').split('\n')[0].strip()
    earliest_release = datetime.strptime(earliest_release_str, '%B %d, %Y')
    earliest_release.strftime('%Y-%m-%d')

    #Rating
    rating = get_movie_value(soup,'MPAA')

    # Runtime
    raw_runtime = get_movie_value(soup,'Running Time')
    runtime_minutes = runtime_to_minutes(raw_runtime)

    #Genres
    raw_genres = get_movie_value(soup, 'Genres').split('\n')
    genres = clean_genres(raw_genres)
    
    #Sales list (domestic, international, worldwide)
    raw_sales_list = soup.find(class_='mojo-performance-summary-table').find_all('span', class_='money')[0:]
    sales_list = clean_sales(raw_sales_list)
    
    # Regions list
    raw_sales_regions = soup.find(class_='mojo-performance-summary-table').find_all('span', class_='a-size-small')[0:]
    regions_list = clean_regions(raw_sales_regions)
    
    # Zip region and associated sales per region - believe should solve for any missing regions
    summary_sales = [list(i) for i in zip(regions_list,sales_list)]
    
    #Find link for cast and crew
    credits = soup.find('a', class_='a-size-base a-link-normal mojo-navigation-tab',href=True)
    credits_href = str(credits.get('href'))
    credits_url = base_url + credits_href
    
    #Refer to cast and crew page
    response1 = requests.get(credits_url,headers = user_agent)
    page1 = response1.text
    soup1 = BeautifulSoup(page1, 'lxml')
    
    #Find crew table, cast table
    table_crew = soup1.find('table',id='principalCrew').find_all('td')
    table_cast = soup1.find('table',id='principalCast').find_all('td')
    
    #clean the tables
    def clean_credits(table1):
        lst1 = [item.text for item in table1]
        lst2 = [item.split('\n')[0].strip() for item in lst1]
        lst2 = [item for item in lst2[::2]]

        return lst2

    crew_list = clean_credits(table_crew)
    cast_list = clean_credits(table_cast)
    
    #Create movie dictionary and return
    movie_dict = dict(zip(headers, [title, domestic_dist, budget,domestic_opening_sales,
                                    earliest_release,
                                    rating, runtime_minutes,genres,summary_sales,crew_list,cast_list]))

    return movie_dict

# %%
top_movies_page_info_list = []

for link in top_movies.link_stub:
    top_movies_page_info_list.append(get_movie_dict(link))

# %%
top_movies_page_info = pd.DataFrame(top_movies_page_info_list)  #convert list of dict to df
top_movies_page_info.set_index('movie_title', inplace=True)

# %%
top_movies_page_info.to_csv('mojo_pg3.csv')

# %%
top_movies_page_info.head()
# Out:
#                             domestic_distributor       budget  \
# movie_title
# The Fast and the Furious      Universal Pictures   38000000.0
# Mamma Mia!                    Universal Pictures   52000000.0
# Doctor Dolittle            Twentieth Century Fox          NaN
# Pokémon Detective Pikachu           Warner Bros.  150000000.0
# Rio                        Twentieth Century Fox   90000000.0
#
#                            domestic_opening_sales earliest_release rating  \
# movie_title
# The Fast and the Furious               40089015.0       2001-06-22  PG-13
# Mamma Mia!                             27751240.0       2008-06-27  PG-13
# Doctor Dolittle                        29014324.0       1998-06-26  PG-13
# Pokémon Detective Pikachu              54365242.0       2019-05-03     PG
# Rio                                    39225962.0       2011-04-04     PG
#
#                            runtime_minutes  \
# movie_title
# The Fast and the Furious             106.0
# Mamma Mia!                           108.0
# Doctor Dolittle                       85.0
# Pokémon Detective Pikachu            104.0
# Rio                                   96.0
#
#                                                                       genres  \
# movie_title
# The Fast and the Furious                           [Action, Crime, Thriller]
# Mamma Mia!                                        [Comedy, Musical, Romance]
# Doctor Dolittle                                    [Comedy, Family, Fantasy]
# Pokémon Detective Pikachu  [Action, Adventure, Comedy, Family, Mystery, S...
# Rio                        [Adventure, Animation, Comedy, Crime, Family, ...
#
#                                                                summary_sales  \
# movie_title
# The Fast and the Furious   [[Domestic, 144533925], [International, 627677...
# Mamma Mia!                 [[Domestic, 144169664], [International, 465745...
# Doctor Dolittle            [[Domestic, 144156605], [International, 150300...
# Pokémon Detective Pikachu  [[Domestic, 144105346], [International, 288900...
# Rio                        [[Domestic, 143619809], [International, 340246...
#
#                                                                    crew_list  \
# movie_title
# The Fast and the Furious   [Rob Cohen, Ken Li, Gary Scott Thompson, Gary ...
# Mamma Mia!                 [Phyllida Lloyd, Catherine Johnson, Catherine ...
# Doctor Dolittle            [Betty Thomas, Hugh Lofting, Nat Mauldin, Larr...
# Pokémon Detective Pikachu  [Rob Letterman, Dan Hernandez, Benji Samit, Ro...
# Rio                        [Carlos Saldanha, Carlos Saldanha, Earl Richey...
#
#                                                                    cast_list
# movie_title
# The Fast and the Furious   [Vin Diesel, Paul Walker, Michelle Rodriguez, ...
# Mamma Mia!                 [Meryl Streep, Pierce Brosnan, Amanda Seyfried...
# Doctor Dolittle            [Eddie Murphy, Peter Boyle, Ossie Davis, Olive...
# Pokémon Detective Pikachu  [Ryan Reynolds, Justice Smith, Kathryn Newton,...
# Rio                        [Jesse Eisenberg, Anne Hathaway, George Lopez,...

# %%
top_movies_page_info['domestic_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'Domestic'])
top_movies_page_info['international_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'International'])
top_movies_page_info['worldwide_sales'] = top_movies_page_info['summary_sales'].apply(lambda x: [y[1] for y in x if y[0] == 'Worldwide'])

# %%
top_movies_page_info.head()
# Out:
#                             domestic_distributor       budget  \
# movie_title
# The Fast and the Furious      Universal Pictures   38000000.0
# Mamma Mia!                    Universal Pictures   52000000.0
# Doctor Dolittle            Twentieth Century Fox          NaN
# Pokémon Detective Pikachu           Warner Bros.  150000000.0
# Rio                        Twentieth Century Fox   90000000.0
#
#                            domestic_opening_sales earliest_release rating  \
# movie_title
# The Fast and the Furious               40089015.0       2001-06-22  PG-13
# Mamma Mia!                             27751240.0       2008-06-27  PG-13
# Doctor Dolittle                        29014324.0       1998-06-26  PG-13
# Pokémon Detective Pikachu              54365242.0       2019-05-03     PG
# Rio                                    39225962.0       2011-04-04     PG
#
#                            runtime_minutes  \
# movie_title
# The Fast and the Furious             106.0
# Mamma Mia!                           108.0
# Doctor Dolittle                       85.0
# Pokémon Detective Pikachu            104.0
# Rio                                   96.0
#
#                                                                       genres  \
# movie_title
# The Fast and the Furious                           [Action, Crime, Thriller]
# Mamma Mia!                                        [Comedy, Musical, Romance]
# Doctor Dolittle                                    [Comedy, Family, Fantasy]
# Pokémon Detective Pikachu  [Action, Adventure, Comedy, Family, Mystery, S...
# Rio                        [Adventure, Animation, Comedy, Crime, Family, ...
#
#                                                                summary_sales  \
# movie_title
# The Fast and the Furious   [[Domestic, 144533925], [International, 627677...
# Mamma Mia!                 [[Domestic, 144169664], [International, 465745...
# Doctor Dolittle            [[Domestic, 144156605], [International, 150300...
# Pokémon Detective Pikachu  [[Domestic, 144105346], [International, 288900...
# Rio                        [[Domestic, 143619809], [International, 340246...
#
#                                                                    crew_list  \
# movie_title
# The Fast and the Furious   [Rob Cohen, Ken Li, Gary Scott Thompson, Gary ...
# Mamma Mia!                 [Phyllida Lloyd, Catherine Johnson, Catherine ...
# Doctor Dolittle            [Betty Thomas, Hugh Lofting, Nat Mauldin, Larr...
# Pokémon Detective Pikachu  [Rob Letterman, Dan Hernandez, Benji Samit, Ro...
# Rio                        [Carlos Saldanha, Carlos Saldanha, Earl Richey...
#
#                                                                    cast_list  \
# movie_title
# The Fast and the Furious   [Vin Diesel, Paul Walker, Michelle Rodriguez, ...
# Mamma Mia!                 [Meryl Streep, Pierce Brosnan, Amanda Seyfried...
# Doctor Dolittle            [Eddie Murphy, Peter Boyle, Ossie Davis, Olive...
# Pokémon Detective Pikachu  [Ryan Reynolds, Justice Smith, Kathryn Newton,...
# Rio                        [Jesse Eisenberg, Anne Hathaway, George Lopez,...
#
#                           domestic_sales international_sales worldwide_sales
# movie_title
# The Fast and the Furious     [144533925]          [62767742]     [207301667]
# Mamma Mia!                   [144169664]         [465745071]     [609914735]
# Doctor Dolittle              [144156605]         [150300000]     [294456605]
# Pokémon Detective Pikachu    [144105346]         [288900000]     [433005346]
# Rio                          [143619809]         [340246709]     [483866518]
