# %%
import pandas as pd
import numpy as np
from ast import literal_eval
from datetime import datetime

# %%
df1 = pd.read_csv('data/budget1.csv')
df2 = pd.read_csv('data/budget2.csv')
df3 = pd.read_csv('data/budget3.csv')
df4 = pd.read_csv('data/budget4.csv')
df5 = pd.read_csv('data/budget5.csv')
df6 = pd.read_csv('data/budget6.csv')
df7 = pd.read_csv('data/budget7.csv')
df8 = pd.read_csv('data/budget8.csv')
df9 = pd.read_csv('data/budget8.csv')
df10 = pd.read_csv('data/budget10.csv')

# %%
df_all = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10])
df_all.shape
# Out:
# (987, 8)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 987 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       987 non-null    object
#  1   link_stub        987 non-null    object
#  2   rank_all_movies  987 non-null    object
#  3   release          987 non-null    object
#  4   title            987 non-null    object
#  5   budget           987 non-null    int64
#  6   domestic_gross   987 non-null    object
#  7   worldwide_gross  987 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 69.4+ KB

# %%
df_all.to_csv('budget-all.csv')

# %%
df_all.sample(10)
# Out:
#       Unnamed: 0                           link_stub rank_all_movies  \
# 29   Dec 5, 2014  /box-office-chart/daily/2014/12/05             231
# 30  Jun 30, 2016  /box-office-chart/daily/2016/06/30             232
# 18  Nov 22, 2002  /box-office-chart/daily/2002/11/22             220
# 29   Feb 3, 2021  /box-office-chart/daily/2021/02/03             430
# 42   Nov 5, 2014  /box-office-chart/daily/2014/11/05             143
# 36  Jun 10, 2005  /box-office-chart/daily/2005/06/10             337
# 35  Dec 20, 2002  /box-office-chart/daily/2002/12/20             436
# 18  Mar 12, 2010  /box-office-chart/daily/2010/03/12             419
# 41  Dec 10, 2004  /box-office-chart/daily/2004/12/10             342
# 59  May 21, 2014  /box-office-chart/daily/2014/05/21              60
#
#          release                       title     budget domestic_gross  \
# 29   Dec 5, 2014      Exodus: Gods and Kings  140000000    $65,014,513
# ...
