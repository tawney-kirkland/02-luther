# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %%
url = 'https://www.boxofficemojo.com/chart/mpaa_title_lifetime_gross/?by_mpaa=PG-13&ref_=bo_cso_ac'

response2 = requests.get(url)
page2 = response2.text

soup2 = BeautifulSoup(page2,"lxml")

# %%
table = soup2.find('table')

# %%
rows = [row for row in table.find_all('tr')]

# %%
movies = {}

for row in rows[1:]:
    items = row.find_all('td')
    link = row.find('a')
    title, url = link.text, link['href']
    movies[title] = [url] + [i.text for i in items]
    
movies
# Out:
# {'Star Wars: Episode VII - The Force Awakens': ['/title/tt2488496/?ref_=bo_cso_table_1',
#   'Star Wars: Episode VII - The Force Awakens',
#   '1',
#   '$936,662,225',
#   '1',
#   '2015'],
#  'Avengers: Endgame': ['/title/tt4154796/?ref_=bo_cso_table_2',
#   'Avengers: Endgame',
#   '2',
#   '$858,373,000',
#   '2',
#   '2019'],
#  'Avatar': ['/title/tt0499549/?ref_=bo_cso_table_3',
#   'Avatar',
#   '3',
#   '$760,507,625',
#   '3',
#   '2009'],
#  'Black Panther': ['/title/tt1825683/?ref_=bo_cso_table_4',
#   'Black Panther',
#   '4',
#   '$700,426,566',
#   '4',
#   '2018'],
#  'Avengers: Infinity War': ['/title/tt4154756/?ref_=bo_cso_table_5',
#   'Avengers: Infinity War',
#   '5',
#   '$678,815,482',
#   '5',
#   '2018'],
#  'Titanic': ['/title/tt0120338/?ref_=bo_cso_table_6',
#   'Titanic',
#   '6',
#   '$659,363,944',
#   '6',
#   '1997'],
#  'Jurassic World': ['/title/tt0369610/?ref_=bo_cso_table_7',
#   'Jurassic World',
#   '7',
#   '$652,295,625',
#   '7',
#   '2015'],
#  'The Avengers': ['/title/tt0848228/?ref_=bo_cso_table_8',
#   'The Avengers',
#   '8',
#   '$623,357,910',
#   '8',
#   '2012'],
#  'Star Wars: Episode VIII - The Last Jedi': ['/title/tt2527336/?ref_=bo_cso_table_9',
#   'Star Wars: Episode VIII - The Last Jedi',
#   '9',
#   '$620,181,382',
#   '9',
#   '2017'],
#  'The Dark Knight': ['/title/tt0468569/?ref_=bo_cso_table_10',
#   'The Dark Knight',
#   '10',
#   '$534,858,444',
#   '12',
#   '2008'],
#  'Rogue One: A Star Wars Story': ['/title/tt3748528/?ref_=bo_cso_table_11',
#   'Rogue One: A Star Wars Story',
#   '11',
#   '$532,177,324',
#   '13',
#   '2016'],
#  'Star Wars: Episode IX - The Rise of Skywalker': ['/title/tt2527338/?ref_=bo_cso_table_12',
#   'Star Wars: Episode IX - The Rise of Skywalker',
#   '12',
#   '$515,202,542',
#   '14',
#   '2019'],
#  'Avengers: Age of Ultron': ['/title/tt2395427/?ref_=bo_cso_table_13',
#   'Avengers: Age of Ultron',
#   '13',
#   '$459,005,868',
#   '20',
#   '2015'],
#  'The Dark Knight Rises': ['/title/tt1345836/?ref_=bo_cso_table_14',
#   'The Dark Knight Rises',
#   '14',
#   '$448,139,099',
#   '21',
#   '2012'],
#  'Captain Marvel': ['/title/tt4154664/?ref_=bo_cso_table_15',
#   'Captain Marvel',
#   '15',
#   '$426,829,839',
#   '25',
#   '2019'],
#  'The Hunger Games: Catching Fire': ['/title/tt1951264/?ref_=bo_cso_table_16',
#   'The Hunger Games: Catching Fire',
#   '16',
#   '$424,668,047',
#   '26',
#   '2013'],
#  "Pirates of the Caribbean: Dead Man's Chest": ['/title/tt0383574/?ref_=bo_cso_table_17',
#   "Pirates of the Caribbean: Dead Man's Chest",
#   '17',
#   '$423,315,812',
#   '27',
#   '2006'],
#  'Jurassic World: Fallen Kingdom': ['/title/tt4881806/?ref_=bo_cso_table_18',
#   'Jurassic World: Fallen Kingdom',
#   '18',
#   '$417,719,760',
#   '29',
#   '2018'],
#  'Wonder Woman': ['/title/tt0451279/?ref_=bo_cso_table_19',
#   'Wonder Woman',
#   '19',
#   '$412,815,408',
#   '31',
#   '2017'],
#  'Iron Man 3': ['/title/tt1300854/?ref_=bo_cso_table_20',
#   'Iron Man 3',
#   '20',
#   '$409,013,994',
#   '32',
#   '2013'],
#  'Captain America: Civil War': ['/title/tt3498820/?ref_=bo_cso_table_21',
#   'Captain America: Civil War',
#   '21',
#   '$408,084,349',
#   '33',
#   '2016'],
#  'The Hunger Games': ['/title/tt1392170/?ref_=bo_cso_table_22',
#   'The Hunger Games',
#   '22',
#   '$408,010,692',
#   '34',
#   '2012'],
#  'Spider-Man': ['/title/tt0145487/?ref_=bo_cso_table_23',
#   'Spider-Man',
#   '23',
#   '$407,022,860',
#   '35',
#   '2002'],
#  'Jumanji: Welcome to the Jungle': ['/title/tt2283362/?ref_=bo_cso_table_24',
#   'Jumanji: Welcome to the Jungle',
#   '24',
#   '$404,540,171',
#   '36',
#   '2017'],
#  'Jurassic Park': ['/title/tt0107290/?ref_=bo_cso_table_25',
#   'Jurassic Park',
#   '25',
#   '$404,214,720',
#   '37',
#   '1993'],
#  'Transformers: Revenge of the Fallen': ['/title/tt1055369/?ref_=bo_cso_table_26',
#   'Transformers: Revenge of the Fallen',
#   '26',
#   '$402,111,870',
#   '38',
#   '2009'],
#  'Spider-Man: Far from Home': ['/title/tt6320628/?ref_=bo_cso_table_27',
#   'Spider-Man: Far from Home',
#   '27',
#   '$390,532,085',
#   '40',
#   '2019'],
#  'Guardians of the Galaxy Vol. 2': ['/title/tt3896198/?ref_=bo_cso_table_28',
#   'Guardians of the Galaxy Vol. 2',
#   '28',
#   '$389,813,101',
#   '41',
#   '2017'],
#  'Harry Potter and the Deathly Hallows: Part 2': ['/title/tt1201607/?ref_=bo_cso_table_29',
#   'Harry Potter and the Deathly Hallows: Part 2',
#   '29',
#   '$381,409,310',
#   '42',
#   '2011'],
#  'Star Wars: Episode III - Revenge of the Sith': ['/title/tt0121766/?ref_=bo_cso_table_30',
#   'Star Wars: Episode III - Revenge of the Sith',
#   '30',
#   '$380,270,577',
#   '44',
#   '2005'],
#  'The Lord of the Rings: The Return of the King': ['/title/tt0167260/?ref_=bo_cso_table_31',
#   'The Lord of the Rings: The Return of the King',
#   '31',
#   '$377,845,905',
#   '45',
#   '2003'],
#  'Spider-Man 2': ['/title/tt0316654/?ref_=bo_cso_table_32',
#   'Spider-Man 2',
#   '32',
#   '$373,585,825',
#   '46',
#   '2004'],
#  'Furious 7': ['/title/tt2820852/?ref_=bo_cso_table_33',
#   'Furious 7',
#   '33',
#   '$353,007,020',
#   '54',
#   '2015'],
#  'Transformers: Dark of the Moon': ['/title/tt1399103/?ref_=bo_cso_table_34',
#   'Transformers: Dark of the Moon',
#   '34',
#   '$352,390,543',
#   '55',
#   '2011'],
#  'The Lord of the Rings: The Two Towers': ['/title/tt0167261/?ref_=bo_cso_table_35',
#   'The Lord of the Rings: The Two Towers',
#   '35',
#   '$342,551,365',
#   '57',
#   '2002'],
#  'The Hunger Games: Mockingjay - Part 1': ['/title/tt1951265/?ref_=bo_cso_table_36',
#   'The Hunger Games: Mockingjay - Part 1',
#   '36',
#   '$337,135,885',
#   '59',
#   '2014'],
#  'Spider-Man 3': ['/title/tt0413300/?ref_=bo_cso_table_37',
#   'Spider-Man 3',
#   '37',
#   '$336,530,303',
#   '60',
#   '2007'],
#  'Aquaman': ['/title/tt1477834/?ref_=bo_cso_table_38',
#   'Aquaman',
#   '38',
#   '$335,061,807',
#   '63',
#   '2018'],
#  'Spider-Man: Homecoming': ['/title/tt2250912/?ref_=bo_cso_table_39',
#   'Spider-Man: Homecoming',
#   '39',
#   '$334,201,140',
#   '64',
#   '2017'],
#  'Guardians of the Galaxy': ['/title/tt2015381/?ref_=bo_cso_table_40',
#   'Guardians of the Galaxy',
#   '40',
#   '$333,718,600',
#   '66',
#   '2014'],
#  'Forrest Gump': ['/title/tt0109830/?ref_=bo_cso_table_41',
#   'Forrest Gump',
#   '41',
#   '$330,455,270',
#   '67',
#   '1994'],
#  'Batman v Superman: Dawn of Justice': ['/title/tt2975590/?ref_=bo_cso_table_42',
#   'Batman v Superman: Dawn of Justice',
#   '42',
#   '$330,360,194',
#   '68',
#   '2016'],
#  'Suicide Squad': ['/title/tt1386697/?ref_=bo_cso_table_43',
#   'Suicide Squad',
#   '43',
#   '$325,100,054',
#   '70',
#   '2016'],
#  'Jumanji: The Next Level': ['/title/tt7975244/?ref_=bo_cso_table_44',
#   'Jumanji: The Next Level',
#   '44',
#   '$320,314,960',
#   '73',
#   '2019'],
#  'Transformers': ['/title/tt0418279/?ref_=bo_cso_table_45',
#   'Transformers',
#   '45',
#   '$319,246,193',
#   '74',
#   '2007'],
#  'Iron Man': ['/title/tt0371746/?ref_=bo_cso_table_46',
#   'Iron Man',
#   '46',
#   '$319,034,126',
#   '75',
#   '2008'],
#  'Indiana Jones and the Kingdom of the Crystal Skull': ['/title/tt0367882/?ref_=bo_cso_table_47',
#   'Indiana Jones and the Kingdom of the Crystal Skull',
#   '47',
#   '$317,101,119',
#   '77',
#   '2008'],
#  'The Lord of the Rings: The Fellowship of the Ring': ['/title/tt0120737/?ref_=bo_cso_table_48',
#   'The Lord of the Rings: The Fellowship of the Ring',
#   '48',
#   '$315,544,750',
#   '78',
#   '2001'],
#  'Thor: Ragnarok': ['/title/tt3501632/?ref_=bo_cso_table_49',
#   'Thor: Ragnarok',
#   '49',
#   '$315,058,289',
#   '79',
#   '2017'],
#  'Iron Man 2': ['/title/tt1228705/?ref_=bo_cso_table_50',
#   'Iron Man 2',
#   '50',
#   '$312,433,331',
#   '80',
#   '2010'],
#  "Pirates of the Caribbean: At World's End": ['/title/tt0449088/?ref_=bo_cso_table_51',
#   "Pirates of the Caribbean: At World's End",
#   '51',
#   '$309,420,425',
#   '82',
#   '2007'],
#  'Independence Day': ['/title/tt0116629/?ref_=bo_cso_table_52',
#   'Independence Day',
#   '52',
#   '$306,169,268',
#   '84',
#   '1996'],
#  'Pirates of the Caribbean: The Curse of the Black Pearl': ['/title/tt0325980/?ref_=bo_cso_table_53',
#   'Pirates of the Caribbean: The Curse of the Black Pearl',
#   '53',
#   '$305,413,918',
#   '85',
#   '2003'],
#  'Skyfall': ['/title/tt1074638/?ref_=bo_cso_table_54',
#   'Skyfall',
#   '54',
#   '$304,360,277',
#   '86',
#   '2012'],
#  'The Hobbit: An Unexpected Journey': ['/title/tt0903624/?ref_=bo_cso_table_55',
#   'The Hobbit: An Unexpected Journey',
#   '55',
#   '$303,003,568',
#   '87',
#   '2012'],
#  'The Twilight Saga: Eclipse': ['/title/tt1325004/?ref_=bo_cso_table_56',
#   'The Twilight Saga: Eclipse',
#   '56',
#   '$300,531,751',
#   '89',
#   '2010'],
#  'The Twilight Saga: New Moon': ['/title/tt1259571/?ref_=bo_cso_table_57',
#   'The Twilight Saga: New Moon',
#   '57',
#   '$297,816,253',
#   '90',
#   '2009'],
#  'Harry Potter and the Deathly Hallows: Part 1': ['/title/tt0926084/?ref_=bo_cso_table_58',
#   'Harry Potter and the Deathly Hallows: Part 1',
#   '58',
#   '$296,347,721',
#   '91',
#   '2010'],
#  'The Sixth Sense': ['/title/tt0167404/?ref_=bo_cso_table_59',
#   'The Sixth Sense',
#   '59',
#   '$293,506,292',
#   '92',
#   '1999'],
#  'Inception': ['/title/tt1375666/?ref_=bo_cso_table_60',
#   'Inception',
#   '60',
#   '$292,576,195',
#   '95',
#   '2010'],
#  'Harry Potter and the Order of the Phoenix': ['/title/tt0373889/?ref_=bo_cso_table_61',
#   'Harry Potter and the Order of the Phoenix',
#   '61',
#   '$292,353,413',
#   '96',
#   '2007'],
#  'The Twilight Saga: Breaking Dawn - Part 2': ['/title/tt1673434/?ref_=bo_cso_table_62',
#   'The Twilight Saga: Breaking Dawn - Part 2',
#   '62',
#   '$292,324,737',
#   '97',
#   '2012'],
#  'Man of Steel': ['/title/tt0770828/?ref_=bo_cso_table_63',
#   'Man of Steel',
#   '63',
#   '$291,045,518',
#   '99',
#   '2013'],
#  'Harry Potter and the Goblet of Fire': ['/title/tt0330373/?ref_=bo_cso_table_64',
#   'Harry Potter and the Goblet of Fire',
#   '64',
#   '$290,417,905',
#   '101',
#   '2005'],
#  'The Hunger Games: Mockingjay - Part 2': ['/title/tt1951266/?ref_=bo_cso_table_65',
#   'The Hunger Games: Mockingjay - Part 2',
#   '65',
#   '$281,723,902',
#   '103',
#   '2015'],
#  'The Twilight Saga: Breaking Dawn - Part 1': ['/title/tt1324999/?ref_=bo_cso_table_66',
#   'The Twilight Saga: Breaking Dawn - Part 1',
#   '66',
#   '$281,287,133',
#   '105',
#   '2011'],
#  'Meet the Fockers': ['/title/tt0290002/?ref_=bo_cso_table_67',
#   'Meet the Fockers',
#   '67',
#   '$279,261,160',
#   '106',
#   '2004'],
#  'Gravity': ['/title/tt1454468/?ref_=bo_cso_table_68',
#   'Gravity',
#   '68',
#   '$274,092,705',
#   '108',
#   '2013'],
#  'The Amazing Spider-Man': ['/title/tt0948470/?ref_=bo_cso_table_69',
#   'The Amazing Spider-Man',
#   '69',
#   '$262,030,663',
#   '115',
#   '2012'],
#  'Captain America: The Winter Soldier': ['/title/tt1843866/?ref_=bo_cso_table_70',
#   'Captain America: The Winter Soldier',
#   '70',
#   '$259,766,572',
#   '119',
#   '2014'],
#  'The Hobbit: The Desolation of Smaug': ['/title/tt1170358/?ref_=bo_cso_table_71',
#   'The Hobbit: The Desolation of Smaug',
#   '71',
#   '$258,366,855',
#   '120',
#   '2013'],
#  'Star Trek': ['/title/tt0796366/?ref_=bo_cso_table_72',
#   'Star Trek',
#   '72',
#   '$257,730,019',
#   '122',
#   '2009'],
#  'I Am Legend': ['/title/tt0480249/?ref_=bo_cso_table_73',
#   'I Am Legend',
#   '73',
#   '$256,393,010',
#   '123',
#   '2007'],
#  'The Blind Side': ['/title/tt0878804/?ref_=bo_cso_table_74',
#   'The Blind Side',
#   '74',
#   '$255,959,475',
#   '124',
#   '2009'],
#  'The Hobbit: The Battle of the Five Armies': ['/title/tt2310332/?ref_=bo_cso_table_75',
#   'The Hobbit: The Battle of the Five Armies',
#   '75',
#   '$255,119,788',
#   '125',
#   '2014'],
#  'Batman': ['/title/tt0096895/?ref_=bo_cso_table_76',
#   'Batman',
#   '76',
#   '$251,348,343',
#   '128',
#   '1989'],
#  'Men in Black': ['/title/tt0119654/?ref_=bo_cso_table_77',
#   'Men in Black',
#   '77',
#   '$250,690,539',
#   '130',
#   '1997'],
#  'Transformers: Age of Extinction': ['/title/tt2109248/?ref_=bo_cso_table_78',
#   'Transformers: Age of Extinction',
#   '78',
#   '$245,439,076',
#   '135',
#   '2014'],
#  'Bruce Almighty': ['/title/tt0315327/?ref_=bo_cso_table_79',
#   'Bruce Almighty',
#   '79',
#   '$242,829,261',
#   '138',
#   '2003'],
#  'Twister': ['/title/tt0117998/?ref_=bo_cso_table_80',
#   'Twister',
#   '80',
#   '$241,721,524',
#   '139',
#   '1996'],
#  'Pirates of the Caribbean: On Stranger Tides': ['/title/tt1298650/?ref_=bo_cso_table_81',
#   'Pirates of the Caribbean: On Stranger Tides',
#   '81',
#   '$241,071,802',
#   '142',
#   '2011'],
#  'Fast & Furious 6': ['/title/tt1905041/?ref_=bo_cso_table_82',
#   'Fast & Furious 6',
#   '82',
#   '$238,679,850',
#   '144',
#   '2013'],
#  'X-Men: The Last Stand': ['/title/tt0376994/?ref_=bo_cso_table_83',
#   'X-Men: The Last Stand',
#   '83',
#   '$234,362,462',
#   '148',
#   '2006'],
#  'War of the Worlds': ['/title/tt0407304/?ref_=bo_cso_table_84',
#   'War of the Worlds',
#   '84',
#   '$234,280,354',
#   '149',
#   '2005'],
#  'Fantastic Beasts and Where to Find Them': ['/title/tt3183660/?ref_=bo_cso_table_85',
#   'Fantastic Beasts and Where to Find Them',
#   '85',
#   '$234,037,575',
#   '150',
#   '2016'],
#  'X-Men: Days of Future Past': ['/title/tt1877832/?ref_=bo_cso_table_86',
#   'X-Men: Days of Future Past',
#   '86',
#   '$233,921,534',
#   '151',
#   '2014'],
#  'Cast Away': ['/title/tt0162222/?ref_=bo_cso_table_87',
#   'Cast Away',
#   '87',
#   '$233,632,142',
#   '152',
#   '2000'],
#  'Doctor Strange': ['/title/tt1211837/?ref_=bo_cso_table_88',
#   'Doctor Strange',
#   '88',
#   '$232,641,920',
#   '154',
#   '2016'],
#  'The Lost World: Jurassic Park': ['/title/tt0119567/?ref_=bo_cso_table_89',
#   'The Lost World: Jurassic Park',
#   '89',
#   '$229,086,679',
#   '155',
#   '1997'],
#  'Justice League': ['/title/tt0974015/?ref_=bo_cso_table_90',
#   'Justice League',
#   '90',
#   '$229,024,295',
#   '156',
#   '2017'],
#  'Star Trek Into Darkness': ['/title/tt1408101/?ref_=bo_cso_table_91',
#   'Star Trek Into Darkness',
#   '91',
#   '$228,778,661',
#   '157',
#   '2013'],
#  'The Martian': ['/title/tt3659388/?ref_=bo_cso_table_92',
#   'The Martian',
#   '92',
#   '$228,433,663',
#   '158',
#   '2015'],
#  'Signs': ['/title/tt0286106/?ref_=bo_cso_table_93',
#   'Signs',
#   '93',
#   '$227,966,634',
#   '159',
#   '2002'],
#  'Hancock': ['/title/tt0448157/?ref_=bo_cso_table_94',
#   'Hancock',
#   '94',
#   '$227,946,274',
#   '160',
#   '2008'],
#  'The Bourne Ultimatum': ['/title/tt0440963/?ref_=bo_cso_table_95',
#   'The Bourne Ultimatum',
#   '95',
#   '$227,471,070',
#   '161',
#   '2007'],
#  'Rush Hour 2': ['/title/tt0266915/?ref_=bo_cso_table_96',
#   'Rush Hour 2',
#   '96',
#   '$226,164,286',
#   '163',
#   '2001'],
#  'The Fate of the Furious': ['/title/tt4630562/?ref_=bo_cso_table_97',
#   'The Fate of the Furious',
#   '97',
#   '$226,008,385',
#   '164',
#   '2017'],
#  'Mission: Impossible - Fallout': ['/title/tt4912910/?ref_=bo_cso_table_98',
#   'Mission: Impossible - Fallout',
#   '98',
#   '$220,159,104',
#   '168',
#   '2018'],
#  'Mrs. Doubtfire': ['/title/tt0107614/?ref_=bo_cso_table_99',
#   'Mrs. Doubtfire',
#   '99',
#   '$219,195,243',
#   '171',
#   '1993'],
#  'King Kong': ['/title/tt0360717/?ref_=bo_cso_table_100',
#   'King Kong',
#   '100',
#   '$218,080,025',
#   '174',
#   '2005'],
#  'Ghost': ['/title/tt0099653/?ref_=bo_cso_table_101',
#   'Ghost',
#   '101',
#   '$217,631,306',
#   '175',
#   '1990'],
#  'The Da Vinci Code': ['/title/tt0382625/?ref_=bo_cso_table_102',
#   'The Da Vinci Code',
#   '102',
#   '$217,536,138',
#   '177',
#   '2006'],
#  'Bohemian Rhapsody': ['/title/tt1727824/?ref_=bo_cso_table_103',
#   'Bohemian Rhapsody',
#   '103',
#   '$216,668,042',
#   '181',
#   '2018'],
#  'Ant-Man and the Wasp': ['/title/tt5095030/?ref_=bo_cso_table_104',
#   'Ant-Man and the Wasp',
#   '104',
#   '$216,648,740',
#   '182',
#   '2018'],
#  'Mission: Impossible II': ['/title/tt0120755/?ref_=bo_cso_table_105',
#   'Mission: Impossible II',
#   '105',
#   '$215,409,889',
#   '185',
#   '2000'],
#  'X2: X-Men United': ['/title/tt0290334/?ref_=bo_cso_table_106',
#   'X2: X-Men United',
#   '106',
#   '$214,949,694',
#   '187',
#   '2003'],
#  'Solo: A Star Wars Story': ['/title/tt3778644/?ref_=bo_cso_table_107',
#   'Solo: A Star Wars Story',
#   '107',
#   '$213,767,512',
#   '189',
#   '2018'],
#  'Venom': ['/title/tt1270797/?ref_=bo_cso_table_108',
#   'Venom',
#   '108',
#   '$213,515,506',
#   '190',
#   '2018'],
#  'Austin Powers in Goldmember': ['/title/tt0295178/?ref_=bo_cso_table_109',
#   'Austin Powers in Goldmember',
#   '109',
#   '$213,307,889',
#   '191',
#   '2002'],
#  'Fast Five': ['/title/tt1596343/?ref_=bo_cso_table_110',
#   'Fast Five',
#   '110',
#   '$209,837,675',
#   '196',
#   '2011'],
#  'Mission: Impossible - Ghost Protocol': ['/title/tt1229238/?ref_=bo_cso_table_111',
#   'Mission: Impossible - Ghost Protocol',
#   '111',
#   '$209,397,903',
#   '197',
#   '2011'],
#  'Sherlock Holmes': ['/title/tt0988045/?ref_=bo_cso_table_112',
#   'Sherlock Holmes',
#   '112',
#   '$209,028,679',
#   '199',
#   '2009'],
#  'Dawn of the Planet of the Apes': ['/title/tt2103281/?ref_=bo_cso_table_113',
#   'Dawn of the Planet of the Apes',
#   '113',
#   '$208,545,589',
#   '200',
#   '2014'],
#  'Batman Begins': ['/title/tt0372784/?ref_=bo_cso_table_114',
#   'Batman Begins',
#   '114',
#   '$206,852,432',
#   '201',
#   '2005'],
#  'Thor: The Dark World': ['/title/tt1981115/?ref_=bo_cso_table_115',
#   'Thor: The Dark World',
#   '115',
#   '$206,362,140',
#   '204',
#   '2013'],
#  'Austin Powers: The Spy Who Shagged Me': ['/title/tt0145660/?ref_=bo_cso_table_116',
#   'Austin Powers: The Spy Who Shagged Me',
#   '116',
#   '$206,040,086',
#   '206',
#   '1999'],
#  'The Amazing Spider-Man 2': ['/title/tt1872181/?ref_=bo_cso_table_117',
#   'The Amazing Spider-Man 2',
#   '117',
#   '$202,853,933',
#   '208',
#   '2014'],
#  'World War Z': ['/title/tt0816711/?ref_=bo_cso_table_118',
#   'World War Z',
#   '118',
#   '$202,359,711',
#   '209',
#   '2013'],
#  'The Mummy Returns': ['/title/tt0209163/?ref_=bo_cso_table_119',
#   'The Mummy Returns',
#   '119',
#   '$202,019,785',
#   '210',
#   '2001'],
#  'Armageddon': ['/title/tt0120591/?ref_=bo_cso_table_120',
#   'Armageddon',
#   '120',
#   '$201,578,182',
#   '211',
#   '1998'],
#  'Godzilla': ['/title/tt0831387/?ref_=bo_cso_table_121',
#   'Godzilla',
#   '121',
#   '$200,676,069',
#   '216',
#   '2014'],
#  'Superman Returns': ['/title/tt0348150/?ref_=bo_cso_table_122',
#   'Superman Returns',
#   '122',
#   '$200,081,192',
#   '217',
#   '2006'],
#  'Spectre': ['/title/tt2379713/?ref_=bo_cso_table_123',
#   'Spectre',
#   '123',
#   '$200,074,609',
#   '218',
#   '2015'],
#  'Pearl Harbor': ['/title/tt0213149/?ref_=bo_cso_table_124',
#   'Pearl Harbor',
#   '124',
#   '$198,542,554',
#   '219',
#   '2001'],
#  'Indiana Jones and the Last Crusade': ['/title/tt0097576/?ref_=bo_cso_table_125',
#   'Indiana Jones and the Last Crusade',
#   '125',
#   '$197,171,806',
#   '222',
#   '1989'],
#  'Mission: Impossible - Rogue Nation': ['/title/tt2381249/?ref_=bo_cso_table_126',
#   'Mission: Impossible - Rogue Nation',
#   '126',
#   '$195,042,377',
#   '225',
#   '2015'],
#  'Twilight': ['/title/tt1099212/?ref_=bo_cso_table_127',
#   'Twilight',
#   '127',
#   '$193,962,473',
#   '226',
#   '2008'],
#  'Men in Black II': ['/title/tt0120912/?ref_=bo_cso_table_128',
#   'Men in Black II',
#   '128',
#   '$193,735,288',
#   '227',
#   '2002'],
#  'Teenage Mutant Ninja Turtles': ['/title/tt1291150/?ref_=bo_cso_table_129',
#   'Teenage Mutant Ninja Turtles',
#   '129',
#   '$191,204,754',
#   '231',
#   '2014'],
#  'Dunkirk': ['/title/tt5013056/?ref_=bo_cso_table_130',
#   'Dunkirk',
#   '130',
#   '$189,740,665',
#   '234',
#   '2017'],
#  'A Quiet Place': ['/title/tt6644200/?ref_=bo_cso_table_131',
#   'A Quiet Place',
#   '131',
#   '$188,024,361',
#   '236',
#   '2018'],
#  'Interstellar': ['/title/tt0816692/?ref_=bo_cso_table_132',
#   'Interstellar',
#   '132',
#   '$188,020,017',
#   '237',
#   '2014'],
#  'Sherlock Holmes: A Game of Shadows': ['/title/tt1515091/?ref_=bo_cso_table_133',
#   'Sherlock Holmes: A Game of Shadows',
#   '133',
#   '$186,848,418',
#   '241',
#   '2011'],
#  'The Day After Tomorrow': ['/title/tt0319262/?ref_=bo_cso_table_134',
#   'The Day After Tomorrow',
#   '134',
#   '$186,740,799',
#   '242',
#   '2004'],
#  'Mr. & Mrs. Smith': ['/title/tt0356910/?ref_=bo_cso_table_135',
#   'Mr. & Mrs. Smith',
#   '135',
#   '$186,336,279',
#   '243',
#   '2005'],
#  'Pitch Perfect 2': ['/title/tt2848292/?ref_=bo_cso_table_136',
#   'Pitch Perfect 2',
#   '136',
#   '$184,296,230',
#   '245',
#   '2015'],
#  'Dances with Wolves': ['/title/tt0099348/?ref_=bo_cso_table_137',
#   'Dances with Wolves',
#   '137',
#   '$184,208,848',
#   '246',
#   '1990'],
#  'Batman Forever': ['/title/tt0112462/?ref_=bo_cso_table_138',
#   'Batman Forever',
#   '138',
#   '$184,069,126',
#   '247',
#   '1995'],
#  'The Fugitive': ['/title/tt0106977/?ref_=bo_cso_table_139',
#   'The Fugitive',
#   '139',
#   '$183,875,760',
#   '248',
#   '1993'],
#  "Ocean's Eleven": ['/title/tt0240772/?ref_=bo_cso_table_140',
#   "Ocean's Eleven",
#   '140',
#   '$183,417,150',
#   '250',
#   '2001'],
#  'The Simpsons Movie': ['/title/tt0462538/?ref_=bo_cso_table_141',
#   'The Simpsons Movie',
#   '141',
#   '$183,135,014',
#   '251',
#   '2007'],
#  'What Women Want': ['/title/tt0207201/?ref_=bo_cso_table_142',
#   'What Women Want',
#   '142',
#   '$182,811,707',
#   '252',
#   '2000'],
#  'The Perfect Storm': ['/title/tt0177971/?ref_=bo_cso_table_143',
#   'The Perfect Storm',
#   '143',
#   '$182,618,434',
#   '253',
#   '2000'],
#  'Lincoln': ['/title/tt0443272/?ref_=bo_cso_table_144',
#   'Lincoln',
#   '144',
#   '$182,207,973',
#   '254',
#   '2012'],
#  'Liar Liar': ['/title/tt0119528/?ref_=bo_cso_table_145',
#   'Liar Liar',
#   '145',
#   '$181,410,615',
#   '255',
#   '1997'],
#  'Jurassic Park III': ['/title/tt0163025/?ref_=bo_cso_table_146',
#   'Jurassic Park III',
#   '146',
#   '$181,171,875',
#   '256',
#   '2001'],
#  'Thor': ['/title/tt0800369/?ref_=bo_cso_table_147',
#   'Thor',
#   '147',
#   '$181,030,624',
#   '257',
#   '2011'],
#  'Mission: Impossible': ['/title/tt0117060/?ref_=bo_cso_table_148',
#   'Mission: Impossible',
#   '148',
#   '$180,981,856',
#   '258',
#   '1996'],
#  'Ant-Man': ['/title/tt0478970/?ref_=bo_cso_table_149',
#   'Ant-Man',
#   '149',
#   '$180,202,163',
#   '259',
#   '2015'],
#  'Planet of the Apes': ['/title/tt0133152/?ref_=bo_cso_table_150',
#   'Planet of the Apes',
#   '150',
#   '$180,011,740',
#   '260',
#   '2001'],
#  'X-Men Origins: Wolverine': ['/title/tt0458525/?ref_=bo_cso_table_151',
#   'X-Men Origins: Wolverine',
#   '151',
#   '$179,883,157',
#   '262',
#   '2009'],
#  'Hitch': ['/title/tt0386588/?ref_=bo_cso_table_152',
#   'Hitch',
#   '152',
#   '$179,495,555',
#   '265',
#   '2005'],
#  'Men in Black 3': ['/title/tt1409024/?ref_=bo_cso_table_153',
#   'Men in Black 3',
#   '153',
#   '$179,020,854',
#   '266',
#   '2012'],
#  'Rise of the Planet of the Apes': ['/title/tt1318514/?ref_=bo_cso_table_154',
#   'Rise of the Planet of the Apes',
#   '154',
#   '$176,760,185',
#   '272',
#   '2011'],
#  'Captain America: The First Avenger': ['/title/tt0458339/?ref_=bo_cso_table_155',
#   'Captain America: The First Avenger',
#   '155',
#   '$176,654,505',
#   '273',
#   '2011'],
#  'The Bourne Supremacy': ['/title/tt0372183/?ref_=bo_cso_table_156',
#   'The Bourne Supremacy',
#   '156',
#   '$176,241,941',
#   '278',
#   '2004'],
#  'Crocodile Dundee': ['/title/tt0090555/?ref_=bo_cso_table_157',
#   'Crocodile Dundee',
#   '157',
#   '$174,803,506',
#   '283',
#   '1986'],
#  'Crazy Rich Asians': ['/title/tt3104988/?ref_=bo_cso_table_158',
#   'Crazy Rich Asians',
#   '158',
#   '$174,532,921',
#   '284',
#   '2018'],
#  'Fast & Furious Presents: Hobbs & Shaw': ['/title/tt6806448/?ref_=bo_cso_table_159',
#   'Fast & Furious Presents: Hobbs & Shaw',
#   '159',
#   '$173,956,935',
#   '286',
#   '2019'],
#  'Pirates of the Caribbean: Dead Men Tell No Tales': ['/title/tt1790809/?ref_=bo_cso_table_160',
#   'Pirates of the Caribbean: Dead Men Tell No Tales',
#   '160',
#   '$172,558,876',
#   '292',
#   '2017'],
#  'True Grit': ['/title/tt1403865/?ref_=bo_cso_table_161',
#   'True Grit',
#   '161',
#   '$171,243,005',
#   '296',
#   '2010'],
#  'A Beautiful Mind': ['/title/tt0268978/?ref_=bo_cso_table_162',
#   'A Beautiful Mind',
#   '162',
#   '$170,742,341',
#   '299',
#   '2001'],
#  'Chicago': ['/title/tt0299658/?ref_=bo_cso_table_163',
#   'Chicago',
#   '163',
#   '$170,687,518',
#   '300',
#   '2002'],
#  'The Help': ['/title/tt1454029/?ref_=bo_cso_table_164',
#   'The Help',
#   '164',
#   '$169,708,112',
#   '301',
#   '2011'],
#  'Quantum of Solace': ['/title/tt0830515/?ref_=bo_cso_table_165',
#   'Quantum of Solace',
#   '165',
#   '$168,368,427',
#   '305',
#   '2008'],
#  'Wild Hogs': ['/title/tt0486946/?ref_=bo_cso_table_166',
#   'Wild Hogs',
#   '166',
#   '$168,273,550',
#   '306',
#   '2007'],
#  'Kong: Skull Island': ['/title/tt3731562/?ref_=bo_cso_table_167',
#   'Kong: Skull Island',
#   '167',
#   '$168,052,812',
#   '307',
#   '2017'],
#  'Casino Royale': ['/title/tt0381061/?ref_=bo_cso_table_168',
#   'Casino Royale',
#   '168',
#   '$167,445,960',
#   '311',
#   '2006'],
#  'Meet the Parents': ['/title/tt0212338/?ref_=bo_cso_table_169',
#   'Meet the Parents',
#   '169',
#   '$166,244,045',
#   '312',
#   '2000'],
#  '2012': ['/title/tt1190080/?ref_=bo_cso_table_170',
#   '2012',
#   '170',
#   '$166,112,167',
#   '314',
#   '2009'],
#  'Robin Hood: Prince of Thieves': ['/title/tt0102798/?ref_=bo_cso_table_171',
#   'Robin Hood: Prince of Thieves',
#   '171',
#   '$165,493,908',
#   '315',
#   '1991'],
#  'Knives Out': ['/title/tt8946378/?ref_=bo_cso_table_172',
#   'Knives Out',
#   '172',
#   '$165,363,234',
#   '316',
#   '2019'],
#  'Catch Me If You Can': ['/title/tt0264464/?ref_=bo_cso_table_173',
#   'Catch Me If You Can',
#   '173',
#   '$164,615,351',
#   '319',
#   '2002'],
#  'The Proposal': ['/title/tt1041829/?ref_=bo_cso_table_174',
#   'The Proposal',
#   '174',
#   '$163,958,031',
#   '320',
#   '2009'],
#  'The Pursuit of Happyness': ['/title/tt0454921/?ref_=bo_cso_table_175',
#   'The Pursuit of Happyness',
#   '175',
#   '$163,566,459',
#   '321',
#   '2006'],
#  'Big Daddy': ['/title/tt0142342/?ref_=bo_cso_table_176',
#   'Big Daddy',
#   '176',
#   '$163,479,795',
#   '322',
#   '1999'],
#  'Clash of the Titans': ['/title/tt0800320/?ref_=bo_cso_table_177',
#   'Clash of the Titans',
#   '177',
#   '$163,214,888',
#   '323',
#   '2010'],
#  'Batman Returns': ['/title/tt0103776/?ref_=bo_cso_table_178',
#   'Batman Returns',
#   '178',
#   '$162,902,340',
#   '325',
#   '1992'],
#  'Jason Bourne': ['/title/tt4196776/?ref_=bo_cso_table_179',
#   'Jason Bourne',
#   '179',
#   '$162,434,410',
#   '328',
#   '2016'],
#  'Grown Ups': ['/title/tt1375670/?ref_=bo_cso_table_180',
#   'Grown Ups',
#   '180',
#   '$162,001,186',
#   '329',
#   '2010'],
#  'The Waterboy': ['/title/tt0120484/?ref_=bo_cso_table_181',
#   'The Waterboy',
#   '181',
#   '$161,491,646',
#   '330',
#   '1998'],
#  'Die Another Day': ['/title/tt0246460/?ref_=bo_cso_table_182',
#   'Die Another Day',
#   '182',
#   '$160,942,139',
#   '333',
#   '2002'],
#  'Fantastic Beasts: The Crimes of Grindelwald': ['/title/tt4123430/?ref_=bo_cso_table_183',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   '183',
#   '$159,555,901',
#   '337',
#   '2018'],
#  'Star Trek Beyond': ['/title/tt2660888/?ref_=bo_cso_table_184',
#   'Star Trek Beyond',
#   '184',
#   '$158,848,340',
#   '342',
#   '2016'],
#  'The Longest Yard': ['/title/tt0398165/?ref_=bo_cso_table_185',
#   'The Longest Yard',
#   '185',
#   '$158,119,460',
#   '344',
#   '2005'],
#  'X-Men': ['/title/tt0120903/?ref_=bo_cso_table_186',
#   'X-Men',
#   '186',
#   '$157,299,718',
#   '345',
#   '2000'],
#  'What Lies Beneath': ['/title/tt0161081/?ref_=bo_cso_table_187',
#   'What Lies Beneath',
#   '187',
#   '$155,464,351',
#   '350',
#   '2000'],
#  'X-Men: Apocalypse': ['/title/tt3385516/?ref_=bo_cso_table_188',
#   'X-Men: Apocalypse',
#   '188',
#   '$155,442,489',
#   '351',
#   '2016'],
#  'The Mummy': ['/title/tt0120616/?ref_=bo_cso_table_189',
#   'The Mummy',
#   '189',
#   '$155,385,488',
#   '352',
#   '1999'],
#  'Snow White and the Huntsman': ['/title/tt1735898/?ref_=bo_cso_table_190',
#   'Snow White and the Huntsman',
#   '190',
#   '$155,332,381',
#   '353',
#   '2012'],
#  'San Andreas': ['/title/tt2126355/?ref_=bo_cso_table_191',
#   'San Andreas',
#   '191',
#   '$155,190,832',
#   '354',
#   '2015'],
#  'Fast & Furious': ['/title/tt1013752/?ref_=bo_cso_table_192',
#   'Fast & Furious',
#   '192',
#   '$155,064,265',
#   '355',
#   '2009'],
#  'Fantastic Four': ['/title/tt0120667/?ref_=bo_cso_table_193',
#   'Fantastic Four',
#   '193',
#   '$154,696,080',
#   '357',
#   '2005'],
#  'La La Land': ['/title/tt3783958/?ref_=bo_cso_table_194',
#   'La La Land',
#   '194',
#   '$151,101,803',
#   '368',
#   '2016'],
#  'Divergent': ['/title/tt1840309/?ref_=bo_cso_table_195',
#   'Divergent',
#   '195',
#   '$150,947,895',
#   '369',
#   '2014'],
#  "Daddy's Home": ['/title/tt1528854/?ref_=bo_cso_table_196',
#   "Daddy's Home",
#   '196',
#   '$150,357,137',
#   '373',
#   '2015'],
#  'G.I. Joe: The Rise of Cobra': ['/title/tt1046173/?ref_=bo_cso_table_197',
#   'G.I. Joe: The Rise of Cobra',
#   '197',
#   '$150,201,498',
#   '374',
#   '2009'],
#  'Les Misérables': ['/title/tt1707386/?ref_=bo_cso_table_198',
#   'Les Misérables',
#   '198',
#   '$148,809,770',
#   '379',
#   '2012'],
#  'As Good as It Gets': ['/title/tt0119822/?ref_=bo_cso_table_199',
#   'As Good as It Gets',
#   '199',
#   '$148,478,011',
#   '381',
#   '1997'],
#  'Little Fockers': ['/title/tt0970866/?ref_=bo_cso_table_200',
#   'Little Fockers',
#   '200',
#   '$148,438,600',
#   '382',
#   '2010']}

# %%
g_movies = pd.DataFrame(movies).T  #transpose
g_movies.columns = ['link_stub', 'title', 'rank_g_movies', 
                    'lifetime_gross', 'rank_overall', 'year']

g_movies.head()
# Out:
#                                                                         link_stub  \
# Star Wars: Episode VII - The Force Awakens  /title/tt2488496/?ref_=bo_cso_table_1
# Avengers: Endgame                           /title/tt4154796/?ref_=bo_cso_table_2
# Avatar                                      /title/tt0499549/?ref_=bo_cso_table_3
# Black Panther                               /title/tt1825683/?ref_=bo_cso_table_4
# Avengers: Infinity War                      /title/tt4154756/?ref_=bo_cso_table_5
#
#                                                                                  title  \
# Star Wars: Episode VII - The Force Awakens  Star Wars: Episode VII - The Force Awakens
# Avengers: Endgame                                                    Avengers: Endgame
# Avatar                                                                          Avatar
# Black Panther                                                            Black Panther
# Avengers: Infinity War                                          Avengers: Infinity War
#
#                                            rank_g_movies lifetime_gross  \
# Star Wars: Episode VII - The Force Awakens             1   $936,662,225
# Avengers: Endgame                                      2   $858,373,000
# Avatar                                                 3   $760,507,625
# Black Panther                                          4   $700,426,566
# Avengers: Infinity War                                 5   $678,815,482
#
#                                            rank_overall  year
# Star Wars: Episode VII - The Force Awakens            1  2015
# Avengers: Endgame                                     2  2019
# Avatar                                                3  2009
# Black Panther                                         4  2018
# Avengers: Infinity War                                5  2018
