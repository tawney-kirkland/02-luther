# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, OneHotEncoder
import seaborn as sns
import datetime as dt
from datetime import datetime
import statsmodels.api as sm
import statsmodels.formula.api as smf
import scipy.stats as stats
from statsmodels.sandbox.regression.predstd import wls_prediction_std

# %%
df = pd.read_csv('data/master_data_with_sequel_director.csv')

# %%
df['release_date'] = pd.to_datetime(df['release_date'])
df['year'] = pd.DatetimeIndex(df['release_date']).year

# %%
df['returnb'] = df['domestic_gross'] / df['budget']
df.sort_values('budget',ascending=False).head(50)
# Out:
#      Unnamed: 0                                       movie_title  \
# 1             1                                 Avengers: Endgame
# 7             7                           Star Wars: Episode VIII
# 71           72          Pirates of the Caribbean: At World's End
# 4             4                            Avengers: Infinity War
# 130         135                                    Justice League
# 158         165                           Solo: A Star Wars Story
# 11           11                             Star Wars: Episode IX
# 181         193                                  Superman Returns
# 179         188                                           Tangled
# 50           51                                      Spider-Man 3
# 138         143                           The Fate of the Furious
# 108         112         The Hobbit: The Battle of the Five Armies
# 75           76                         Harry Potter and the Half
# 57           58                Batman v Superman: Dawn of Justice
# 119         123       Pirates of the Caribbean: On Stranger Tides
# 14           14                           Avengers: Age of Ultron
# 15           15                             The Dark Knight Rises
# 103         107               The Hobbit: The Desolation of Smaug
# 25           25                        Captain America: Civil War
# 182         194                                           Spectre
# 0             0                            Star Wars: Episode VII
# 2             2                                            Avatar
# 99          103                            The Amazing Spider-Man
# 239         253  Pirates of the Caribbean: Dead Men Tell No Tales
# 20           20        Pirates of the Caribbean: Dead Man's Chest
# 332         348          The Chronicles of Narnia: Prince Caspian
# 221         235                                    Men in Black 3
# 84           86                                      Man of Steel
# 6             6                                      The Avengers
# 377         393                     Transformers: The Last Knight
# 123         127                         Oz the Great and Powerful
# 627         646                                   The Lone Ranger
# 124         129                             X-Men: The Last Stand
# 114         118                   Transformers: Age of Extinction
# 145         152                                         King Kong
# 250         264                                 Quantum of Solace
# 345         361                                 A Christmas Carol
# 237         251             Fast & Furious Presents: Hobbs & Shaw
# 69           70                                        Iron Man 2
# 275         289       Fantastic Beasts: The Crimes of Grindelwald
# 95           99                               Monsters University
# 55           56                               Alice in Wonderland
# 258         272                                              2012
# 73           74                                           Skyfall
# 449         465                                     Green Lantern
# 74           75                 The Hobbit: An Unexpected Journey
# 403         419                              Terminator Salvation
# 299         315                Terminator 3: Rise of the Machines
# 29           29               Transformers: Revenge of the Fallen
# 12           12                                      Finding Dory
#
#                     domestic_distributor     budget  domestic_opening_sales  \
# 1    Walt Disney Studios Motion Pictures  356000000               357115007
# 7    Walt Disney Studios Motion Pictures  317000000               220009584
# 71   Walt Disney Studios Motion Pictures  300000000               114732820
# 4    Walt Disney Studios Motion Pictures  300000000               257698183
# 130                         Warner Bros.  300000000                93842239
# 158  Walt Disney Studios Motion Pictures  275000000                84420489
# 11   Walt Disney Studios Motion Pictures  275000000               177383864
# 181                         Warner Bros.  270000000                52535096
# 179  Walt Disney Studios Motion Pictures  260000000                48767052
# 50     Sony Pictures Entertainment (SPE)  258000000               151116516
# 138                   Universal Pictures  250000000                98786705
# 108                         Warner Bros.  250000000                54724334
# 75                          Warner Bros.  250000000                77835727
# 57                          Warner Bros.  250000000               166007347
# 119  Walt Disney Studios Motion Pictures  250000000                90151958
# 627       2013-07-03  PG-13            150.0
# 124       2006-05-24  PG-13            104.0
# 114       2014-06-25  PG-13            165.0
# 145       2005-12-14  PG-13            187.0
# 250       2008-10-31  PG-13            106.0
# 345       2009-09-09     PG             96.0
# 237       2019-07-01  PG-13            137.0
# 69        2010-04-28  PG-13            124.0
# 275       2018-10-12  PG-13            134.0
# 95        2013-06-19      G            104.0
# 55        2010-03-03     PG            108.0
# 258       2009-11-11  PG-13            158.0
# 73        2012-10-25  PG-13            143.0
# 449       2011-06-15  PG-13            114.0
# 74        2012-12-12  PG-13            169.0
# 403       2009-05-20  PG-13            115.0
# 299       2003-07-02      R            109.0
# 29        2009-06-19  PG-13            149.0
# 12        2016-06-15     PG             97.0
#
#                                                 genres  \
# 1           ['Action', 'Adventure', 'Drama', 'Sci-Fi']
# 7         ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 71                  ['Action', 'Adventure', 'Fantasy']
# 4                    ['Action', 'Adventure', 'Sci-Fi']
# 130       ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 158                  ['Action', 'Adventure', 'Sci-Fi']
# 11        ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 181                               ['Action', 'Sci-Fi']
# 179  ['Adventure', 'Animation', 'Comedy', 'Family',...
# 50                   ['Action', 'Adventure', 'Sci-Fi']
# 138       ['Action', 'Adventure', 'Crime', 'Thriller']
# 108                           ['Adventure', 'Fantasy']
# 75   ['Action', 'Adventure', 'Family', 'Fantasy', '...
# 57                   ['Action', 'Adventure', 'Sci-Fi']
# 119                 ['Action', 'Adventure', 'Fantasy']
# 14                   ['Action', 'Adventure', 'Sci-Fi']
# 15                             ['Action', 'Adventure']
# 103                           ['Adventure', 'Fantasy']
# 25                   ['Action', 'Adventure', 'Sci-Fi']
# 182                ['Action', 'Adventure', 'Thriller']
# 0                    ['Action', 'Adventure', 'Sci-Fi']
# 2         ['Action', 'Adventure', 'Fantasy', 'Sci-Fi']
# 99                   ['Action', 'Adventure', 'Sci-Fi']
# 239                 ['Action', 'Adventure', 'Fantasy']
# 20                  ['Action', 'Adventure', 'Fantasy']
# 332       ['Action', 'Adventure', 'Family', 'Fantasy']
# 221        ['Action', 'Adventure', 'Comedy', 'Sci-Fi']
# 84                   ['Action', 'Adventure', 'Sci-Fi']
# 6                    ['Action', 'Adventure', 'Sci-Fi']
# 377                  ['Action', 'Adventure', 'Sci-Fi']
# 123                 ['Adventure', 'Family', 'Fantasy']
# 627                 ['Action', 'Adventure', 'Western']
# 124                  ['Action', 'Adventure', 'Sci-Fi']
# 114                  ['Action', 'Adventure', 'Sci-Fi']
# 145        ['Action', 'Adventure', 'Drama', 'Romance']
# 250                ['Action', 'Adventure', 'Thriller']
# 345        ['Animation', 'Drama', 'Family', 'Fantasy']
# 237                ['Action', 'Adventure', 'Thriller']
# 69                   ['Action', 'Adventure', 'Sci-Fi']
# 275                 ['Adventure', 'Family', 'Fantasy']
# 95   ['Adventure', 'Animation', 'Comedy', 'Family',...
# 55                  ['Adventure', 'Family', 'Fantasy']
# 258                  ['Action', 'Adventure', 'Sci-Fi']
# 73                 ['Action', 'Adventure', 'Thriller']
# 449                  ['Action', 'Adventure', 'Sci-Fi']
# 74                            ['Adventure', 'Fantasy']
# 403                               ['Action', 'Sci-Fi']
# 299                               ['Action', 'Sci-Fi']
# 29                   ['Action', 'Adventure', 'Sci-Fi']
# 12      ['Adventure', 'Animation', 'Comedy', 'Family']
#
#                                          summary_sales  ... Gal Gadot  \
# 1    [['Domestic', 858373000], ['International', 19...  ...         0
# 7    [['Domestic', 620181382], ['International', 71...  ...         0
# 71   [['Domestic', 309420425], ['International', 65...  ...         0
# 4    [['Domestic', 678815482], ['International', 13...  ...         0
# 130  [['Domestic', 229024295], ['International', 42...  ...         1
# 158  [['Domestic', 213767512], ['International', 17...  ...         0
# 11   [['Domestic', 515202542], ['International', 55...  ...         0
# 181  [['Domestic', 200081192], ['International', 19...  ...         0
# 179  [['Domestic', 200821936], ['International', 39...  ...         0
# 50   [['Domestic', 336530303], ['International', 55...  ...         0
# 138  [['Domestic', 226008385], ['International', 10...  ...         0
# 108  [['Domestic', 255119788], ['International', 70...  ...         0
# 75   [['Domestic', 302305431], ['International', 63...  ...         0
# 57   [['Domestic', 330360194], ['International', 54...  ...         0
# 119  [['Domestic', 241071802], ['International', 80...  ...         0
# 14   [['Domestic', 459005868], ['International', 94...  ...         0
# 15   [['Domestic', 448139099], ['International', 63...  ...         0
# 103  [['Domestic', 258366855], ['International', 70...  ...         0
# 25   [['Domestic', 408084349], ['International', 74...  ...         0
# 182  [['Domestic', 200074609], ['International', 68...  ...         0
# 0    [['Domestic', 936662225], ['International', 11...  ...         0
# 2    [['Domestic', 760507625], ['International', 20...  ...         0
# 99   [['Domestic', 262030663], ['International', 49...  ...         0
# 239  [['Domestic', 172558876], ['International', 62...  ...         0
# 20   [['Domestic', 423315812], ['International', 64...  ...         0
# 332  [['Domestic', 141621490], ['International', 27...  ...         0
# 221  [['Domestic', 179020854], ['International', 44...  ...         0
# 84   [['Domestic', 291045518], ['International', 37...  ...         0
# 6    [['Domestic', 623357910], ['International', 89...  ...         0
# 377  [['Domestic', 130168683], ['International', 47...  ...         0
# 123  [['Domestic', 234911825], ['International', 25...  ...         0
# 627  [['Domestic', 89302115], ['International', 171...  ...         0
# 124  [['Domestic', 234362462], ['International', 22...  ...         0
# 114  [['Domestic', 245439076], ['International', 85...  ...         0
# 145  [['Domestic', 218080025], ['International', 34...  ...         0
# 250  [['Domestic', 168368427], ['International', 42...  ...         0
# 345  [['Domestic', 137855863], ['International', 18...  ...         0
# 237  [['Domestic', 173956935], ['International', 58...  ...         0
# 69   [['Domestic', 312433331], ['International', 31...  ...         0
# 275  [['Domestic', 159555901], ['International', 49...  ...         0
# 95   [['Domestic', 268492764], ['International', 47...  ...         0
# 55   [['Domestic', 334191110], ['International', 69...  ...         0
# 258  [['Domestic', 166112167], ['International', 62...  ...         0
# 73   [['Domestic', 304360277], ['International', 80...  ...         0
# 449  [['Domestic', 116601172], ['International', 10...  ...         0
# 74   [['Domestic', 303003568], ['International', 71...  ...         0
# 403  [['Domestic', 125322469], ['International', 24...  ...         0
# 299  [['Domestic', 150371112], ['International', 28...  ...         0
# 29   [['Domestic', 402111870], ['International', 43...  ...         0
# 12   [['Domestic', 486295561], ['International', 54...  ...         0
#
#     Angelina Jolie Jason Statham Thomas Tull Tommy Lee Jones  \
# 258                    0               1       166112167  2009  0.830561
# 73                     0               1       304360277  2012  1.521801
# 449                    0               1       116601172  2011  0.583006
# 74                     0               1       303003568  2012  1.515018
# 403                    0               0       125322469  2009  0.626612
# 299                    0               0       150371112  2003  0.751856
# 29                     0               0       402111870  2009  2.010559
# 12                     0               0       486295561  2016  2.431478
#
# [50 rows x 98 columns]

# %%
df.sort_values('budget').groupby('Horror').describe()
# Out:
#        Unnamed: 0                                                              \
#             count        mean         std   min     25%    50%     75%    max
# Horror
# 0           686.0  367.243440  213.328698   0.0  182.25  369.5  553.75  742.0
# 1            37.0  508.216216  195.875121  59.0  360.00  549.0  685.00  739.0
#
#        budget                ...    year         returnb              \
#         count          mean  ...     75%     max   count        mean
# Horror                       ...
# 0       686.0  1.009933e+08  ...  2015.0  2020.0   686.0    2.533172
# 1        37.0  3.871392e+07  ...  2017.0  2019.0    37.0  202.439801
#
#
#                 std       min       25%       50%        75%          max
# Horror
# 0          4.365821  0.415359  1.198442  1.775354   2.702282    93.383953
# 1       1181.463239  0.706840  2.228579  5.677805  11.060257  7194.587333
#
# [2 rows x 664 columns]

# %%
df1 = df[['budget','is_sequel','month','top50_d','year','bankable_count','runtime_minutes','domestic_gross']]

# %%
fig, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df1.corr(), cmap="seismic", vmin=-1, vmax=1, ax=ax);

# %%
fig, ax = plt.subplots(figsize=(15, 15))
pd.plotting.scatter_matrix(df1[df1.columns[0:]], ax=ax);
# Out:
# <ipython-input-81-0640107250d6>:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   pd.plotting.scatter_matrix(df1[df1.columns[0:]], ax=ax);

# %%
#fig, ax = plt.subplots(figsize=(9, 7))

budget_x = df['budget']
sales_y = df['domestic_gross']

plt.scatter(budget_x, sales_y)
plt.xlabel('Budget')
plt.ylabel('Opening sales')
plt.title('Budget versus domestic gross top movies from 2000 to 2020')
# Out:
# Text(0.5, 1.0, 'Budget versus domestic gross top movies from 2000 to 2020')

# %%
x = df[['budget','is_sequel','rating','top50_d','year','runtime_minutes','month','Action','Adventure','Animation','Comedy','Drama','Horror','Mystery','Romance']]


y = df['domestic_gross']

x_tr, x_test, y_tr, y_test = train_test_split(x, y,test_size=.2, random_state=5)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_tr, y_tr, test_size=.25, random_state=10)

# %%
x_budget_train = x_train[['budget']]
x_budget_val = x_val[['budget']]
x_budget_test = x_test[['budget']]

# %%
b_lr = LinearRegression()

b_lr.fit(x_budget_train, y_train)

b_lr.score(x_budget_val, y_val) #R2

y_pred = b_lr.predict(x_budget_val)
np.sqrt(mean_squared_error(y_val, y_pred))
# Out:
# 97328915.5094579

# %%
b_lr.score(x_budget_val, y_val) #R2
# Out:
# 0.35766365683765244

# %%
print('Feature coefficient results: \n')
for feature, coef in zip(x_budget_train.columns, b_lr.coef_):
        print(feature, ':', f'{coef:.2f}')
# Out:
# Feature coefficient results:
#
# budget : 0.90

# %%
x_budget_train['b2'] = x_budget_train['budget']**2
x_budget_val['b2'] = x_budget_val['budget']**2
# Out:
# <ipython-input-89-154c5e5295c1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_budget_train['b2'] = x_budget_train['budget']**2
# <ipython-input-89-154c5e5295c1>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x_budget_val['b2'] = x_budget_val['budget']**2

# %%
x_budget_train.head()
# Out:
#         budget                 b2
# 128   90000000   8100000000000000
# 254   80000000   6400000000000000
# 394   50000000   2500000000000000
# 532   34000000   1156000000000000
# 78   125000000  15625000000000000

# %%
b_lr = LinearRegression()

b_lr.fit(x_budget_train, y_train)

b_lr.score(x_budget_val, y_val) #R2

y_pred = b_lr.predict(x_budget_val)
np.sqrt(mean_squared_error(y_val, y_pred))
# Out:
# 91263547.88702409

# %%
b_lr.score(x_budget_val, y_val) #R2
# Out:
# 0.43522765516896855

# %%
print('Feature coefficient results: \n')
for feature, coef in zip(x_budget_train.columns, b_lr.coef_):
        print(feature, ':', f'{coef:.10f}')
# Out:
# Feature coefficient results:
#
# budget : 0.2141919691
# b2 : 0.0000000030

# %%
import scipy.stats as stats
x1 = df[['budget']]
y1 = df['domestic_gross']

# %%
def diagnostic_plot(x, y):
    plt.figure(figsize=(20,5))
    
    rgr = LinearRegression()
    rgr.fit(x,y)
    pred = rgr.predict(x)

    plt.subplot(1, 3, 1)
    plt.scatter(x,y)
    plt.plot(x, pred, color='blue',linewidth=1)
    plt.title("Regression fit")
    plt.xlabel("x")
    plt.ylabel("y")
    
    plt.subplot(1, 3, 2)
    res = y - pred
    plt.scatter(pred, res)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")
    
    plt.subplot(1, 3, 3)
    #Generates a probability plot of sample data against the quantiles of a 
    # specified theoretical distribution 
    stats.probplot(res, dist="norm", plot=plt)
    plt.title("Normal Q-Q plot")

# %%
diagnostic_plot(x1, y1)

# %%
model = sm.OLS(y1,x1)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:         domestic_gross   R-squared (uncentered):                   1.897
# Model:                            OLS   Adj. R-squared (uncentered):              1.899
# Method:                 Least Squares   F-statistic:                             -1527.
# Date:                Wed, 20 Jan 2021   Prob (F-statistic):                        1.00
# Time:                        09:44:17   Log-Likelihood:                         -14334.
# No. Observations:                 723   AIC:                                  2.867e+04
# Df Residuals:                     722   BIC:                                  2.868e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# budget         1.5021      0.032     47.522      0.000       1.440       1.564
# ==============================================================================
# Omnibus:                       86.457   Durbin-Watson:                   1.212
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              227.074
# Skew:                           0.622   Prob(JB):                     4.91e-50
# Kurtosis:                       5.448   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
x1['predict']=fit.predict(x1)
x1['resid']= y1-x1.predict
with sns.axes_style('white'):
    plot = x1.plot(
        kind='scatter', x='predict', y='resid', alpha=0.5, figsize=(10,6))
# Out:
# <ipython-input-115-9f06596dc521>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1['predict']=fit.predict(x1)
# <ipython-input-115-9f06596dc521>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   x1['resid']= y1-x1.predict

# %%
x1.head()
# Out:
#       budget       predict         resid
# 0  245000000  3.680063e+08  5.686560e+08
# 1  356000000  5.347356e+08  3.236374e+08
# 2  237000000  3.559897e+08  4.045179e+08
# 3  200000000  3.004133e+08  4.000133e+08
# 4  300000000  4.506199e+08  2.281956e+08

# %%
plt.scatter(x1.budget,y1)
plt.scatter(x1.budget,x1.predict);

# %%
x2 = x_train[['budget']]
y2 = y_train

# %%
nsample = 433
w = np.ones(nsample)

# %%
mod_wls = sm.WLS(y2, x2, weights=1./(w ** 2))
res_wls = mod_wls.fit()
print(res_wls.summary())
# Out:
#                                  WLS Regression Results
# =======================================================================================
# Dep. Variable:         domestic_gross   R-squared (uncentered):                   0.760
# Model:                            WLS   Adj. R-squared (uncentered):              0.759
# Method:                 Least Squares   F-statistic:                              1365.
# Date:                Wed, 20 Jan 2021   Prob (F-statistic):                   8.03e-136
# Time:                        10:56:41   Log-Likelihood:                         -8576.8
# No. Observations:                 433   AIC:                                  1.716e+04
# Df Residuals:                     432   BIC:                                  1.716e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# budget         1.5012      0.041     36.951      0.000       1.421       1.581
# ==============================================================================
# Omnibus:                       87.469   Durbin-Watson:                   1.880
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              311.047
# Skew:                           0.875   Prob(JB):                     2.86e-68
# Kurtosis:                       6.765   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Is this correct model to use?
# How to plot the above to show actual + prediction?
# Where to next?

# %%
prstd, iv_l, iv_u = wls_prediction_std(res_wls)

fig, ax = plt.subplots(figsize=(8,6))
ax.plot(x1, y1, 'o', label="Data")
#ax.plot(x1, y_train, 'b-', label="True")
# OLS
#ax.plot(x1, res_ols.fittedvalues, 'r--')
#ax.plot(x1, iv_u_ols, 'r--', label="OLS")
#ax.plot(x1, iv_l_ols, 'r--')
# WLS
ax.plot(x1, res_wls.fittedvalues, 'g--.')
ax.plot(x1, iv_u, 'g--', label="WLS")
ax.plot(x1, iv_l, 'g--')
ax.legend(loc="best");

# %%
x3 = df[['budget','is_sequel']]
y3 = df['domestic_gross']

# %%
mod_wls3 = sm.WLS(y3, x3, weights=1./(w ** 2))
res_wls3 = mod_wls3.fit()
print(res_wls3.summary())
# Out:
#                                  WLS Regression Results
# =======================================================================================
# Dep. Variable:         domestic_gross   R-squared (uncentered):                   0.763
# Model:                            WLS   Adj. R-squared (uncentered):              0.763
# Method:                 Least Squares   F-statistic:                              1163.
# Date:                Wed, 20 Jan 2021   Prob (F-statistic):                   2.50e-226
# Time:                        10:39:50   Log-Likelihood:                         -14326.
# No. Observations:                 723   AIC:                                  2.866e+04
# Df Residuals:                     721   BIC:                                  2.866e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# budget         1.3985      0.040     34.843      0.000       1.320       1.477
# is_sequel   3.422e+07   8.32e+06      4.113      0.000    1.79e+07    5.06e+07
# ==============================================================================
# Omnibus:                       87.787   Durbin-Watson:                   1.241
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              229.991
# Skew:                           0.632   Prob(JB):                     1.14e-50
# Kurtosis:                       5.457   Cond. No.                     2.66e+08
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 2.66e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x4 = df[['budget','year']]
y4 = df['domestic_gross']

# %%
mod_wls4 = sm.WLS(y4, x4, weights=1./(w ** 2))
res_wls4 = mod_wls4.fit()
print(res_wls4.summary())
# Out:
#                                  WLS Regression Results
# =======================================================================================
# Dep. Variable:         domestic_gross   R-squared (uncentered):                   0.804
# Model:                            WLS   Adj. R-squared (uncentered):              0.803
# Method:                 Least Squares   F-statistic:                              1475.
# Date:                Wed, 20 Jan 2021   Prob (F-statistic):                   1.61e-255
# Time:                        10:40:07   Log-Likelihood:                         -14259.
# No. Observations:                 723   AIC:                                  2.852e+04
# Df Residuals:                     721   BIC:                                  2.853e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# budget         0.9251      0.053     17.510      0.000       0.821       1.029
# year        3.959e+04   3053.264     12.967      0.000    3.36e+04    4.56e+04
# ==============================================================================
# Omnibus:                      323.113   Durbin-Watson:                   0.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1995.840
# Skew:                           1.922   Prob(JB):                         0.00
# Kurtosis:                      10.175   Cond. No.                     1.07e+05
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.07e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
