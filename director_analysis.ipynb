# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from ast import literal_eval
from datetime import datetime
from sklearn.preprocessing import OneHotEncoder
from fuzzywuzzy import fuzz
import fuzzymatcher

# %%
df = pd.read_csv('data/director.csv')

# %%
df
# Out:
#      Unnamed: 0                  movie_title     budget  \
# 0             0       Star Wars: Episode VII  245000000
# 1             1            Avengers: Endgame  356000000
# 2             2                       Avatar  237000000
# 3             3                Black Panther  200000000
# 4             4       Avengers: Infinity War  300000000
# ..          ...                          ...        ...
# 718         738                 Jack Reacher   60000000
# 719         739                  Cloverfield   25000000
# 720         740                    Dear John   25000000
# 721         741  Men in Black: International  110000000
# 722         742                      Knowing   50000000
#
#      domestic_opening_sales               director
# 0                 247966675            J.J. Abrams
# 1                 357115007          Anthony Russo
# 2                  77025481          James Cameron
# 3                 202003951           Ryan Coogler
# 4                 257698183          Anthony Russo
# ..                      ...                    ...
# 718                15210156  Christopher McQuarrie
# 719                40058229            Matt Reeves
# 720                30468614        Lasse Hallström
# 721                30035838           F. Gary Gray
# 722                24604751            Alex Proyas
#
# [723 rows x 5 columns]

# %%
total_sales = df['domestic_opening_sales'].sum()

# %%
director_list = df['director'].unique().tolist()

# %%
director_list
# Out:
# ['J.J. Abrams',
#  'Anthony Russo',
#  'James Cameron',
#  'Ryan Coogler',
#  'Colin Trevorrow',
#  'Joss Whedon',
#  'Rian Johnson',
#  'Brad Bird',
#  'Christopher Nolan',
#  'Gareth Edwards',
#  'Andrew Stanton',
#  'Chris Buck',
#  'Andrew Adamson',
#  'Josh Cooley',
#  'Anna Boden',
#  'Francis Lawrence',
#  'Gore Verbinski',
#  'J.A. Bayona',
#  'Lee Unkrich',
#  'Patty Jenkins',
#  'Shane Black',
#  'Gary Ross',
#  'Sam Raimi',
#  'Jake Kasdan',
#  'Michael Bay',
#  'Jon Watts',
#  'James Gunn',
#  'David Yates',
#  'George Lucas',
#  'Peter Jackson',
#  'Mel Gibson',
#  'Chris Renaud',
#  'Pierre Coffin',
#  'Jon Favreau',
#  'Tim Miller',
#  'Pete Docter',
#  'James Wan',
#  'Clint Eastwood',
#  'Byron Howard',
#  'Kyle Balda',
#  'Todd Phillips',
#  'Tim Burton',
#  'Zack Snyder',
#  'Andy Muschietti',
#  'David Ayer',
#  'David Leitch',
#  'Chris Miller',
#  'Chris Columbus',
#  'Steven Spielberg',
#  'Taika Waititi',
#  'Sam Mendes',
#  'David Slade',
#  'Chris Weitz',
#  'Bill Condon',
#  'Mike Newell',
#  'Lana Wachowski',
#  'Jay Roach',
#  'Alfonso Cuarón',
#  'Yarrow Cheney',
#  'Garth Jennings',
#  'Dan Scanlon',
#  'Marc Webb',
#  'Ron Howard',
#  'Christopher Miller',
#  'John Lee Hancock',
#  'Shawn Levy',
#  'Ron Clements',
#  'John Lasseter',
#  'Tom Shadyac',
#  'Joel Zwick',
#  'Robert Stromberg',
#  'Rob Marshall',
#  'Mike Mitchell',
#  'Justin Lin',
#  'Mark Andrews',
#  'Brett Ratner',
#  'Bryan Singer',
#  'Robert Zemeckis',
#  'Scott Derrickson',
#  'Ridley Scott',
#  'M. Night Shyamalan',
#  'Peter Berg',
#  'Paul Greengrass',
#  'James Mangold',
#  'F. Gary Gray',
#  'Don Hall',
#  'Christopher McQuarrie',
#  'Jon Turteltaub',
#  'Betty Thomas',
#  'Seth MacFarlane',
#  'Dean DeBlois',
#  'Tim Hill',
#  'Peyton Reed',
#  'Eric Darnell',
#  'Mark Osborne',
#  'John Woo',
#  'Bradley Cooper',
#  'Ruben Fleischer',
#  'David Dobkin',
#  'Guy Ritchie',
#  'Matt Reeves',
#  'Alan Taylor',
#  'Adil El Arbi',
#  'Marc Forster',
#  'Stephen Sommers',
#  'Kenneth Branagh',
#  'Phil Johnston',
#  'Nathan Greno',
#  'Rob Letterman',
#  'George Miller',
#  'Carlos Saldanha',
#  'Catherine Hardwicke',
#  'Barry Sonnenfeld',
#  'Phil Lord',
#  'Jonathan Liebesman',
#  'Bob Persichetti',
#  'Rich Moore',
#  'John Krasinski',
#  'Kirk DeMicco',
#  'Roland Emmerich',
#  'Doug Liman',
#  'Elizabeth Banks',
#  'Alejandro G. Iñárritu',
#  'Steven Soderbergh',
#  'David Silverman',
#  'Nancy Meyers',
#  'Wolfgang Petersen',
#  'Joe Johnston',
#  'Gavin Hood',
#  'Andy Tennant',
#  'Tim Johnson',
#  'Rupert Wyatt',
#  'Harald Zwart',
#  'Chris Wedge',
#  'Jordan Peele',
#  'Chris McKay',
#  'Tom McGrath',
#  'Jon M. Chu',
#  'Michael Gracey',
#  'Joachim Rønning',
#  'Joseph Kosinski',
#  'Ethan Coen',
#  'Chad Stahelski',
#  'Tate Taylor',
#  'Genndy Tartakovsky',
#  'Theodore Melfi',
#  'Paul Feig',
#  'Walt Becker',
#  'Jordan Vogt-Roberts',
#  'David Fincher',
#  'Martin Campbell',
#  'Sam Taylor-Johnson',
#  'Jennifer Yuh Nelson',
#  'Anne Fletcher',
#  'Gabriele Muccino',
#  'Louis Leterrier',
#  'Paul Tibbitt',
#  'Quentin Tarantino',
#  'Dennis Dugan',
#  'Steve Martino',
#  'Lee Tamahori',
#  'Bibo Bergeron',
#  'David Gordon Green',
#  'Peter Segal',
#  'Keenen Ivory Wayans',
#  'Rupert Sanders',
#  'Brad Peyton',
#  'Tim Story',
#  'Jimmy Hayward',
#  'Raja Gosnell',
#  'Brian Fee',
#  'Michael Patrick King',
#  'Damien Chazelle',
#  'Neil Burger',
#  'Rawson Marshall Thurber',
#  'Jonathan Mostow',
#  'Sean Anders',
#  'Nicholas Stoller',
#  'David O. Russell',
#  'Jeff Fowler',
#  'Tom Hooper',
#  'Judd Apatow',
#  'Paul Weitz',
#  'Adam McKay',
#  'Matthew Vaughn',
#  'Steve Carr',
#  'J.B. Rogers',
#  'Pierre Morel',
#  'Baz Luhrmann',
#  'Alex Proyas',
#  'Rob Cohen',
#  'Phyllida Lloyd',
#  'Alessandro Carloni',
#  'Jason Reitman',
#  'David Frankel',
#  'Danny Boyle',
#  'David F. Sandberg',
#  'Olivier Megaton',
#  'Michael Lembeck',
#  'Eric Leighton',
#  'Frank Coraci',
#  'Ben Affleck',
#  'Mark Dindal',
#  'Len Wiseman',
#  'Timur Bekmambetov',
#  'Seth Gordon',
#  'Adam Shankman',
#  'Stephen Chbosky',
#  'Martin Scorsese',
#  'Ang Lee',
#  'Simon West',
#  'Robert Schwentke',
#  'Larry Charles',
#  'Kevin Lima',
#  'Travis Knight',
#  'John Singleton',
#  'Luc Besson',
#  'Simon J. Smith',
#  'Daniel Espinosa',
#  'Steven Brill',
#  'McG',
#  'Michael Sucsy',
#  'Josh Boone',
#  'Peter Sohn',
#  'Greg Mottola',
#  'Ol Parker',
#  'Cody Cameron',
#  'Hoyt Yeatman',
#  'Michael Moore',
#  'Phil Alden Robinson',
#  'Brad Silberling',
#  'Josh Gordon',
#  'Phillip Noyce',
#  'Corin Hardy',
#  'Jeff Tremaine',
#  'Clark Johnson',
#  'Curtis Hanson',
#  'Lee Daniels',
#  'Mark Steven Johnson',
#  'Steven Caple Jr.',
#  'Boaz Yakin',
#  'Neill Blomkamp',
#  'Angelina Jolie',
#  'Will Gluck',
#  'Malcolm D. Lee',
#  'James Foley',
#  'Greg Tiernan',
#  'Jon Lucas',
#  'Tony Gilroy',
#  'Robert Rodriguez',
#  'Rob Minkoff',
#  'Edward Zwick',
#  'Ben Stiller',
#  'Michael Dougherty',
#  'Garry Marshall',
#  'Takashi Shimizu',
#  'Dean Parisot',
#  'Mark Waters',
#  'David Zucker',
#  'Peter Billingsley',
#  'Greta Gerwig',
#  'Oren Peli',
#  'Edgar Wright',
#  'Clay Kaytis',
#  'Darren Aronofsky',
#  'Peter Lord',
#  'Donald Petrie',
#  'Noam Murro',
#  'Lorene Scafaria',
#  'Trish Sie',
#  'Jesse Dylan',
#  'Michael Apted',
#  'Henry Joost',
#  'Peter Ramsey',
#  'Sylvester Stallone',
#  'Wes Ball',
#  'Antoine Fuqua',
#  'Guillermo del Toro',
#  'Eric Brevig',
#  'Dominic Sena',
#  'Evan Goldberg',
#  'D.J. Caruso',
#  'Bo Welch',
#  'Michael Mann',
#  'Cameron Crowe',
#  'Denis Villeneuve',
#  'Ava DuVernay',
#  'Morten Tyldum',
#  'Kelly Asbury',
#  'Michel Gondry',
#  'Stephen J. Anderson',
#  'Michael Engler',
#  'Alejandro Amenábar',
#  'Robert Luketic',
#  'Dexter Fletcher',
#  'Kathryn Bigelow',
#  'Brian Robbins',
#  'Anthony Minghella',
#  'Brian Helgeland',
#  'Albert Hughes',
#  'Nora Ephron',
#  'Wayne Wang',
#  'Ken Kwapis',
#  'Peter Weir',
#  'Joe Roth',
#  'Rob Reiner',
#  'Lawrence Guterman',
#  'Toni Myers',
#  'Marc Lawrence',
#  'Jaume Collet-Serra',
#  'Randall Wallace',
#  'Thomas Carter',
#  'Chuck Russell',
#  'Andy Fickman',
#  'Bobby Farrelly',
#  'Kenny Ortega',
#  'Tyler Perry',
#  'Etan Cohen',
#  'Klay Hall',
#  'Charles Herman-Wurmfeld',
#  'Fede Alvarez',
#  'Wes Craven',
#  'Tom Dey',
#  'James Bobin',
#  'Spike Lee',
#  'John Hamburg',
#  'Jason Moore',
#  'Darren Lynn Bousman',
#  "Gavin O'Connor",
#  'Tony Leondis',
#  'Stephen Hillenburg',
#  'Dean Israelite',
#  'Aaron Blaise',
#  'Roger Allers',
#  'Peter Farrelly',
#  'Tod Williams',
#  'Ben Falcone',
#  'Glenn Ficarra',
#  'John R. Leonetti',
#  'Cathy Yan',
#  'Gary Trousdale',
#  'Nick Cassavetes',
#  'Tarsem Singh',
#  'Andrew Erwin',
#  'Karey Kirkpatrick',
#  'Gene Stupnitsky',
#  'David Soren',
#  'Gary Winick',
#  'Brian Levant',
#  'Ronny Yu',
#  'Alexander Payne',
#  'Luke Greenfield',
#  'Gabor Csupo',
#  'Dave Green',
#  'Frank Marshall',
#  'Tony Scott',
#  'Richard Linklater',
#  'John A. Davis',
#  'Ryan Murphy',
#  'Marcus Nispel',
#  'Paul W.S. Anderson',
#  'Tom Vaughan',
#  'Jay Chandrasekhar',
#  'Alex Kurtzman',
#  'Jared Hess',
#  'Lasse Hallström']

# %%
df1 = df.groupby('director').sum('domestic_opening_sales')

# %%
df2 = df1.sort_values('domestic_opening_sales',ascending = False).head(50).reset_index()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   director                50 non-null     object
#  1   Unnamed: 0              50 non-null     int64
#  2   budget                  50 non-null     int64
#  3   domestic_opening_sales  50 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 1.7+ KB

# %%
top50_director = df2['director'].unique().tolist()

# %%
top50_sales = df2['domestic_opening_sales'].sum()

# %%
top50_sales/total_sales
# Out:
# 0.44917135374406175

# %%
top50_director
# Out:
# ['Anthony Russo',
#  'J.J. Abrams',
#  'David Yates',
#  'Christopher Nolan',
#  'Michael Bay',
#  'Zack Snyder',
#  'Francis Lawrence',
#  'Peter Jackson',
#  'Sam Raimi',
#  'Bryan Singer',
#  'Joss Whedon',
#  'Jon Favreau',
#  'Gore Verbinski',
#  'Brad Bird',
#  'James Wan',
#  'Todd Phillips',
#  'Peyton Reed',
#  'Tim Burton',
#  'Justin Lin',
#  'Bill Condon',
#  'Ridley Scott',
#  'Steven Spielberg',
#  'Andrew Adamson',
#  'Andrew Stanton',
#  'Ron Howard',
#  'M. Night Shyamalan',
#  'Brett Ratner',
#  'Gareth Edwards',
#  'Rian Johnson',
#  'James Gunn',
#  'Roland Emmerich',
#  'Ryan Coogler',
#  'Tim Story',
#  'Chris Renaud',
#  'Pete Docter',
#  'Gary Ross',
#  'Andy Muschietti',
#  'Peter Segal',
#  'Chris Columbus',
#  'Jon Watts',
#  'Colin Trevorrow',
#  'F. Gary Gray',
#  'Paul Greengrass',
#  'Shawn Levy',
#  'Carlos Saldanha',
#  'Eric Darnell',
#  'James Mangold',
#  'George Lucas',
#  'Kyle Balda',
#  'David Leitch']

# %%
df1.describe()
# Out:
#        Unnamed: 0        budget  domestic_opening_sales
# count   366.00000  3.660000e+02            3.660000e+02
# mean    739.70765  1.932071e+08            9.543914e+07
# std     559.72200  2.181809e+08            1.098738e+08
# min       2.00000  1.500000e+04            7.787300e+04
# 25%     374.25000  5.000000e+07            3.088366e+07
# 50%     617.50000  1.165000e+08            5.389678e+07
# 75%     998.25000  2.550000e+08            1.247093e+08
# max    3183.00000  1.242000e+09            8.889761e+08

# %%
plt.figure(figsize = [10,5])
plt.hist(df1['domestic_opening_sales'],10)
plt.axis([150000, 900000000, 0, 250]); 
plt.show;
